# %%
import os
import time
from IPython import display

import torch
import torchvision
from torch import nn
import torchvision.transforms as transforms
from torch.utils import data
import matplotlib.pyplot as plt

# %% [markdown]
# Debug Code
# ```
# def debug(self,X):
#         print('---------------1--------------')
#         X1 = self.layer1(X)
#         print(self.layer1.__class__.__name__, "output shape: \t", X1.shape)
#         print('---------------2--------------')
#         X2 = self.layer2(X1)
#         print(self.layer2.__class__.__name__, "output shape: \t", X2.shape)
#         print('----------------3-------------')
#         X3 = self.layer3(X2)
#         print(self.layer3.__class__.__name__, "output shape: \t", X3.shape)
#         print('---------------4--------------')
#         X4 = self.layer4(X3)
#         print(self.layer4.__class__.__name__, "output shape: \t", X4.shape)
#         print('----------------5-------------')
#         X5 = self.layer5(X4)
#         print(self.layer5.__class__.__name__, "output shape: \t", X5.shape)
#         print('----------------6-------------')
#         X5_with_upscale = self.crop_and_cat(X4,self.upCov1(X5),crop_by=4)
#         X6 = self.layer6(X5_with_upscale)
#         print(self.layer6.__class__.__name__, "output shape: \t", X6.shape)
#         print('-----------------7------------')
#         X6_with_upscale = self.crop_and_cat(X3,self.upCov2(X6),crop_by=16)
#         X7 = self.layer7(X6_with_upscale)
#         print(self.layer7.__class__.__name__, "output shape: \t", X7.shape)
#         print('-----------------8------------')
#         X7_with_upscale = self.crop_and_cat(X2,self.upCov3(X7),crop_by=40)
#         X8 = self.layer8(X7_with_upscale)
#         print(self.layer8.__class__.__name__, "output shape: \t", X8.shape)
#         print('-----------------9------------')
#         X8_with_upscale = self.crop_and_cat(X1,self.upCov4(X8),crop_by=88)
#         X9 = self.layer9(X8_with_upscale)
#         print(self.layer9.__class__.__name__, "output shape: \t", X9.shape)
#         return X9
# ```
# Experimental code
# ```
# # input = torch.randn(1, 16, 12, 12)
# # downsample = nn.Conv2d(16, 16, 3, stride=2, padding=1)
# # upsample = nn.ConvTranspose2d(16, 16, 3, stride=2, padding=1)
# # h = downsample(input)
# # print(h.size())
# # torch.Size([1, 16, 6, 6])
# # output = upsample(h, output_size=input.size())
# # print(output.size())
#
# input = torch.randn(1, 512, 64, 64)
# downsample = nn.Sequential(
#     nn.MaxPool2d(kernel_size=2),
#     nn.Conv2d(512,1024,kernel_size=3),
#     nn.ReLU(),
#     nn.Conv2d(1024,1024,kernel_size=3),
#     nn.ReLU()
# )
# upsample = nn.Sequential(
#     nn.ConvTranspose2d(1024, 512, 2,stride=2)
# )
# h = downsample(input)
# print(h.size())
# output = upsample(h)
# # output = upsample(h, output_size=(-1,512,32,32))
# print(output.size())
# ```

# %%
class UNetModel(nn.Module):

    def __init__(self,input_channels=3,output_channels=3):
        super().__init__()
        self.layer1 = self.defineFirstLayer(input_channels)
        self.layer2 = self.defineSecondLayer()
        self.layer3 = self.defineThirdLayer()
        self.layer4 = self.defineFourthLayer()
        self.layer5 = self.defineFifthLayer()
        self.upCov1 = nn.ConvTranspose2d(128,64,kernel_size=2,stride=2)
        self.layer6 = self.defineSixthLayer()
        self.upCov2 = nn.ConvTranspose2d(64,32,kernel_size=2,stride=2)
        self.layer7 = self.defineSeventhLayer()
        self.upCov3 = nn.ConvTranspose2d(32,16,kernel_size=2,stride=2)
        self.layer8 = self.defineEighthLayer()
        self.upCov4 = nn.ConvTranspose2d(16,8,kernel_size=2,stride=2)
        self.layer9 = self.defineNinthLayer(output_channels)
    
    def defineFirstLayer(self,input_channels):
        return nn.Sequential(
            nn.Conv2d(input_channels,8,kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(8,8,kernel_size=3),
            nn.ReLU()
        )
    
    def defineSecondLayer(self):
        return nn.Sequential(
            nn.MaxPool2d(kernel_size=2,stride=2),
            nn.Conv2d(8,16,kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(16,16,kernel_size=3),
            nn.ReLU()
        )
    
    def defineThirdLayer(self):
        return nn.Sequential(
            nn.MaxPool2d(kernel_size=2,stride=2),
            nn.Conv2d(16,32,kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(32,32,kernel_size=3),
            nn.ReLU()
        )
    
    def defineFourthLayer(self):
        return nn.Sequential(
            nn.MaxPool2d(kernel_size=2,stride=2),
            nn.Conv2d(32,64,kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(64,64,kernel_size=3),
            nn.ReLU()
        )
    
    def defineFifthLayer(self):
        return nn.Sequential(
            nn.MaxPool2d(kernel_size=2,stride=2),
            nn.Conv2d(64,128,kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(128,128,kernel_size=3),
            nn.ReLU()
        )

    def defineSixthLayer(self):
        return nn.Sequential(
            nn.Conv2d(128,64,kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(64,64,kernel_size=3),
            nn.ReLU()
        )
    
    
    def defineSeventhLayer(self):
        return nn.Sequential(
            nn.Conv2d(64,32,kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(32,32,kernel_size=3),
            nn.ReLU()
        )
    
    def defineEighthLayer(self):
        return nn.Sequential(
            nn.Conv2d(32,16,kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(16,16,kernel_size=3),
            nn.ReLU()
        )
    
    def defineNinthLayer(self,output_channels):
        return nn.Sequential(
            nn.Conv2d(16,8,kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(8,8,kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(8,output_channels,kernel_size=1)
        )
    
    def crop_and_cat(self,cropTensor,catTensor,crop_by=(4,4)):
        cropTensor = self.crop(cropTensor,crop_by)
        # print(cropTensor.shape)
        # print(catTensor.shape)
        return torch.cat((cropTensor, catTensor),dim=1)


    def crop(self,cropTensor,crop_by):
        # print(crop_by)
        match crop_by:
            case (16,17):
                return cropTensor[:,:,crop_by[0]:-crop_by[0]-1,crop_by[1]:-crop_by[1]+1] 
            case _:
                return cropTensor[:,:,crop_by[0]:-crop_by[0],crop_by[1]:-crop_by[1]]
    
    def forward(self,X):
        X1 = self.layer1(X)
        X2 = self.layer2(X1)
        X3 = self.layer3(X2)
        X4 = self.layer4(X3)
        X5 = self.layer5(X4)
        X5_with_upscale = self.crop_and_cat(X4,self.upCov1(X5),crop_by=(4,4))
        X6 = self.layer6(X5_with_upscale)  
        X6_with_upscale = self.crop_and_cat(X3,self.upCov2(X6),crop_by=(16,17))
        X7 = self.layer7(X6_with_upscale)  
        X7_with_upscale = self.crop_and_cat(X2,self.upCov3(X7),crop_by=(41,41))
        X8 = self.layer8(X7_with_upscale)  
        X8_with_upscale = self.crop_and_cat(X1,self.upCov4(X8),crop_by=(90,90))
        X9 = self.layer9(X8_with_upscale)  
        return X9

model = UNetModel(input_channels=1,output_channels=1)
X = torch.rand(size=(1, 1, 256, 256), dtype=torch.float32)
model(X).shape
# Out:
# torch.Size([1, 1, 68, 68])

# %%
transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Resize((256,256))
    ]
)
training_data = torchvision.datasets.MNIST(root="../data/MINST", download=True, train=True, transform=transform)
validation_data = torchvision.datasets.MNIST(root="../data/MINST", download=True, train=False, transform=transform)


train_iter = torch.utils.data.DataLoader(training_data, batch_size=100, shuffle=True)
test_iter = torch.utils.data.DataLoader(validation_data, batch_size=100, shuffle=False)
batch_size = len(train_iter)

# %%
# def load_dataset(batch_size, resize=None):
#   trans = [transforms.ToTensor()]
#   if resize:
#     trans.insert(0, transforms.Resize(resize))
#   trans = transforms.Compose(trans)
#   train = torchvision.datasets.CelebA(root="../data", split='train', transform=trans, download=True)
#   test = torchvision.datasets.CelebA(root="../data", split='test', transform=trans, download=True)
#   return (
#     data.DataLoader(train, batch_size, shuffle=True, num_workers=4),
#     data.DataLoader(test, batch_size, shuffle=False, num_workers=4)
#   )
# batch_size = 1000
# train_iter, test_iter = load_dataset(batch_size=batch_size,resize=(256,256))

# %%
# import random

# x_resize = torchvision.transforms.Resize((68,68))
# i=0
# for images,labels in train_iter: 
#     # index = random.randint(0,batch_size-1)
#     img = images[0]
#     print(img.shape)
#     plt.subplot(3, 4, i + 1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(img.permute(1,2,0))
#     plt.title(labels[0])
#     i += 1
#     if i >= 12 :
#        break
# plt.show()

# %%
def set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend):
  """Set the axes for matlabplots."""
  axes.set_xlabel(xlabel)
  axes.set_ylabel(ylabel)
  axes.set_xlim(xlim)
  axes.set_ylim(ylim)
  axes.set_xscale(xscale)
  axes.set_yscale(yscale)
  if legend:
    axes.legend(legend)
  axes.grid()

class Animator:
  """For plotting data in animation"""

  def __init__(
      self,
      xlabel=None,
      ylabel=None,
      legend=None,
      xlim=None,
      ylim=None,
      xscale="linear",
      yscale="linear",
      fmts=("-", "m--", "g-", "r:"),
      nrows=1,
      ncols=1,
      figsize=(3.5, 2.5),
  ):
      #Incrementally plot multiple lines
      if legend is None:
          legend = []
      display.set_matplotlib_formats("svg")
      self.fig, self.axes = plt.subplots(nrows, ncols, figsize=figsize)
      if nrows*ncols == 1:
        self.axes = [
            self.axes,
        ]
      #Use lamda function to capture arguments
      self.config_axes = lambda: set_axes(self.axes[0], xlabel, ylabel, xlim, ylim, xscale, yscale, legend)
      self.X, self.Y, self.fmts = None, None, fmts

  def add(self, x, y):
    # Add multiple data points into the figure
    if not hasattr(y, "__len__"):
      y = [y]
    n = len(y)
    if not hasattr(x, "__len__"):
      x = [x] * n
    if not self.X:
      self.X = [[] for _ in range(n)]
    if not self.Y:
      self.Y = [[] for _ in range(n)]

    for i ,(a,b) in enumerate(zip(x, y)):
      if a is not None and b is not None:
        self.X[i].append(a)
        self.Y[i].append(b)
    self.axes[0].cla()
    for x, y, fmt in zip(self.X, self.Y, self.fmts):
      self.axes[0].plot(x, y, fmt)
    self.config_axes()
    display.display(self.fig)
    display.clear_output(wait=True)

class Timer:
  """Record multiple running times."""
  def __init__(self):
    self.times = []
    self.start()

  def start(self):
    """Start the timer."""
    self.tik = time.time()

  def stop(self):
    """Stop the timer and record the time in a list."""
    self.times.append(time.time() - self.tik)
    return self.times[-1]

  def avg(self):
    """Returns the average time"""
    return sum(self.times) / len(self.times)

  def sum(self):
    """Returns the sum of time."""
    return sum(self.times)

  def cumsum(self):
    """Return the accumulated time."""
    return np.array(self.times).cumsum().tolist()

class Accumulator:
  """For accumulating sums over `n` variables."""

  def __init__(self, n):
    self.data = [0.0] * n

  def add(self, *args):
    self.data = [a + float(b) for a, b in zip(self.data, args)]

  def reset(self):
    self.data = [0.0] * len(self.data)

  def __getitem__(self, idx):
    return self.data[idx]

def try_gpu(i=0):
  """Return gpu(i) if exists, otherwise return cpu()."""
  if torch.cuda.device_count() >= i+1:
    return torch.device(f"cuda:{i}")
  return torch.device("cpu")

# %%
x_resize_test = torchvision.transforms.Resize((68,68))
loss_test = nn.MSELoss(reduction='sum')
def accuracy(y_hat, y):
  """Compute the number of correct predictions."""
  if len(y_hat.shape) > 1 and y_hat.shape[1] > 1:
    y_hat = torch.argmax(y_hat, axis=1)
  cmp_ = y_hat.type(y.dtype) == y
  return float(cmp_.type(y.dtype).sum())

def evaluate_accuracy_gpu(net, data_iter, device=None):
  """Compute the accuracy of the model on the dataset using GPU"""
  if isinstance(net, torch.nn.Module):
    net.eval() # Set the model to evaluation mode
    if not device:
      device = next(iter(net.parameters())).device
  for X, _ in data_iter:
    X = X.to(device)
    acc = loss_test(net(X), x_resize_test(X))
  return acc

# %%
def train(net, train_iter, test_iter, num_epochs, lr, filename, device):
  def init_weights(m):
    if type(m) == nn.Linear or type(m) == nn.Conv2d:
      nn.init.xavier_uniform_(m.weight)

  net.apply(init_weights)
  print("training on", device)
  net.to(device)
  optimizer = torch.optim.SGD(net.parameters(), lr=lr)
  loss = nn.MSELoss(reduction='sum')
  x_resize = torchvision.transforms.Resize((68,68))
  timer, num_batches = Timer(), len(train_iter)
  # animator = Animator(xlabel="epoch", xlim=[1, num_epochs*num_batches], ylim=[0,100000], legend = ["train loss"])
  for epoch in range(num_epochs):
    net.train()
    for i, (X,_) in enumerate(train_iter):
      timer.start()
      optimizer.zero_grad()
      X = X.to(device)
      y_hat = net(X)
      y = x_resize(X)
      l = loss(y_hat,y)
      optimizer.step()
      with torch.no_grad():
        print(f'epoch : {epoch}, batch per epoch : {i}, X : {epoch*num_batches + (i + 1)}, Y : {l}')
        # animator.add(epoch*num_batches + (i + 1), (l, None))
      # if i%10 == 0:
      #   torch.save(net, filename)
        
    test_acc = evaluate_accuracy_gpu(net, test_iter)
    # animator.add(epoch + 1, (None, test_acc))

# %%
lr, num_epochs = 0.01, 10
file_name = './usp_mnist.pt'
train(model, train_iter, test_iter, num_epochs, lr, file_name, try_gpu())
# Out:
# training on cpu
# /Users/debashisdas/Projects/DeepLearning/.venv/lib/python3.11/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# epoch : 0, batch per epoch : 0, X : 1, Y : 54829.16796875
# epoch : 0, batch per epoch : 1, X : 2, Y : 54800.20703125
# epoch : 0, batch per epoch : 2, X : 3, Y : 54262.91796875
# epoch : 0, batch per epoch : 3, X : 4, Y : 54072.58203125
# epoch : 0, batch per epoch : 4, X : 5, Y : 54839.63671875
# epoch : 0, batch per epoch : 5, X : 6, Y : 54422.4609375
# epoch : 0, batch per epoch : 6, X : 7, Y : 54075.5
# epoch : 0, batch per epoch : 7, X : 8, Y : 54620.0625
# epoch : 0, batch per epoch : 8, X : 9, Y : 55662.6015625
# epoch : 0, batch per epoch : 9, X : 10, Y : 55280.5625
# epoch : 0, batch per epoch : 10, X : 11, Y : 54599.84765625
# epoch : 0, batch per epoch : 11, X : 12, Y : 54887.43359375
# epoch : 0, batch per epoch : 12, X : 13, Y : 54783.4921875
# epoch : 0, batch per epoch : 13, X : 14, Y : 54259.1640625
# epoch : 0, batch per epoch : 14, X : 15, Y : 54000.75
# epoch : 0, batch per epoch : 15, X : 16, Y : 54653.0625
# epoch : 0, batch per epoch : 16, X : 17, Y : 55255.83984375
# epoch : 0, batch per epoch : 17, X : 18, Y : 55517.28125
# epoch : 0, batch per epoch : 18, X : 19, Y : 54798.3984375
# epoch : 0, batch per epoch : 19, X : 20, Y : 55565.6953125
# epoch : 0, batch per epoch : 20, X : 21, Y : 55283.0
# epoch : 0, batch per epoch : 21, X : 22, Y : 55526.71484375
# epoch : 0, batch per epoch : 22, X : 23, Y : 54282.7109375
# epoch : 0, batch per epoch : 23, X : 24, Y : 54314.21484375
# epoch : 0, batch per epoch : 24, X : 25, Y : 54662.10546875
# epoch : 0, batch per epoch : 25, X : 26, Y : 54586.7734375
# epoch : 0, batch per epoch : 26, X : 27, Y : 55385.08203125
# epoch : 0, batch per epoch : 27, X : 28, Y : 55654.5625
# epoch : 0, batch per epoch : 28, X : 29, Y : 54874.35546875
# epoch : 0, batch per epoch : 29, X : 30, Y : 54611.26171875
# epoch : 0, batch per epoch : 30, X : 31, Y : 55743.99609375
# epoch : 0, batch per epoch : 31, X : 32, Y : 54330.3515625
# epoch : 0, batch per epoch : 32, X : 33, Y : 55602.2578125
# epoch : 0, batch per epoch : 33, X : 34, Y : 54971.98828125
# epoch : 0, batch per epoch : 34, X : 35, Y : 53425.48046875
# epoch : 0, batch per epoch : 35, X : 36, Y : 55477.1015625
# epoch : 0, batch per epoch : 36, X : 37, Y : 54686.20703125
# epoch : 0, batch per epoch : 37, X : 38, Y : 54491.0859375
# epoch : 0, batch per epoch : 38, X : 39, Y : 54780.8359375
# epoch : 0, batch per epoch : 39, X : 40, Y : 54328.2265625
# epoch : 0, batch per epoch : 40, X : 41, Y : 53770.67578125
# epoch : 0, batch per epoch : 41, X : 42, Y : 55037.6875
# epoch : 0, batch per epoch : 42, X : 43, Y : 54611.67578125
# epoch : 0, batch per epoch : 43, X : 44, Y : 54738.5390625
# epoch : 0, batch per epoch : 44, X : 45, Y : 55408.9609375
# epoch : 0, batch per epoch : 45, X : 46, Y : 53622.125
# epoch : 0, batch per epoch : 46, X : 47, Y : 54087.37109375
# epoch : 0, batch per epoch : 47, X : 48, Y : 54316.13671875
# epoch : 0, batch per epoch : 48, X : 49, Y : 55215.08203125
# epoch : 0, batch per epoch : 49, X : 50, Y : 54615.2421875
# epoch : 0, batch per epoch : 50, X : 51, Y : 54335.80859375
# epoch : 0, batch per epoch : 51, X : 52, Y : 55270.3828125
# epoch : 0, batch per epoch : 52, X : 53, Y : 55204.05078125
# epoch : 0, batch per epoch : 53, X : 54, Y : 54486.4140625
# epoch : 0, batch per epoch : 54, X : 55, Y : 54806.23046875
# epoch : 0, batch per epoch : 55, X : 56, Y : 55653.54296875
# epoch : 0, batch per epoch : 56, X : 57, Y : 53804.72265625
# epoch : 0, batch per epoch : 57, X : 58, Y : 54759.1875
# epoch : 0, batch per epoch : 58, X : 59, Y : 54921.55859375
# epoch : 0, batch per epoch : 59, X : 60, Y : 54771.5078125
# epoch : 0, batch per epoch : 60, X : 61, Y : 53872.18359375
# epoch : 0, batch per epoch : 61, X : 62, Y : 54961.7109375
# epoch : 0, batch per epoch : 62, X : 63, Y : 54593.5859375
# epoch : 0, batch per epoch : 63, X : 64, Y : 54314.9296875
# epoch : 0, batch per epoch : 64, X : 65, Y : 55273.50390625
# epoch : 0, batch per epoch : 65, X : 66, Y : 54434.6015625
# epoch : 0, batch per epoch : 66, X : 67, Y : 54384.12109375
# epoch : 0, batch per epoch : 67, X : 68, Y : 55699.78125
# epoch : 0, batch per epoch : 68, X : 69, Y : 55038.890625
# epoch : 0, batch per epoch : 69, X : 70, Y : 54028.8359375
# epoch : 0, batch per epoch : 70, X : 71, Y : 54087.16796875
# epoch : 0, batch per epoch : 71, X : 72, Y : 55156.73828125
# epoch : 0, batch per epoch : 72, X : 73, Y : 54979.640625
# epoch : 0, batch per epoch : 73, X : 74, Y : 54375.45703125
# epoch : 0, batch per epoch : 74, X : 75, Y : 53914.0390625
# epoch : 0, batch per epoch : 75, X : 76, Y : 54935.4921875
# epoch : 0, batch per epoch : 76, X : 77, Y : 54783.39453125
# epoch : 0, batch per epoch : 77, X : 78, Y : 55235.671875
# epoch : 0, batch per epoch : 78, X : 79, Y : 54517.609375
# epoch : 0, batch per epoch : 79, X : 80, Y : 55751.5078125
# epoch : 0, batch per epoch : 80, X : 81, Y : 53895.0546875
# epoch : 0, batch per epoch : 81, X : 82, Y : 55848.37109375
# epoch : 0, batch per epoch : 82, X : 83, Y : 53864.85546875
# epoch : 0, batch per epoch : 83, X : 84, Y : 55718.0078125
# epoch : 0, batch per epoch : 84, X : 85, Y : 53991.171875
# epoch : 0, batch per epoch : 85, X : 86, Y : 55083.0625
# epoch : 0, batch per epoch : 86, X : 87, Y : 54724.234375
# epoch : 0, batch per epoch : 87, X : 88, Y : 55458.796875
# epoch : 0, batch per epoch : 88, X : 89, Y : 55125.5625
# epoch : 0, batch per epoch : 89, X : 90, Y : 54337.6328125
# epoch : 0, batch per epoch : 90, X : 91, Y : 55238.59765625
# epoch : 0, batch per epoch : 91, X : 92, Y : 54622.95703125
# epoch : 0, batch per epoch : 92, X : 93, Y : 54254.8984375
# epoch : 0, batch per epoch : 93, X : 94, Y : 54821.265625
# epoch : 0, batch per epoch : 94, X : 95, Y : 55440.69140625
# epoch : 0, batch per epoch : 95, X : 96, Y : 54798.46484375
# epoch : 0, batch per epoch : 96, X : 97, Y : 54261.890625
# epoch : 0, batch per epoch : 97, X : 98, Y : 54290.12890625
# epoch : 0, batch per epoch : 98, X : 99, Y : 54640.63671875
# epoch : 0, batch per epoch : 99, X : 100, Y : 54612.1328125
# epoch : 0, batch per epoch : 100, X : 101, Y : 54241.90625
# epoch : 0, batch per epoch : 101, X : 102, Y : 55032.19140625
# epoch : 0, batch per epoch : 102, X : 103, Y : 55500.1796875
# epoch : 0, batch per epoch : 103, X : 104, Y : 54884.703125
# epoch : 0, batch per epoch : 104, X : 105, Y : 54723.4921875
# epoch : 0, batch per epoch : 105, X : 106, Y : 55457.3203125
# epoch : 0, batch per epoch : 106, X : 107, Y : 53984.44921875
# epoch : 0, batch per epoch : 107, X : 108, Y : 55765.296875
# epoch : 0, batch per epoch : 108, X : 109, Y : 54529.3046875
# epoch : 0, batch per epoch : 109, X : 110, Y : 54731.00390625
# epoch : 0, batch per epoch : 110, X : 111, Y : 54567.69140625
# epoch : 0, batch per epoch : 111, X : 112, Y : 54577.890625
# epoch : 0, batch per epoch : 112, X : 113, Y : 54713.00390625
# epoch : 0, batch per epoch : 113, X : 114, Y : 55289.53515625
# epoch : 0, batch per epoch : 114, X : 115, Y : 55665.9140625
# epoch : 0, batch per epoch : 115, X : 116, Y : 54275.07421875
# epoch : 0, batch per epoch : 116, X : 117, Y : 54458.9765625
# epoch : 0, batch per epoch : 117, X : 118, Y : 55122.4921875
# epoch : 0, batch per epoch : 118, X : 119, Y : 53873.16015625
# epoch : 0, batch per epoch : 119, X : 120, Y : 54994.76171875
# epoch : 0, batch per epoch : 120, X : 121, Y : 54139.078125
# epoch : 0, batch per epoch : 121, X : 122, Y : 54172.140625
# epoch : 0, batch per epoch : 122, X : 123, Y : 54864.5
# epoch : 0, batch per epoch : 123, X : 124, Y : 54878.12109375
# epoch : 0, batch per epoch : 124, X : 125, Y : 54495.15625
# epoch : 0, batch per epoch : 125, X : 126, Y : 55276.46484375
# epoch : 0, batch per epoch : 126, X : 127, Y : 53035.30859375
# epoch : 0, batch per epoch : 127, X : 128, Y : 55053.73046875
# epoch : 0, batch per epoch : 128, X : 129, Y : 54939.82421875
# epoch : 0, batch per epoch : 129, X : 130, Y : 55333.734375
# epoch : 0, batch per epoch : 130, X : 131, Y : 53813.74609375
# epoch : 0, batch per epoch : 131, X : 132, Y : 55565.99609375
# epoch : 0, batch per epoch : 132, X : 133, Y : 54856.84765625
# epoch : 0, batch per epoch : 133, X : 134, Y : 54207.84765625
# epoch : 0, batch per epoch : 134, X : 135, Y : 54215.21484375
# epoch : 0, batch per epoch : 135, X : 136, Y : 55450.60546875
# epoch : 0, batch per epoch : 136, X : 137, Y : 53394.87890625
# epoch : 0, batch per epoch : 137, X : 138, Y : 54422.33984375
# epoch : 0, batch per epoch : 138, X : 139, Y : 55292.9609375
# epoch : 0, batch per epoch : 139, X : 140, Y : 55428.4140625
# epoch : 0, batch per epoch : 140, X : 141, Y : 55688.64453125
# epoch : 0, batch per epoch : 141, X : 142, Y : 55253.60546875
# epoch : 0, batch per epoch : 142, X : 143, Y : 54676.80859375
# epoch : 0, batch per epoch : 143, X : 144, Y : 54357.2421875
# epoch : 0, batch per epoch : 144, X : 145, Y : 56139.8515625
# epoch : 0, batch per epoch : 145, X : 146, Y : 54510.92578125
# epoch : 0, batch per epoch : 146, X : 147, Y : 54308.1171875
# epoch : 0, batch per epoch : 147, X : 148, Y : 54344.66796875
# epoch : 0, batch per epoch : 148, X : 149, Y : 54901.1171875
# epoch : 0, batch per epoch : 149, X : 150, Y : 54553.859375
# epoch : 0, batch per epoch : 150, X : 151, Y : 53813.9921875
# epoch : 0, batch per epoch : 151, X : 152, Y : 54687.66015625
# epoch : 0, batch per epoch : 152, X : 153, Y : 54801.984375
# epoch : 0, batch per epoch : 153, X : 154, Y : 55338.015625
# epoch : 0, batch per epoch : 154, X : 155, Y : 54120.94921875
# epoch : 0, batch per epoch : 155, X : 156, Y : 55269.96875
# epoch : 0, batch per epoch : 156, X : 157, Y : 54762.12109375
# epoch : 0, batch per epoch : 157, X : 158, Y : 54024.75390625
# epoch : 0, batch per epoch : 158, X : 159, Y : 55250.2265625
# epoch : 0, batch per epoch : 159, X : 160, Y : 53871.41015625
# epoch : 0, batch per epoch : 160, X : 161, Y : 54721.27734375
# epoch : 0, batch per epoch : 161, X : 162, Y : 54836.60546875
# epoch : 0, batch per epoch : 162, X : 163, Y : 54360.56640625
# epoch : 0, batch per epoch : 163, X : 164, Y : 54806.26171875
# epoch : 0, batch per epoch : 164, X : 165, Y : 54667.0625
# epoch : 0, batch per epoch : 165, X : 166, Y : 54770.1328125
# epoch : 0, batch per epoch : 166, X : 167, Y : 54583.59375
# epoch : 0, batch per epoch : 167, X : 168, Y : 54434.234375
# epoch : 0, batch per epoch : 168, X : 169, Y : 55121.45703125
# epoch : 0, batch per epoch : 169, X : 170, Y : 54916.65234375
# epoch : 0, batch per epoch : 170, X : 171, Y : 54668.44921875
# epoch : 0, batch per epoch : 171, X : 172, Y : 55333.375
# epoch : 0, batch per epoch : 172, X : 173, Y : 54391.328125
# epoch : 0, batch per epoch : 173, X : 174, Y : 53988.734375
# epoch : 0, batch per epoch : 174, X : 175, Y : 55822.77734375
# epoch : 0, batch per epoch : 175, X : 176, Y : 54846.2734375
# epoch : 0, batch per epoch : 176, X : 177, Y : 54974.625
# epoch : 0, batch per epoch : 177, X : 178, Y : 55265.296875
# epoch : 0, batch per epoch : 178, X : 179, Y : 54807.3671875
# epoch : 0, batch per epoch : 179, X : 180, Y : 54106.71484375
# epoch : 0, batch per epoch : 180, X : 181, Y : 54233.86328125
# epoch : 0, batch per epoch : 181, X : 182, Y : 55411.51953125
# epoch : 0, batch per epoch : 182, X : 183, Y : 54184.87109375
# epoch : 0, batch per epoch : 183, X : 184, Y : 53869.109375
# epoch : 0, batch per epoch : 184, X : 185, Y : 54697.703125
# epoch : 0, batch per epoch : 185, X : 186, Y : 54502.66015625
# epoch : 0, batch per epoch : 186, X : 187, Y : 54420.4609375
# epoch : 0, batch per epoch : 187, X : 188, Y : 54490.0234375
# epoch : 0, batch per epoch : 188, X : 189, Y : 54717.30078125
# epoch : 0, batch per epoch : 189, X : 190, Y : 54620.265625
# epoch : 0, batch per epoch : 190, X : 191, Y : 54166.1875
# epoch : 0, batch per epoch : 191, X : 192, Y : 54985.28515625
# epoch : 0, batch per epoch : 192, X : 193, Y : 54469.3984375
# epoch : 0, batch per epoch : 193, X : 194, Y : 54626.03125
# epoch : 0, batch per epoch : 194, X : 195, Y : 54711.55078125
# epoch : 0, batch per epoch : 195, X : 196, Y : 54627.125
# epoch : 0, batch per epoch : 196, X : 197, Y : 54402.94921875
# epoch : 0, batch per epoch : 197, X : 198, Y : 54569.7109375
# epoch : 0, batch per epoch : 198, X : 199, Y : 54703.96484375
# epoch : 0, batch per epoch : 199, X : 200, Y : 54433.703125
# epoch : 0, batch per epoch : 200, X : 201, Y : 55418.10546875
# epoch : 0, batch per epoch : 201, X : 202, Y : 54614.859375
# epoch : 0, batch per epoch : 202, X : 203, Y : 54858.4609375
# epoch : 0, batch per epoch : 203, X : 204, Y : 54723.90234375
# epoch : 0, batch per epoch : 204, X : 205, Y : 54326.9921875
# epoch : 0, batch per epoch : 205, X : 206, Y : 54596.890625
# epoch : 0, batch per epoch : 206, X : 207, Y : 55521.23046875
# epoch : 0, batch per epoch : 207, X : 208, Y : 54059.90234375
# epoch : 0, batch per epoch : 208, X : 209, Y : 54382.71484375
# epoch : 0, batch per epoch : 209, X : 210, Y : 55458.5234375
# epoch : 0, batch per epoch : 210, X : 211, Y : 54591.46875
# epoch : 0, batch per epoch : 211, X : 212, Y : 55984.85546875
# epoch : 0, batch per epoch : 212, X : 213, Y : 54235.09375
# epoch : 0, batch per epoch : 213, X : 214, Y : 54517.3125
# epoch : 0, batch per epoch : 214, X : 215, Y : 54718.39453125
# epoch : 0, batch per epoch : 215, X : 216, Y : 54117.0078125
# epoch : 0, batch per epoch : 216, X : 217, Y : 55131.99609375
# epoch : 0, batch per epoch : 217, X : 218, Y : 54685.06640625
# epoch : 0, batch per epoch : 218, X : 219, Y : 55340.98828125
# epoch : 0, batch per epoch : 219, X : 220, Y : 53285.83203125
# epoch : 0, batch per epoch : 220, X : 221, Y : 54431.421875
# epoch : 0, batch per epoch : 221, X : 222, Y : 54215.51953125
# epoch : 0, batch per epoch : 222, X : 223, Y : 54304.640625
# epoch : 0, batch per epoch : 223, X : 224, Y : 53988.9609375
# epoch : 0, batch per epoch : 224, X : 225, Y : 54867.94140625
# epoch : 0, batch per epoch : 225, X : 226, Y : 54855.9609375
# epoch : 0, batch per epoch : 226, X : 227, Y : 54193.38671875
# epoch : 0, batch per epoch : 227, X : 228, Y : 55281.08203125
# epoch : 0, batch per epoch : 228, X : 229, Y : 54499.40234375
# epoch : 0, batch per epoch : 229, X : 230, Y : 54300.31640625
# epoch : 0, batch per epoch : 230, X : 231, Y : 55289.15625
# epoch : 0, batch per epoch : 231, X : 232, Y : 54483.4609375
# epoch : 0, batch per epoch : 232, X : 233, Y : 53920.4375
# epoch : 0, batch per epoch : 233, X : 234, Y : 53773.09375
# epoch : 0, batch per epoch : 234, X : 235, Y : 53292.4375
# epoch : 0, batch per epoch : 235, X : 236, Y : 55132.0390625
# epoch : 0, batch per epoch : 236, X : 237, Y : 54772.80859375
# epoch : 0, batch per epoch : 237, X : 238, Y : 54512.640625
# epoch : 0, batch per epoch : 238, X : 239, Y : 54557.71484375
# epoch : 0, batch per epoch : 239, X : 240, Y : 54627.69921875
# epoch : 0, batch per epoch : 240, X : 241, Y : 53932.43359375
# epoch : 0, batch per epoch : 241, X : 242, Y : 54903.08984375
# epoch : 0, batch per epoch : 242, X : 243, Y : 54157.9453125
# epoch : 0, batch per epoch : 243, X : 244, Y : 54567.53125
# epoch : 0, batch per epoch : 244, X : 245, Y : 55680.8671875
# epoch : 0, batch per epoch : 245, X : 246, Y : 54333.34765625
# epoch : 0, batch per epoch : 246, X : 247, Y : 53618.47265625
# epoch : 0, batch per epoch : 247, X : 248, Y : 55481.5859375
# epoch : 0, batch per epoch : 248, X : 249, Y : 54803.8203125
# epoch : 0, batch per epoch : 249, X : 250, Y : 55017.12890625
# epoch : 0, batch per epoch : 250, X : 251, Y : 55440.69921875
# epoch : 0, batch per epoch : 251, X : 252, Y : 54111.7265625
# epoch : 0, batch per epoch : 252, X : 253, Y : 55221.92578125
# epoch : 0, batch per epoch : 253, X : 254, Y : 54092.78125
# epoch : 0, batch per epoch : 254, X : 255, Y : 54700.5546875
# epoch : 0, batch per epoch : 255, X : 256, Y : 55561.33203125
# epoch : 0, batch per epoch : 256, X : 257, Y : 53987.49609375
# epoch : 0, batch per epoch : 257, X : 258, Y : 53746.828125
# epoch : 0, batch per epoch : 258, X : 259, Y : 55130.0078125
# epoch : 0, batch per epoch : 259, X : 260, Y : 54808.62890625
# epoch : 0, batch per epoch : 260, X : 261, Y : 54173.0625
# epoch : 0, batch per epoch : 261, X : 262, Y : 53774.609375
# epoch : 0, batch per epoch : 262, X : 263, Y : 55182.234375
# epoch : 0, batch per epoch : 263, X : 264, Y : 55140.140625
# epoch : 0, batch per epoch : 264, X : 265, Y : 54970.546875
# epoch : 0, batch per epoch : 265, X : 266, Y : 54312.59375
# epoch : 0, batch per epoch : 266, X : 267, Y : 55494.73828125
# epoch : 0, batch per epoch : 267, X : 268, Y : 54282.40625
# epoch : 0, batch per epoch : 268, X : 269, Y : 54915.74609375
# epoch : 0, batch per epoch : 269, X : 270, Y : 54207.24609375
# epoch : 0, batch per epoch : 270, X : 271, Y : 54575.9921875
# epoch : 0, batch per epoch : 271, X : 272, Y : 54997.0625
# epoch : 0, batch per epoch : 272, X : 273, Y : 54739.6953125
# epoch : 0, batch per epoch : 273, X : 274, Y : 54563.48828125
# epoch : 0, batch per epoch : 274, X : 275, Y : 54323.1484375
# epoch : 0, batch per epoch : 275, X : 276, Y : 55151.56640625
# epoch : 0, batch per epoch : 276, X : 277, Y : 54308.625
# epoch : 0, batch per epoch : 277, X : 278, Y : 54058.84375
# epoch : 0, batch per epoch : 278, X : 279, Y : 54289.234375
# epoch : 0, batch per epoch : 279, X : 280, Y : 54444.078125
# epoch : 0, batch per epoch : 280, X : 281, Y : 54419.96875
# epoch : 0, batch per epoch : 281, X : 282, Y : 53634.640625
# epoch : 0, batch per epoch : 282, X : 283, Y : 54487.3515625
# epoch : 0, batch per epoch : 283, X : 284, Y : 55548.1953125
# epoch : 0, batch per epoch : 284, X : 285, Y : 56022.98046875
# epoch : 0, batch per epoch : 285, X : 286, Y : 54323.3359375
# epoch : 0, batch per epoch : 286, X : 287, Y : 54273.27734375
# epoch : 0, batch per epoch : 287, X : 288, Y : 54768.52734375
# epoch : 0, batch per epoch : 288, X : 289, Y : 54968.7421875
# epoch : 0, batch per epoch : 289, X : 290, Y : 54878.12890625
# epoch : 0, batch per epoch : 290, X : 291, Y : 54241.28515625
# epoch : 0, batch per epoch : 291, X : 292, Y : 54480.703125
# epoch : 0, batch per epoch : 292, X : 293, Y : 55416.9375
# epoch : 0, batch per epoch : 293, X : 294, Y : 54301.30078125
# epoch : 0, batch per epoch : 294, X : 295, Y : 55553.52734375
# epoch : 0, batch per epoch : 295, X : 296, Y : 54521.41796875
# epoch : 0, batch per epoch : 296, X : 297, Y : 54975.828125
# epoch : 0, batch per epoch : 297, X : 298, Y : 54838.48828125
# epoch : 0, batch per epoch : 298, X : 299, Y : 54108.90234375
# epoch : 0, batch per epoch : 299, X : 300, Y : 54521.44140625
# epoch : 0, batch per epoch : 300, X : 301, Y : 53770.62890625
# epoch : 0, batch per epoch : 301, X : 302, Y : 54243.14453125
# epoch : 0, batch per epoch : 302, X : 303, Y : 54464.8671875
# epoch : 0, batch per epoch : 303, X : 304, Y : 54410.54296875
# epoch : 0, batch per epoch : 304, X : 305, Y : 55016.59375
# epoch : 0, batch per epoch : 305, X : 306, Y : 54369.62890625
# epoch : 0, batch per epoch : 306, X : 307, Y : 54279.8359375
# epoch : 0, batch per epoch : 307, X : 308, Y : 54484.91015625
# epoch : 0, batch per epoch : 308, X : 309, Y : 53477.29296875
# epoch : 0, batch per epoch : 309, X : 310, Y : 55104.2578125
# epoch : 0, batch per epoch : 310, X : 311, Y : 54871.234375
# epoch : 0, batch per epoch : 311, X : 312, Y : 54159.0078125
# epoch : 0, batch per epoch : 312, X : 313, Y : 56043.703125
# epoch : 0, batch per epoch : 313, X : 314, Y : 55672.3203125
# epoch : 0, batch per epoch : 314, X : 315, Y : 53747.11328125
# epoch : 0, batch per epoch : 315, X : 316, Y : 54581.19140625
# epoch : 0, batch per epoch : 316, X : 317, Y : 55009.4609375
# epoch : 0, batch per epoch : 317, X : 318, Y : 55076.484375
# epoch : 0, batch per epoch : 318, X : 319, Y : 53494.46875
# epoch : 0, batch per epoch : 319, X : 320, Y : 54376.671875
# epoch : 0, batch per epoch : 320, X : 321, Y : 54516.53125
# epoch : 0, batch per epoch : 321, X : 322, Y : 55921.86328125
# epoch : 0, batch per epoch : 322, X : 323, Y : 54616.640625
# epoch : 0, batch per epoch : 323, X : 324, Y : 54040.97265625
# epoch : 0, batch per epoch : 324, X : 325, Y : 54065.421875
# epoch : 0, batch per epoch : 325, X : 326, Y : 54366.4921875
# epoch : 0, batch per epoch : 326, X : 327, Y : 54433.921875
# epoch : 0, batch per epoch : 327, X : 328, Y : 55203.0390625
# epoch : 0, batch per epoch : 328, X : 329, Y : 53469.71484375
# epoch : 0, batch per epoch : 329, X : 330, Y : 54697.84765625
# epoch : 0, batch per epoch : 330, X : 331, Y : 54997.98828125
# epoch : 0, batch per epoch : 331, X : 332, Y : 55193.1171875
# epoch : 0, batch per epoch : 332, X : 333, Y : 53838.25390625
# epoch : 0, batch per epoch : 333, X : 334, Y : 55343.453125
# epoch : 0, batch per epoch : 334, X : 335, Y : 56010.3671875
# epoch : 0, batch per epoch : 335, X : 336, Y : 55882.49609375
# epoch : 0, batch per epoch : 336, X : 337, Y : 55893.765625
# epoch : 0, batch per epoch : 337, X : 338, Y : 54190.8359375
# epoch : 0, batch per epoch : 338, X : 339, Y : 54695.453125
# epoch : 0, batch per epoch : 339, X : 340, Y : 53689.86328125
# epoch : 0, batch per epoch : 340, X : 341, Y : 54879.8671875
# epoch : 0, batch per epoch : 341, X : 342, Y : 54464.68359375
# epoch : 0, batch per epoch : 342, X : 343, Y : 55138.2734375
# epoch : 0, batch per epoch : 343, X : 344, Y : 54910.92578125
# epoch : 0, batch per epoch : 344, X : 345, Y : 52891.9765625
# epoch : 0, batch per epoch : 345, X : 346, Y : 54684.31640625
# epoch : 0, batch per epoch : 346, X : 347, Y : 53851.0390625
# epoch : 0, batch per epoch : 347, X : 348, Y : 54861.015625
# epoch : 0, batch per epoch : 348, X : 349, Y : 54332.02734375
# epoch : 0, batch per epoch : 349, X : 350, Y : 55328.9765625
# epoch : 0, batch per epoch : 350, X : 351, Y : 53819.31640625
# epoch : 0, batch per epoch : 351, X : 352, Y : 55011.3515625
# epoch : 0, batch per epoch : 352, X : 353, Y : 54663.2578125
# epoch : 0, batch per epoch : 353, X : 354, Y : 55185.359375
# epoch : 0, batch per epoch : 354, X : 355, Y : 53114.484375
# epoch : 0, batch per epoch : 355, X : 356, Y : 55257.3125
# epoch : 0, batch per epoch : 356, X : 357, Y : 55307.4921875
# epoch : 0, batch per epoch : 357, X : 358, Y : 55286.56640625
# epoch : 0, batch per epoch : 358, X : 359, Y : 55377.87109375
# epoch : 0, batch per epoch : 359, X : 360, Y : 53718.12890625
# epoch : 0, batch per epoch : 360, X : 361, Y : 55032.23046875
# epoch : 0, batch per epoch : 361, X : 362, Y : 54435.15234375
# epoch : 0, batch per epoch : 362, X : 363, Y : 55312.91015625
# epoch : 0, batch per epoch : 363, X : 364, Y : 54888.625
# epoch : 0, batch per epoch : 364, X : 365, Y : 54510.2265625
# epoch : 0, batch per epoch : 365, X : 366, Y : 54067.7421875
# epoch : 0, batch per epoch : 366, X : 367, Y : 55058.03515625
# epoch : 0, batch per epoch : 367, X : 368, Y : 54761.7421875
# epoch : 0, batch per epoch : 368, X : 369, Y : 55609.96484375
# epoch : 0, batch per epoch : 369, X : 370, Y : 54204.84375
# epoch : 0, batch per epoch : 370, X : 371, Y : 54653.80078125
# epoch : 0, batch per epoch : 371, X : 372, Y : 55602.55859375
# epoch : 0, batch per epoch : 372, X : 373, Y : 55036.703125
# epoch : 0, batch per epoch : 373, X : 374, Y : 54432.65234375
# epoch : 0, batch per epoch : 374, X : 375, Y : 54108.6640625
# epoch : 0, batch per epoch : 375, X : 376, Y : 54562.30078125
# epoch : 0, batch per epoch : 376, X : 377, Y : 54846.6640625
# epoch : 0, batch per epoch : 377, X : 378, Y : 55171.546875
# epoch : 0, batch per epoch : 378, X : 379, Y : 55631.5859375
# epoch : 0, batch per epoch : 379, X : 380, Y : 54496.47265625
# epoch : 0, batch per epoch : 380, X : 381, Y : 54827.34375
# epoch : 0, batch per epoch : 381, X : 382, Y : 54334.78515625
# epoch : 0, batch per epoch : 382, X : 383, Y : 56009.3984375
# epoch : 0, batch per epoch : 383, X : 384, Y : 54964.21875
# epoch : 0, batch per epoch : 384, X : 385, Y : 54613.71875
# epoch : 0, batch per epoch : 385, X : 386, Y : 55710.28125
# epoch : 0, batch per epoch : 386, X : 387, Y : 54789.53515625
# epoch : 0, batch per epoch : 387, X : 388, Y : 55382.19921875
# epoch : 0, batch per epoch : 388, X : 389, Y : 55070.4453125
# epoch : 0, batch per epoch : 389, X : 390, Y : 55249.48828125
# epoch : 0, batch per epoch : 390, X : 391, Y : 53815.36328125
# epoch : 0, batch per epoch : 391, X : 392, Y : 54632.921875
# epoch : 0, batch per epoch : 392, X : 393, Y : 54648.59375
# epoch : 0, batch per epoch : 393, X : 394, Y : 54580.3828125
# epoch : 0, batch per epoch : 394, X : 395, Y : 54349.3828125
# epoch : 0, batch per epoch : 395, X : 396, Y : 55299.43359375
# epoch : 0, batch per epoch : 396, X : 397, Y : 55066.23828125
# epoch : 0, batch per epoch : 397, X : 398, Y : 53835.32421875
# epoch : 0, batch per epoch : 398, X : 399, Y : 54618.0078125
# epoch : 0, batch per epoch : 399, X : 400, Y : 53193.4140625
# epoch : 0, batch per epoch : 400, X : 401, Y : 54699.4765625
# epoch : 0, batch per epoch : 401, X : 402, Y : 54395.99609375
# epoch : 0, batch per epoch : 402, X : 403, Y : 54692.171875
# epoch : 0, batch per epoch : 403, X : 404, Y : 55329.91796875
# epoch : 0, batch per epoch : 404, X : 405, Y : 55250.4921875
# epoch : 0, batch per epoch : 405, X : 406, Y : 54458.3046875
# epoch : 0, batch per epoch : 406, X : 407, Y : 54362.08203125
# epoch : 0, batch per epoch : 407, X : 408, Y : 55483.0390625
# epoch : 0, batch per epoch : 408, X : 409, Y : 54643.52734375
# epoch : 0, batch per epoch : 409, X : 410, Y : 55077.53125
# epoch : 0, batch per epoch : 410, X : 411, Y : 54825.140625
# epoch : 0, batch per epoch : 411, X : 412, Y : 54319.47265625
# epoch : 0, batch per epoch : 412, X : 413, Y : 54342.51171875
# epoch : 0, batch per epoch : 413, X : 414, Y : 54676.28515625
# epoch : 0, batch per epoch : 414, X : 415, Y : 54702.2578125
# epoch : 0, batch per epoch : 415, X : 416, Y : 55296.984375
# epoch : 0, batch per epoch : 416, X : 417, Y : 54590.765625
# epoch : 0, batch per epoch : 417, X : 418, Y : 54906.2734375
# epoch : 0, batch per epoch : 418, X : 419, Y : 55172.9921875
# epoch : 0, batch per epoch : 419, X : 420, Y : 54746.4375
# epoch : 0, batch per epoch : 420, X : 421, Y : 55120.1953125
# epoch : 0, batch per epoch : 421, X : 422, Y : 54338.78125
# epoch : 0, batch per epoch : 422, X : 423, Y : 54477.50390625
# epoch : 0, batch per epoch : 423, X : 424, Y : 55736.78125
# epoch : 0, batch per epoch : 424, X : 425, Y : 53909.6015625
# epoch : 0, batch per epoch : 425, X : 426, Y : 55186.88671875
# epoch : 0, batch per epoch : 426, X : 427, Y : 55049.51953125
# epoch : 0, batch per epoch : 427, X : 428, Y : 54942.6015625
# epoch : 0, batch per epoch : 428, X : 429, Y : 55036.515625
# epoch : 0, batch per epoch : 429, X : 430, Y : 54721.05859375
# epoch : 0, batch per epoch : 430, X : 431, Y : 53841.94921875
# epoch : 0, batch per epoch : 431, X : 432, Y : 55892.5390625
# epoch : 0, batch per epoch : 432, X : 433, Y : 54949.5234375
# epoch : 0, batch per epoch : 433, X : 434, Y : 54551.4140625
# epoch : 0, batch per epoch : 434, X : 435, Y : 54096.6484375
# epoch : 0, batch per epoch : 435, X : 436, Y : 55116.73828125
# epoch : 0, batch per epoch : 436, X : 437, Y : 54911.375
# epoch : 0, batch per epoch : 437, X : 438, Y : 55269.51953125
# epoch : 0, batch per epoch : 438, X : 439, Y : 54933.8046875
# epoch : 0, batch per epoch : 439, X : 440, Y : 54652.3515625
# epoch : 0, batch per epoch : 440, X : 441, Y : 54651.50390625
# epoch : 0, batch per epoch : 441, X : 442, Y : 54250.37109375
# epoch : 0, batch per epoch : 442, X : 443, Y : 55579.671875
# epoch : 0, batch per epoch : 443, X : 444, Y : 55461.30078125
# epoch : 0, batch per epoch : 444, X : 445, Y : 53777.59765625
# epoch : 0, batch per epoch : 445, X : 446, Y : 54814.1640625
# epoch : 0, batch per epoch : 446, X : 447, Y : 54716.859375
# epoch : 0, batch per epoch : 447, X : 448, Y : 56159.63671875
# epoch : 0, batch per epoch : 448, X : 449, Y : 54151.9765625
# epoch : 0, batch per epoch : 449, X : 450, Y : 55756.5234375
# epoch : 0, batch per epoch : 450, X : 451, Y : 55352.25
# epoch : 0, batch per epoch : 451, X : 452, Y : 55952.64453125
# epoch : 0, batch per epoch : 452, X : 453, Y : 53821.98046875
# epoch : 0, batch per epoch : 453, X : 454, Y : 54593.0390625
# epoch : 0, batch per epoch : 454, X : 455, Y : 54649.125
# epoch : 0, batch per epoch : 455, X : 456, Y : 54072.2578125
# epoch : 0, batch per epoch : 456, X : 457, Y : 54860.07421875
# epoch : 0, batch per epoch : 457, X : 458, Y : 54721.421875
# epoch : 0, batch per epoch : 458, X : 459, Y : 55633.6640625
# epoch : 0, batch per epoch : 459, X : 460, Y : 54718.36328125
# epoch : 0, batch per epoch : 460, X : 461, Y : 54153.2734375
# epoch : 0, batch per epoch : 461, X : 462, Y : 54745.83984375
# epoch : 0, batch per epoch : 462, X : 463, Y : 55402.02734375
# epoch : 0, batch per epoch : 463, X : 464, Y : 54102.6015625
# epoch : 0, batch per epoch : 464, X : 465, Y : 54304.15625
# epoch : 0, batch per epoch : 465, X : 466, Y : 55536.171875
# epoch : 0, batch per epoch : 466, X : 467, Y : 55318.4609375
# epoch : 0, batch per epoch : 467, X : 468, Y : 54672.41015625
# epoch : 0, batch per epoch : 468, X : 469, Y : 55115.54296875
# epoch : 0, batch per epoch : 469, X : 470, Y : 56222.20703125
# epoch : 0, batch per epoch : 470, X : 471, Y : 54359.125
# epoch : 0, batch per epoch : 471, X : 472, Y : 54213.8515625
# epoch : 0, batch per epoch : 472, X : 473, Y : 54471.3984375
# epoch : 0, batch per epoch : 473, X : 474, Y : 54909.609375
# epoch : 0, batch per epoch : 474, X : 475, Y : 54821.03515625
# epoch : 0, batch per epoch : 475, X : 476, Y : 55293.296875
# epoch : 0, batch per epoch : 476, X : 477, Y : 54123.421875
# epoch : 0, batch per epoch : 477, X : 478, Y : 55066.66015625
# epoch : 0, batch per epoch : 478, X : 479, Y : 55833.1328125
# epoch : 0, batch per epoch : 479, X : 480, Y : 53679.0546875
# epoch : 0, batch per epoch : 480, X : 481, Y : 54501.47265625
# epoch : 0, batch per epoch : 481, X : 482, Y : 54880.5234375
# epoch : 0, batch per epoch : 482, X : 483, Y : 55047.6796875
# epoch : 0, batch per epoch : 483, X : 484, Y : 55254.42578125
# epoch : 0, batch per epoch : 484, X : 485, Y : 55316.81640625
# epoch : 0, batch per epoch : 485, X : 486, Y : 54967.6328125
# epoch : 0, batch per epoch : 486, X : 487, Y : 53805.90234375
# epoch : 0, batch per epoch : 487, X : 488, Y : 55180.55859375
# epoch : 0, batch per epoch : 488, X : 489, Y : 54995.8046875
# epoch : 0, batch per epoch : 489, X : 490, Y : 55388.30078125
# epoch : 0, batch per epoch : 490, X : 491, Y : 53906.3671875
# epoch : 0, batch per epoch : 491, X : 492, Y : 54863.41796875
# epoch : 0, batch per epoch : 492, X : 493, Y : 55132.3515625
# epoch : 0, batch per epoch : 493, X : 494, Y : 53854.5546875
# epoch : 0, batch per epoch : 494, X : 495, Y : 54339.796875
# epoch : 0, batch per epoch : 495, X : 496, Y : 54751.72265625
# epoch : 0, batch per epoch : 496, X : 497, Y : 53381.265625
# epoch : 0, batch per epoch : 497, X : 498, Y : 53382.171875
# epoch : 0, batch per epoch : 498, X : 499, Y : 54653.92578125
# epoch : 0, batch per epoch : 499, X : 500, Y : 55572.015625
# epoch : 0, batch per epoch : 500, X : 501, Y : 54672.2890625
# epoch : 0, batch per epoch : 501, X : 502, Y : 54219.2890625
# epoch : 0, batch per epoch : 502, X : 503, Y : 54653.3203125
# epoch : 0, batch per epoch : 503, X : 504, Y : 53844.45703125
# epoch : 0, batch per epoch : 504, X : 505, Y : 56140.5546875
# epoch : 0, batch per epoch : 505, X : 506, Y : 54082.33984375
# epoch : 0, batch per epoch : 506, X : 507, Y : 54892.796875
# epoch : 0, batch per epoch : 507, X : 508, Y : 54113.56640625
# epoch : 0, batch per epoch : 508, X : 509, Y : 53472.8203125
# epoch : 0, batch per epoch : 509, X : 510, Y : 54221.8125
# epoch : 0, batch per epoch : 510, X : 511, Y : 55636.11328125
# epoch : 0, batch per epoch : 511, X : 512, Y : 54903.046875
# epoch : 0, batch per epoch : 512, X : 513, Y : 54642.1171875
# epoch : 0, batch per epoch : 513, X : 514, Y : 53721.515625
# epoch : 0, batch per epoch : 514, X : 515, Y : 54058.171875
# epoch : 0, batch per epoch : 515, X : 516, Y : 54446.8203125
# epoch : 0, batch per epoch : 516, X : 517, Y : 54531.890625
# epoch : 0, batch per epoch : 517, X : 518, Y : 54917.484375
# epoch : 0, batch per epoch : 518, X : 519, Y : 54115.55078125
# epoch : 0, batch per epoch : 519, X : 520, Y : 54335.81640625
# epoch : 0, batch per epoch : 520, X : 521, Y : 54332.734375
# epoch : 0, batch per epoch : 521, X : 522, Y : 54906.40234375
# epoch : 0, batch per epoch : 522, X : 523, Y : 53929.89453125
# epoch : 0, batch per epoch : 523, X : 524, Y : 54765.3515625
# epoch : 0, batch per epoch : 524, X : 525, Y : 54753.27734375
# epoch : 0, batch per epoch : 525, X : 526, Y : 54215.9296875
# epoch : 0, batch per epoch : 526, X : 527, Y : 54531.06640625
# epoch : 0, batch per epoch : 527, X : 528, Y : 54030.8671875
# epoch : 0, batch per epoch : 528, X : 529, Y : 54680.390625
# epoch : 0, batch per epoch : 529, X : 530, Y : 54008.5625
# epoch : 0, batch per epoch : 530, X : 531, Y : 53970.90234375
# epoch : 0, batch per epoch : 531, X : 532, Y : 55347.375
# epoch : 0, batch per epoch : 532, X : 533, Y : 54213.171875
# epoch : 0, batch per epoch : 533, X : 534, Y : 56148.7734375
# epoch : 0, batch per epoch : 534, X : 535, Y : 55028.49609375
# epoch : 0, batch per epoch : 535, X : 536, Y : 54739.640625
# epoch : 0, batch per epoch : 536, X : 537, Y : 54104.41796875
# epoch : 0, batch per epoch : 537, X : 538, Y : 54158.49609375
# epoch : 0, batch per epoch : 538, X : 539, Y : 54863.2578125
# epoch : 0, batch per epoch : 539, X : 540, Y : 54959.13671875
# epoch : 0, batch per epoch : 540, X : 541, Y : 55093.13671875
# epoch : 0, batch per epoch : 541, X : 542, Y : 54698.7890625
# epoch : 0, batch per epoch : 542, X : 543, Y : 54627.47265625
# epoch : 0, batch per epoch : 543, X : 544, Y : 53905.43359375
# epoch : 0, batch per epoch : 544, X : 545, Y : 54803.796875
# epoch : 0, batch per epoch : 545, X : 546, Y : 55657.3359375
# epoch : 0, batch per epoch : 546, X : 547, Y : 54787.234375
# epoch : 0, batch per epoch : 547, X : 548, Y : 55678.54296875
# epoch : 0, batch per epoch : 548, X : 549, Y : 54648.95703125
# epoch : 0, batch per epoch : 549, X : 550, Y : 54128.9921875
# epoch : 0, batch per epoch : 550, X : 551, Y : 56799.56640625
# epoch : 0, batch per epoch : 551, X : 552, Y : 54749.21875
# epoch : 0, batch per epoch : 552, X : 553, Y : 55047.6171875
# epoch : 0, batch per epoch : 553, X : 554, Y : 54218.70703125
# epoch : 0, batch per epoch : 554, X : 555, Y : 54288.66796875
# epoch : 0, batch per epoch : 555, X : 556, Y : 54043.765625
# epoch : 0, batch per epoch : 556, X : 557, Y : 54606.6875
# epoch : 0, batch per epoch : 557, X : 558, Y : 54441.53125
# epoch : 0, batch per epoch : 558, X : 559, Y : 54881.69921875
# epoch : 0, batch per epoch : 559, X : 560, Y : 54411.3359375
# epoch : 0, batch per epoch : 560, X : 561, Y : 54672.234375
# epoch : 0, batch per epoch : 561, X : 562, Y : 54604.73828125
# epoch : 0, batch per epoch : 562, X : 563, Y : 55014.6796875
# epoch : 0, batch per epoch : 563, X : 564, Y : 54982.9921875
# epoch : 0, batch per epoch : 564, X : 565, Y : 54538.05078125
# epoch : 0, batch per epoch : 565, X : 566, Y : 54711.234375
# epoch : 0, batch per epoch : 566, X : 567, Y : 54314.1484375
# epoch : 0, batch per epoch : 567, X : 568, Y : 54418.41796875
# epoch : 0, batch per epoch : 568, X : 569, Y : 55240.9453125
# epoch : 0, batch per epoch : 569, X : 570, Y : 55443.7265625
# epoch : 0, batch per epoch : 570, X : 571, Y : 54855.2421875
# epoch : 0, batch per epoch : 571, X : 572, Y : 55269.53125
# epoch : 0, batch per epoch : 572, X : 573, Y : 54633.515625
# epoch : 0, batch per epoch : 573, X : 574, Y : 56300.1015625
# epoch : 0, batch per epoch : 574, X : 575, Y : 54301.984375
# epoch : 0, batch per epoch : 575, X : 576, Y : 54185.65234375
# epoch : 0, batch per epoch : 576, X : 577, Y : 54951.6015625
# epoch : 0, batch per epoch : 577, X : 578, Y : 53819.77734375
# epoch : 0, batch per epoch : 578, X : 579, Y : 53228.84375
# epoch : 0, batch per epoch : 579, X : 580, Y : 54709.8046875
# epoch : 0, batch per epoch : 580, X : 581, Y : 54299.109375
# epoch : 0, batch per epoch : 581, X : 582, Y : 54815.79296875
# epoch : 0, batch per epoch : 582, X : 583, Y : 54424.1875
# epoch : 0, batch per epoch : 583, X : 584, Y : 54434.99609375
# epoch : 0, batch per epoch : 584, X : 585, Y : 54245.97265625
# epoch : 0, batch per epoch : 585, X : 586, Y : 54298.734375
# epoch : 0, batch per epoch : 586, X : 587, Y : 55351.4765625
# epoch : 0, batch per epoch : 587, X : 588, Y : 53893.6796875
# epoch : 0, batch per epoch : 588, X : 589, Y : 54346.52734375
# epoch : 0, batch per epoch : 589, X : 590, Y : 54603.7734375
# epoch : 0, batch per epoch : 590, X : 591, Y : 54937.67578125
# epoch : 0, batch per epoch : 591, X : 592, Y : 54571.28515625
# epoch : 0, batch per epoch : 592, X : 593, Y : 55443.40234375
# epoch : 0, batch per epoch : 593, X : 594, Y : 55426.46875
# epoch : 0, batch per epoch : 594, X : 595, Y : 54851.84375
# epoch : 0, batch per epoch : 595, X : 596, Y : 54945.8671875
# epoch : 0, batch per epoch : 596, X : 597, Y : 53651.03125
# epoch : 0, batch per epoch : 597, X : 598, Y : 55027.25390625
# epoch : 0, batch per epoch : 598, X : 599, Y : 55563.6328125
# epoch : 0, batch per epoch : 599, X : 600, Y : 54748.4296875
# epoch : 1, batch per epoch : 0, X : 601, Y : 53639.1328125
# epoch : 1, batch per epoch : 1, X : 602, Y : 54751.94921875
# epoch : 1, batch per epoch : 2, X : 603, Y : 54621.16015625
# epoch : 1, batch per epoch : 3, X : 604, Y : 54108.828125
# epoch : 1, batch per epoch : 4, X : 605, Y : 54835.875
# epoch : 1, batch per epoch : 5, X : 606, Y : 54251.25390625
# epoch : 1, batch per epoch : 6, X : 607, Y : 54803.39453125
# epoch : 1, batch per epoch : 7, X : 608, Y : 55171.75390625
# epoch : 1, batch per epoch : 8, X : 609, Y : 55460.99609375
# epoch : 1, batch per epoch : 9, X : 610, Y : 54622.3125
# epoch : 1, batch per epoch : 10, X : 611, Y : 55127.05859375
# epoch : 1, batch per epoch : 11, X : 612, Y : 54593.09375
# epoch : 1, batch per epoch : 12, X : 613, Y : 53929.60546875
# epoch : 1, batch per epoch : 13, X : 614, Y : 55367.54296875
# epoch : 1, batch per epoch : 14, X : 615, Y : 54404.8828125
# epoch : 1, batch per epoch : 15, X : 616, Y : 53730.6015625
# epoch : 1, batch per epoch : 16, X : 617, Y : 53251.76171875
# epoch : 1, batch per epoch : 17, X : 618, Y : 55145.25
# epoch : 1, batch per epoch : 18, X : 619, Y : 54919.67578125
# epoch : 1, batch per epoch : 19, X : 620, Y : 54974.8984375
# epoch : 1, batch per epoch : 20, X : 621, Y : 54950.3671875
# epoch : 1, batch per epoch : 21, X : 622, Y : 53549.578125
# epoch : 1, batch per epoch : 22, X : 623, Y : 54129.46875
# epoch : 1, batch per epoch : 23, X : 624, Y : 54246.1953125
# epoch : 1, batch per epoch : 24, X : 625, Y : 54814.8125
# epoch : 1, batch per epoch : 25, X : 626, Y : 54672.0390625
# epoch : 1, batch per epoch : 26, X : 627, Y : 55068.63671875
# epoch : 1, batch per epoch : 27, X : 628, Y : 55374.8125
# epoch : 1, batch per epoch : 28, X : 629, Y : 54277.25390625
# epoch : 1, batch per epoch : 29, X : 630, Y : 54530.85546875
# epoch : 1, batch per epoch : 30, X : 631, Y : 54608.04296875
# epoch : 1, batch per epoch : 31, X : 632, Y : 54619.5703125
# epoch : 1, batch per epoch : 32, X : 633, Y : 55423.34375
# epoch : 1, batch per epoch : 33, X : 634, Y : 55510.13671875
# epoch : 1, batch per epoch : 34, X : 635, Y : 55587.57421875
# epoch : 1, batch per epoch : 35, X : 636, Y : 54720.8984375
# epoch : 1, batch per epoch : 36, X : 637, Y : 54387.71484375
# epoch : 1, batch per epoch : 37, X : 638, Y : 55261.08203125
# epoch : 1, batch per epoch : 38, X : 639, Y : 55417.54296875
# epoch : 1, batch per epoch : 39, X : 640, Y : 54639.09765625
# epoch : 1, batch per epoch : 40, X : 641, Y : 55192.65625
# epoch : 1, batch per epoch : 41, X : 642, Y : 55248.8359375
# epoch : 1, batch per epoch : 42, X : 643, Y : 53427.06640625
# epoch : 1, batch per epoch : 43, X : 644, Y : 55025.5625
# epoch : 1, batch per epoch : 44, X : 645, Y : 54126.21484375
# epoch : 1, batch per epoch : 45, X : 646, Y : 55382.3203125
# epoch : 1, batch per epoch : 46, X : 647, Y : 55108.609375
# epoch : 1, batch per epoch : 47, X : 648, Y : 54659.48046875
# epoch : 1, batch per epoch : 48, X : 649, Y : 54555.8203125
# epoch : 1, batch per epoch : 49, X : 650, Y : 54904.91796875
# epoch : 1, batch per epoch : 50, X : 651, Y : 54085.30078125
# epoch : 1, batch per epoch : 51, X : 652, Y : 54558.0859375
# epoch : 1, batch per epoch : 52, X : 653, Y : 54144.6328125
# epoch : 1, batch per epoch : 53, X : 654, Y : 53749.05859375
# epoch : 1, batch per epoch : 54, X : 655, Y : 53995.21875
# epoch : 1, batch per epoch : 55, X : 656, Y : 53107.37890625
# epoch : 1, batch per epoch : 56, X : 657, Y : 54306.1953125
# epoch : 1, batch per epoch : 57, X : 658, Y : 54076.3046875
# epoch : 1, batch per epoch : 58, X : 659, Y : 54506.05078125
# epoch : 1, batch per epoch : 59, X : 660, Y : 55220.02734375
# epoch : 1, batch per epoch : 60, X : 661, Y : 55156.47265625
# epoch : 1, batch per epoch : 61, X : 662, Y : 54786.58203125
# epoch : 1, batch per epoch : 62, X : 663, Y : 54001.3203125
# epoch : 1, batch per epoch : 63, X : 664, Y : 55701.63671875
# epoch : 1, batch per epoch : 64, X : 665, Y : 54633.96875
# epoch : 1, batch per epoch : 65, X : 666, Y : 54409.95703125
# epoch : 1, batch per epoch : 66, X : 667, Y : 55796.234375
# epoch : 1, batch per epoch : 67, X : 668, Y : 54341.30078125
# epoch : 1, batch per epoch : 68, X : 669, Y : 54394.40234375
# epoch : 1, batch per epoch : 69, X : 670, Y : 55411.6015625
# epoch : 1, batch per epoch : 70, X : 671, Y : 55834.4375
# epoch : 1, batch per epoch : 71, X : 672, Y : 54385.9765625
# epoch : 1, batch per epoch : 72, X : 673, Y : 53092.203125
# epoch : 1, batch per epoch : 73, X : 674, Y : 54720.41796875
# epoch : 1, batch per epoch : 74, X : 675, Y : 54371.52734375
# epoch : 1, batch per epoch : 75, X : 676, Y : 55143.34765625
# epoch : 1, batch per epoch : 76, X : 677, Y : 55623.203125
# epoch : 1, batch per epoch : 77, X : 678, Y : 56294.6953125
# epoch : 1, batch per epoch : 78, X : 679, Y : 55324.671875
# epoch : 1, batch per epoch : 79, X : 680, Y : 54887.11328125
# epoch : 1, batch per epoch : 80, X : 681, Y : 54659.5546875
# epoch : 1, batch per epoch : 81, X : 682, Y : 54553.140625
# epoch : 1, batch per epoch : 82, X : 683, Y : 55948.6328125
# epoch : 1, batch per epoch : 83, X : 684, Y : 54356.8359375
# epoch : 1, batch per epoch : 84, X : 685, Y : 54547.84765625
# epoch : 1, batch per epoch : 85, X : 686, Y : 54642.109375
# epoch : 1, batch per epoch : 86, X : 687, Y : 54433.8359375
# epoch : 1, batch per epoch : 87, X : 688, Y : 54238.25390625
# epoch : 1, batch per epoch : 88, X : 689, Y : 54637.53515625
# epoch : 1, batch per epoch : 89, X : 690, Y : 54412.5390625
# epoch : 1, batch per epoch : 90, X : 691, Y : 55048.57421875
# epoch : 1, batch per epoch : 91, X : 692, Y : 53307.96875
# epoch : 1, batch per epoch : 92, X : 693, Y : 56082.5
# epoch : 1, batch per epoch : 93, X : 694, Y : 52833.03125
# epoch : 1, batch per epoch : 94, X : 695, Y : 53522.89453125
# epoch : 1, batch per epoch : 95, X : 696, Y : 54975.75
# epoch : 1, batch per epoch : 96, X : 697, Y : 55391.87109375
# epoch : 1, batch per epoch : 97, X : 698, Y : 54282.90234375
# epoch : 1, batch per epoch : 98, X : 699, Y : 55400.4921875
# epoch : 1, batch per epoch : 99, X : 700, Y : 54168.92578125
# epoch : 1, batch per epoch : 100, X : 701, Y : 54294.18359375
# epoch : 1, batch per epoch : 101, X : 702, Y : 53857.7734375
# epoch : 1, batch per epoch : 102, X : 703, Y : 54522.62890625
# epoch : 1, batch per epoch : 103, X : 704, Y : 54818.609375
# epoch : 1, batch per epoch : 104, X : 705, Y : 54035.828125
# epoch : 1, batch per epoch : 105, X : 706, Y : 53837.30078125
# epoch : 1, batch per epoch : 106, X : 707, Y : 55378.57421875
# epoch : 1, batch per epoch : 107, X : 708, Y : 54185.48828125
# epoch : 1, batch per epoch : 108, X : 709, Y : 54743.484375
# epoch : 1, batch per epoch : 109, X : 710, Y : 54807.984375
# epoch : 1, batch per epoch : 110, X : 711, Y : 54274.39453125
# epoch : 1, batch per epoch : 111, X : 712, Y : 54920.1171875
# epoch : 1, batch per epoch : 112, X : 713, Y : 55355.53515625
# epoch : 1, batch per epoch : 113, X : 714, Y : 53369.5078125
# epoch : 1, batch per epoch : 114, X : 715, Y : 54945.87109375
# epoch : 1, batch per epoch : 115, X : 716, Y : 55257.20703125
# epoch : 1, batch per epoch : 116, X : 717, Y : 54967.62109375
# epoch : 1, batch per epoch : 117, X : 718, Y : 55141.609375
# epoch : 1, batch per epoch : 118, X : 719, Y : 53613.28515625
# epoch : 1, batch per epoch : 119, X : 720, Y : 54455.46875
# epoch : 1, batch per epoch : 120, X : 721, Y : 54164.421875
# epoch : 1, batch per epoch : 121, X : 722, Y : 54739.6171875
# epoch : 1, batch per epoch : 122, X : 723, Y : 54260.703125
# epoch : 1, batch per epoch : 123, X : 724, Y : 54111.0234375
# epoch : 1, batch per epoch : 124, X : 725, Y : 55361.25
# epoch : 1, batch per epoch : 125, X : 726, Y : 56270.171875
# epoch : 1, batch per epoch : 126, X : 727, Y : 56091.7265625
# epoch : 1, batch per epoch : 127, X : 728, Y : 54422.421875
# epoch : 1, batch per epoch : 128, X : 729, Y : 54908.875
# epoch : 1, batch per epoch : 129, X : 730, Y : 55004.62890625
# epoch : 1, batch per epoch : 130, X : 731, Y : 54652.4453125
# epoch : 1, batch per epoch : 131, X : 732, Y : 54726.8828125
# epoch : 1, batch per epoch : 132, X : 733, Y : 54131.72265625
# epoch : 1, batch per epoch : 133, X : 734, Y : 55448.26953125
# epoch : 1, batch per epoch : 134, X : 735, Y : 55842.8984375
# epoch : 1, batch per epoch : 135, X : 736, Y : 55063.4453125
# epoch : 1, batch per epoch : 136, X : 737, Y : 53996.0625
# epoch : 1, batch per epoch : 137, X : 738, Y : 54853.14453125
# epoch : 1, batch per epoch : 138, X : 739, Y : 54985.890625
# epoch : 1, batch per epoch : 139, X : 740, Y : 54440.1015625
# epoch : 1, batch per epoch : 140, X : 741, Y : 55182.5078125
# epoch : 1, batch per epoch : 141, X : 742, Y : 55324.1875
# epoch : 1, batch per epoch : 142, X : 743, Y : 55249.4453125
# epoch : 1, batch per epoch : 143, X : 744, Y : 53710.14453125
# epoch : 1, batch per epoch : 144, X : 745, Y : 53852.046875
# epoch : 1, batch per epoch : 145, X : 746, Y : 55381.9453125
# epoch : 1, batch per epoch : 146, X : 747, Y : 55142.2109375
# epoch : 1, batch per epoch : 147, X : 748, Y : 54775.29296875
# epoch : 1, batch per epoch : 148, X : 749, Y : 55107.69140625
# epoch : 1, batch per epoch : 149, X : 750, Y : 54919.69140625
# epoch : 1, batch per epoch : 150, X : 751, Y : 54390.01953125
# epoch : 1, batch per epoch : 151, X : 752, Y : 54746.93359375
# epoch : 1, batch per epoch : 152, X : 753, Y : 54822.40625
# epoch : 1, batch per epoch : 153, X : 754, Y : 54499.0703125
# epoch : 1, batch per epoch : 154, X : 755, Y : 54572.7734375
# epoch : 1, batch per epoch : 155, X : 756, Y : 54051.36328125
# epoch : 1, batch per epoch : 156, X : 757, Y : 55076.8359375
# epoch : 1, batch per epoch : 157, X : 758, Y : 54671.4609375
# epoch : 1, batch per epoch : 158, X : 759, Y : 53591.2265625
# epoch : 1, batch per epoch : 159, X : 760, Y : 54908.32421875
# epoch : 1, batch per epoch : 160, X : 761, Y : 54365.9609375
# epoch : 1, batch per epoch : 161, X : 762, Y : 54333.640625
# epoch : 1, batch per epoch : 162, X : 763, Y : 55246.6015625
# epoch : 1, batch per epoch : 163, X : 764, Y : 55361.7265625
# epoch : 1, batch per epoch : 164, X : 765, Y : 55533.20703125
# epoch : 1, batch per epoch : 165, X : 766, Y : 53950.30078125
# epoch : 1, batch per epoch : 166, X : 767, Y : 55371.9609375
# epoch : 1, batch per epoch : 167, X : 768, Y : 54877.3359375
# epoch : 1, batch per epoch : 168, X : 769, Y : 54369.8515625
# epoch : 1, batch per epoch : 169, X : 770, Y : 54796.265625
# epoch : 1, batch per epoch : 170, X : 771, Y : 54527.515625
# epoch : 1, batch per epoch : 171, X : 772, Y : 54751.41015625
# epoch : 1, batch per epoch : 172, X : 773, Y : 55219.18359375
# epoch : 1, batch per epoch : 173, X : 774, Y : 54308.76171875
# epoch : 1, batch per epoch : 174, X : 775, Y : 55321.71875
# epoch : 1, batch per epoch : 175, X : 776, Y : 53510.83203125
# epoch : 1, batch per epoch : 176, X : 777, Y : 54126.75390625
# epoch : 1, batch per epoch : 177, X : 778, Y : 54708.5625
# epoch : 1, batch per epoch : 178, X : 779, Y : 55343.53515625
# epoch : 1, batch per epoch : 179, X : 780, Y : 54935.08203125
# ...
# epoch : 9, batch per epoch : 342, X : 5743, Y : 53777.53125
# epoch : 9, batch per epoch : 343, X : 5744, Y : 53985.16796875
# epoch : 9, batch per epoch : 344, X : 5745, Y : 54382.84765625
# epoch : 9, batch per epoch : 345, X : 5746, Y : 54846.3046875
# epoch : 9, batch per epoch : 346, X : 5747, Y : 54715.52734375
# epoch : 9, batch per epoch : 347, X : 5748, Y : 53983.21875
# epoch : 9, batch per epoch : 348, X : 5749, Y : 54474.88671875
# epoch : 9, batch per epoch : 349, X : 5750, Y : 54995.1484375
# epoch : 9, batch per epoch : 350, X : 5751, Y : 54321.359375
# epoch : 9, batch per epoch : 351, X : 5752, Y : 54490.01171875
# epoch : 9, batch per epoch : 352, X : 5753, Y : 55875.078125
# epoch : 9, batch per epoch : 353, X : 5754, Y : 55470.171875
# epoch : 9, batch per epoch : 354, X : 5755, Y : 54300.66796875
# epoch : 9, batch per epoch : 355, X : 5756, Y : 53899.8125
# epoch : 9, batch per epoch : 356, X : 5757, Y : 53596.1015625
# epoch : 9, batch per epoch : 357, X : 5758, Y : 54490.5390625
# epoch : 9, batch per epoch : 358, X : 5759, Y : 55185.84375
# epoch : 9, batch per epoch : 359, X : 5760, Y : 54252.34375
# epoch : 9, batch per epoch : 360, X : 5761, Y : 54307.75
# epoch : 9, batch per epoch : 361, X : 5762, Y : 54654.953125
# epoch : 9, batch per epoch : 362, X : 5763, Y : 54111.48046875
# epoch : 9, batch per epoch : 363, X : 5764, Y : 54413.95703125
# epoch : 9, batch per epoch : 364, X : 5765, Y : 54708.28125
# epoch : 9, batch per epoch : 365, X : 5766, Y : 54427.33203125
# epoch : 9, batch per epoch : 366, X : 5767, Y : 55322.41796875
# epoch : 9, batch per epoch : 367, X : 5768, Y : 55041.8671875
# epoch : 9, batch per epoch : 368, X : 5769, Y : 54603.25
# epoch : 9, batch per epoch : 369, X : 5770, Y : 53521.62109375
# epoch : 9, batch per epoch : 370, X : 5771, Y : 54039.453125
# epoch : 9, batch per epoch : 371, X : 5772, Y : 54882.6328125
# epoch : 9, batch per epoch : 372, X : 5773, Y : 55010.3828125
# epoch : 9, batch per epoch : 373, X : 5774, Y : 54996.7890625
# epoch : 9, batch per epoch : 374, X : 5775, Y : 54361.75390625
# epoch : 9, batch per epoch : 375, X : 5776, Y : 54137.796875
# epoch : 9, batch per epoch : 376, X : 5777, Y : 55321.1640625
# epoch : 9, batch per epoch : 377, X : 5778, Y : 54502.1015625
# epoch : 9, batch per epoch : 378, X : 5779, Y : 54027.40234375
# epoch : 9, batch per epoch : 379, X : 5780, Y : 54766.9296875
# epoch : 9, batch per epoch : 380, X : 5781, Y : 55011.2421875
# epoch : 9, batch per epoch : 381, X : 5782, Y : 54459.8359375
# epoch : 9, batch per epoch : 382, X : 5783, Y : 54541.05078125
# epoch : 9, batch per epoch : 383, X : 5784, Y : 54253.58984375
# epoch : 9, batch per epoch : 384, X : 5785, Y : 55087.859375
# epoch : 9, batch per epoch : 385, X : 5786, Y : 54281.32421875
# epoch : 9, batch per epoch : 386, X : 5787, Y : 54601.04296875
# epoch : 9, batch per epoch : 387, X : 5788, Y : 55035.20703125
# epoch : 9, batch per epoch : 388, X : 5789, Y : 55098.5
# epoch : 9, batch per epoch : 389, X : 5790, Y : 54169.734375
# epoch : 9, batch per epoch : 390, X : 5791, Y : 53917.38671875
# epoch : 9, batch per epoch : 391, X : 5792, Y : 55488.5859375
# epoch : 9, batch per epoch : 392, X : 5793, Y : 54180.05859375
# epoch : 9, batch per epoch : 393, X : 5794, Y : 54567.79296875
# epoch : 9, batch per epoch : 394, X : 5795, Y : 55185.2109375
# epoch : 9, batch per epoch : 395, X : 5796, Y : 55328.109375
# epoch : 9, batch per epoch : 396, X : 5797, Y : 53796.8125
# epoch : 9, batch per epoch : 397, X : 5798, Y : 54334.08984375
# epoch : 9, batch per epoch : 398, X : 5799, Y : 53710.578125
# epoch : 9, batch per epoch : 399, X : 5800, Y : 54363.4375
# epoch : 9, batch per epoch : 400, X : 5801, Y : 55561.953125
# epoch : 9, batch per epoch : 401, X : 5802, Y : 53942.4453125
# epoch : 9, batch per epoch : 402, X : 5803, Y : 54364.640625
# epoch : 9, batch per epoch : 403, X : 5804, Y : 54969.59765625
# epoch : 9, batch per epoch : 404, X : 5805, Y : 54558.44140625
# epoch : 9, batch per epoch : 405, X : 5806, Y : 54794.0234375
# epoch : 9, batch per epoch : 406, X : 5807, Y : 54564.53125
# epoch : 9, batch per epoch : 407, X : 5808, Y : 54809.86328125
# epoch : 9, batch per epoch : 408, X : 5809, Y : 56462.13671875
# epoch : 9, batch per epoch : 409, X : 5810, Y : 54498.25390625
# epoch : 9, batch per epoch : 410, X : 5811, Y : 54677.44921875
# epoch : 9, batch per epoch : 411, X : 5812, Y : 53617.4375
# epoch : 9, batch per epoch : 412, X : 5813, Y : 54567.38671875
# epoch : 9, batch per epoch : 413, X : 5814, Y : 56012.4375
# epoch : 9, batch per epoch : 414, X : 5815, Y : 55620.4765625
# epoch : 9, batch per epoch : 415, X : 5816, Y : 53818.5
# epoch : 9, batch per epoch : 416, X : 5817, Y : 55102.63671875
# epoch : 9, batch per epoch : 417, X : 5818, Y : 53822.78515625
# epoch : 9, batch per epoch : 418, X : 5819, Y : 54271.62109375
# epoch : 9, batch per epoch : 419, X : 5820, Y : 54978.703125
# epoch : 9, batch per epoch : 420, X : 5821, Y : 53798.3671875
# epoch : 9, batch per epoch : 421, X : 5822, Y : 54765.1796875
# epoch : 9, batch per epoch : 422, X : 5823, Y : 54323.3203125
# epoch : 9, batch per epoch : 423, X : 5824, Y : 54890.92578125
# epoch : 9, batch per epoch : 424, X : 5825, Y : 52978.01171875
# epoch : 9, batch per epoch : 425, X : 5826, Y : 55365.83203125
# epoch : 9, batch per epoch : 426, X : 5827, Y : 55703.2890625
# epoch : 9, batch per epoch : 427, X : 5828, Y : 54367.66796875
# epoch : 9, batch per epoch : 428, X : 5829, Y : 54850.375
# epoch : 9, batch per epoch : 429, X : 5830, Y : 54560.62109375
# epoch : 9, batch per epoch : 430, X : 5831, Y : 53975.42578125
# epoch : 9, batch per epoch : 431, X : 5832, Y : 54938.421875
# epoch : 9, batch per epoch : 432, X : 5833, Y : 54208.86328125
# epoch : 9, batch per epoch : 433, X : 5834, Y : 54291.30859375
# epoch : 9, batch per epoch : 434, X : 5835, Y : 54855.48046875
# epoch : 9, batch per epoch : 435, X : 5836, Y : 55196.359375
# epoch : 9, batch per epoch : 436, X : 5837, Y : 54258.25
# epoch : 9, batch per epoch : 437, X : 5838, Y : 53389.67578125
# epoch : 9, batch per epoch : 438, X : 5839, Y : 55292.484375
# epoch : 9, batch per epoch : 439, X : 5840, Y : 54491.41015625
# epoch : 9, batch per epoch : 440, X : 5841, Y : 55113.6875
# epoch : 9, batch per epoch : 441, X : 5842, Y : 53677.140625
# epoch : 9, batch per epoch : 442, X : 5843, Y : 55644.9140625
# epoch : 9, batch per epoch : 443, X : 5844, Y : 55864.5390625
# epoch : 9, batch per epoch : 444, X : 5845, Y : 54978.1640625
# epoch : 9, batch per epoch : 445, X : 5846, Y : 54279.87890625
# epoch : 9, batch per epoch : 446, X : 5847, Y : 53692.1484375
# epoch : 9, batch per epoch : 447, X : 5848, Y : 54889.0625
# epoch : 9, batch per epoch : 448, X : 5849, Y : 55141.54296875
# epoch : 9, batch per epoch : 449, X : 5850, Y : 55487.0234375
# epoch : 9, batch per epoch : 450, X : 5851, Y : 54500.41015625
# epoch : 9, batch per epoch : 451, X : 5852, Y : 55775.625
# epoch : 9, batch per epoch : 452, X : 5853, Y : 53759.6171875
# epoch : 9, batch per epoch : 453, X : 5854, Y : 54941.5703125
# epoch : 9, batch per epoch : 454, X : 5855, Y : 54418.2578125
# epoch : 9, batch per epoch : 455, X : 5856, Y : 54578.328125
# epoch : 9, batch per epoch : 456, X : 5857, Y : 54133.81640625
# epoch : 9, batch per epoch : 457, X : 5858, Y : 54183.6953125
# epoch : 9, batch per epoch : 458, X : 5859, Y : 54313.45703125
# epoch : 9, batch per epoch : 459, X : 5860, Y : 55196.91015625
# epoch : 9, batch per epoch : 460, X : 5861, Y : 55325.75390625
# epoch : 9, batch per epoch : 461, X : 5862, Y : 54507.44140625
# epoch : 9, batch per epoch : 462, X : 5863, Y : 54324.03515625
# epoch : 9, batch per epoch : 463, X : 5864, Y : 55123.125
# epoch : 9, batch per epoch : 464, X : 5865, Y : 54042.04296875
# epoch : 9, batch per epoch : 465, X : 5866, Y : 55111.99609375
# epoch : 9, batch per epoch : 466, X : 5867, Y : 55565.0
# epoch : 9, batch per epoch : 467, X : 5868, Y : 55267.1484375
# epoch : 9, batch per epoch : 468, X : 5869, Y : 53290.07421875
# epoch : 9, batch per epoch : 469, X : 5870, Y : 55040.4921875
# epoch : 9, batch per epoch : 470, X : 5871, Y : 54065.2265625
# epoch : 9, batch per epoch : 471, X : 5872, Y : 54144.86328125
# epoch : 9, batch per epoch : 472, X : 5873, Y : 53569.32421875
# epoch : 9, batch per epoch : 473, X : 5874, Y : 54874.3671875
# epoch : 9, batch per epoch : 474, X : 5875, Y : 55256.01953125
# epoch : 9, batch per epoch : 475, X : 5876, Y : 55088.234375
# epoch : 9, batch per epoch : 476, X : 5877, Y : 54461.0234375
# epoch : 9, batch per epoch : 477, X : 5878, Y : 54904.484375
# epoch : 9, batch per epoch : 478, X : 5879, Y : 55532.87890625
# epoch : 9, batch per epoch : 479, X : 5880, Y : 54643.6015625
# epoch : 9, batch per epoch : 480, X : 5881, Y : 54809.6171875
# epoch : 9, batch per epoch : 481, X : 5882, Y : 54389.9609375
# epoch : 9, batch per epoch : 482, X : 5883, Y : 54765.93359375
# epoch : 9, batch per epoch : 483, X : 5884, Y : 54875.41796875
# epoch : 9, batch per epoch : 484, X : 5885, Y : 54638.00390625
# epoch : 9, batch per epoch : 485, X : 5886, Y : 54739.2421875
# epoch : 9, batch per epoch : 486, X : 5887, Y : 54412.10546875
# epoch : 9, batch per epoch : 487, X : 5888, Y : 54128.609375
# epoch : 9, batch per epoch : 488, X : 5889, Y : 53916.5546875
# epoch : 9, batch per epoch : 489, X : 5890, Y : 53634.74609375
# epoch : 9, batch per epoch : 490, X : 5891, Y : 54717.8203125
# epoch : 9, batch per epoch : 491, X : 5892, Y : 55031.94140625
# epoch : 9, batch per epoch : 492, X : 5893, Y : 55190.421875
# epoch : 9, batch per epoch : 493, X : 5894, Y : 54115.6875
# epoch : 9, batch per epoch : 494, X : 5895, Y : 54183.40625
# epoch : 9, batch per epoch : 495, X : 5896, Y : 55633.796875
# epoch : 9, batch per epoch : 496, X : 5897, Y : 54381.9453125
# epoch : 9, batch per epoch : 497, X : 5898, Y : 54910.34765625
# epoch : 9, batch per epoch : 498, X : 5899, Y : 54302.25390625
# epoch : 9, batch per epoch : 499, X : 5900, Y : 54311.0
# epoch : 9, batch per epoch : 500, X : 5901, Y : 55441.140625
# epoch : 9, batch per epoch : 501, X : 5902, Y : 53865.4921875
# epoch : 9, batch per epoch : 502, X : 5903, Y : 55036.41796875
# epoch : 9, batch per epoch : 503, X : 5904, Y : 55544.13671875
# epoch : 9, batch per epoch : 504, X : 5905, Y : 54168.23046875
# epoch : 9, batch per epoch : 505, X : 5906, Y : 54309.765625
# epoch : 9, batch per epoch : 506, X : 5907, Y : 54769.48046875
# epoch : 9, batch per epoch : 507, X : 5908, Y : 54591.25
# epoch : 9, batch per epoch : 508, X : 5909, Y : 54149.1796875
# epoch : 9, batch per epoch : 509, X : 5910, Y : 55160.5703125
# epoch : 9, batch per epoch : 510, X : 5911, Y : 55648.54296875
# epoch : 9, batch per epoch : 511, X : 5912, Y : 53540.17578125
# epoch : 9, batch per epoch : 512, X : 5913, Y : 55701.5859375
# epoch : 9, batch per epoch : 513, X : 5914, Y : 55632.18359375
# epoch : 9, batch per epoch : 514, X : 5915, Y : 56154.3359375
# epoch : 9, batch per epoch : 515, X : 5916, Y : 54879.58203125
# epoch : 9, batch per epoch : 516, X : 5917, Y : 54058.57421875
# epoch : 9, batch per epoch : 517, X : 5918, Y : 54632.23828125
# epoch : 9, batch per epoch : 518, X : 5919, Y : 54385.36328125
# epoch : 9, batch per epoch : 519, X : 5920, Y : 54059.546875
# epoch : 9, batch per epoch : 520, X : 5921, Y : 55102.9140625
# epoch : 9, batch per epoch : 521, X : 5922, Y : 55368.95703125
# epoch : 9, batch per epoch : 522, X : 5923, Y : 54127.92578125
# epoch : 9, batch per epoch : 523, X : 5924, Y : 54460.79296875
# epoch : 9, batch per epoch : 524, X : 5925, Y : 54889.78515625
# epoch : 9, batch per epoch : 525, X : 5926, Y : 54493.6015625
# epoch : 9, batch per epoch : 526, X : 5927, Y : 54737.79296875
# epoch : 9, batch per epoch : 527, X : 5928, Y : 54870.8515625
# epoch : 9, batch per epoch : 528, X : 5929, Y : 54164.5390625
# epoch : 9, batch per epoch : 529, X : 5930, Y : 53828.8125
# epoch : 9, batch per epoch : 530, X : 5931, Y : 55079.5390625
# epoch : 9, batch per epoch : 531, X : 5932, Y : 54636.26953125
# epoch : 9, batch per epoch : 532, X : 5933, Y : 54970.2421875
# epoch : 9, batch per epoch : 533, X : 5934, Y : 54456.68359375
# epoch : 9, batch per epoch : 534, X : 5935, Y : 55004.05859375
# epoch : 9, batch per epoch : 535, X : 5936, Y : 54576.2421875
# epoch : 9, batch per epoch : 536, X : 5937, Y : 55395.2890625
# epoch : 9, batch per epoch : 537, X : 5938, Y : 54808.83203125
# epoch : 9, batch per epoch : 538, X : 5939, Y : 55136.4375
# epoch : 9, batch per epoch : 539, X : 5940, Y : 54188.97265625
# epoch : 9, batch per epoch : 540, X : 5941, Y : 54292.87109375
# epoch : 9, batch per epoch : 541, X : 5942, Y : 53992.11328125
# epoch : 9, batch per epoch : 542, X : 5943, Y : 54122.5859375
# epoch : 9, batch per epoch : 543, X : 5944, Y : 54907.4453125
# epoch : 9, batch per epoch : 544, X : 5945, Y : 55419.01171875
# epoch : 9, batch per epoch : 545, X : 5946, Y : 55086.48828125
# epoch : 9, batch per epoch : 546, X : 5947, Y : 55278.15234375
# epoch : 9, batch per epoch : 547, X : 5948, Y : 54136.73828125
# epoch : 9, batch per epoch : 548, X : 5949, Y : 55337.1875
# epoch : 9, batch per epoch : 549, X : 5950, Y : 54180.8203125
# epoch : 9, batch per epoch : 550, X : 5951, Y : 54949.0078125
# epoch : 9, batch per epoch : 551, X : 5952, Y : 55176.38671875
# epoch : 9, batch per epoch : 552, X : 5953, Y : 54420.77734375
# epoch : 9, batch per epoch : 553, X : 5954, Y : 54090.84765625
# epoch : 9, batch per epoch : 554, X : 5955, Y : 54429.28515625
# epoch : 9, batch per epoch : 555, X : 5956, Y : 53822.54296875
# epoch : 9, batch per epoch : 556, X : 5957, Y : 55030.72265625
# epoch : 9, batch per epoch : 557, X : 5958, Y : 54436.01953125
# epoch : 9, batch per epoch : 558, X : 5959, Y : 54257.06640625
# epoch : 9, batch per epoch : 559, X : 5960, Y : 55966.42578125
# epoch : 9, batch per epoch : 560, X : 5961, Y : 54957.1484375
# epoch : 9, batch per epoch : 561, X : 5962, Y : 54492.640625
# epoch : 9, batch per epoch : 562, X : 5963, Y : 53829.3984375
# epoch : 9, batch per epoch : 563, X : 5964, Y : 55020.625
# epoch : 9, batch per epoch : 564, X : 5965, Y : 53981.87890625
# epoch : 9, batch per epoch : 565, X : 5966, Y : 53719.47265625
# epoch : 9, batch per epoch : 566, X : 5967, Y : 55206.6484375
# epoch : 9, batch per epoch : 567, X : 5968, Y : 55709.3046875
# epoch : 9, batch per epoch : 568, X : 5969, Y : 54448.30078125
# epoch : 9, batch per epoch : 569, X : 5970, Y : 53842.23046875
# epoch : 9, batch per epoch : 570, X : 5971, Y : 54971.8046875
# epoch : 9, batch per epoch : 571, X : 5972, Y : 55235.203125
# epoch : 9, batch per epoch : 572, X : 5973, Y : 54934.2265625
# epoch : 9, batch per epoch : 573, X : 5974, Y : 55089.12890625
# epoch : 9, batch per epoch : 574, X : 5975, Y : 54199.65625
# epoch : 9, batch per epoch : 575, X : 5976, Y : 54628.64453125
# epoch : 9, batch per epoch : 576, X : 5977, Y : 54837.421875
# epoch : 9, batch per epoch : 577, X : 5978, Y : 55068.98046875
# epoch : 9, batch per epoch : 578, X : 5979, Y : 54047.8671875
# epoch : 9, batch per epoch : 579, X : 5980, Y : 55264.328125
# epoch : 9, batch per epoch : 580, X : 5981, Y : 55089.76953125
# epoch : 9, batch per epoch : 581, X : 5982, Y : 55232.04296875
# epoch : 9, batch per epoch : 582, X : 5983, Y : 55199.65234375
# epoch : 9, batch per epoch : 583, X : 5984, Y : 54355.41796875
# epoch : 9, batch per epoch : 584, X : 5985, Y : 55403.3984375
# epoch : 9, batch per epoch : 585, X : 5986, Y : 54101.5703125
# epoch : 9, batch per epoch : 586, X : 5987, Y : 54477.734375
# epoch : 9, batch per epoch : 587, X : 5988, Y : 53889.62109375
# epoch : 9, batch per epoch : 588, X : 5989, Y : 54927.859375
# epoch : 9, batch per epoch : 589, X : 5990, Y : 54270.90625
# epoch : 9, batch per epoch : 590, X : 5991, Y : 54442.984375
# epoch : 9, batch per epoch : 591, X : 5992, Y : 54522.4375
# epoch : 9, batch per epoch : 592, X : 5993, Y : 53980.11328125
# epoch : 9, batch per epoch : 593, X : 5994, Y : 54712.57421875
# epoch : 9, batch per epoch : 594, X : 5995, Y : 55313.57421875
# epoch : 9, batch per epoch : 595, X : 5996, Y : 54623.99609375
# epoch : 9, batch per epoch : 596, X : 5997, Y : 54485.2265625
# epoch : 9, batch per epoch : 597, X : 5998, Y : 54283.8125
# epoch : 9, batch per epoch : 598, X : 5999, Y : 54228.03515625
# epoch : 9, batch per epoch : 599, X : 6000, Y : 53993.41015625

# %%
import random
model = torch.load('./unet_small_parameters_vgg.pt')
model.eval()
for i,(X,_) in enumerate(test_iter):
    if i>=1:
        break
    index = random.randint(0,X.shape[0])
    image = X[index]
    model_input = torch.unsqueeze(image,dim=0)
    with torch.no_grad():
        result = model(model_input)[0]
        plt.subplot(2, 1, 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(x_resize_test(image).permute(1,2,0))
        plt.subplot(2, 1, 2)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(result.permute(1,2,0))
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import random
# ----> 2 model = torch.load('./unet_small_parameters_vgg.pt')
#       3 model.eval()
#       4 for i,(X,_) in enumerate(test_iter):
#
# NameError: name 'torch' is not defined
