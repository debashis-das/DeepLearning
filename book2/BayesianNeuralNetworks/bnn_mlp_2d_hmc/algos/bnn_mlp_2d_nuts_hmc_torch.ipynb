# %%
from typing import NamedTuple, Callable
from functools import partial

import torch
import torch.nn as nn
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# %%
class MLP1D(nn.Module):

    def __init__(self, in_shapes=[2,10,10,10], out_shapes = [10,10,10,1]):
        super().__init__()
        self.linears = [nn.Linear(in_shapes[i], out_shapes[i]) for i in range(len(in_shapes))]
        self.relu = nn.ReLU()
        
    def model(self):
        return nn.Sequential(self.linears[0], self.relu, 
                             self.linears[1], self.relu, 
                             self.linears[2], self.relu, self.linears[3])

    def forward(self, params, X):
        self.weights_and_biases(params)
        return self.model()(X)
    
    def weights_and_biases(self, params):
        for i,param in enumerate(params):
            self.linears[i].weight = nn.Parameter(param['weight'])
            self.linears[i].bias = nn.Parameter(param['bias'])
    
    def fetch_params(self):
        params = []
        for linear in self.linears:
            params.append({
                'weight': linear.weight.detach(),
                'bias': linear.bias.detach()
            })
        return params

def ravel_params(params):
    def ravel_per_item():
        all_params = []
        def ravel_per_item_per_key(param):
            for value in param.values(): 
                all_params.append(value.ravel())

        if type(params) == list:
            for param in params:
                ravel_per_item_per_key(param)
        else:
            ravel_per_item_per_key(params)
        return all_params
    return torch.cat(ravel_per_item())

def unravel_params(params_raveled: torch.Tensor, structured_tuple):
    
    def unravel_all_shapes(structure, is_list):
        shapes = []
        def extract_shapes(structure):
            if is_list:
                for per_structure in structure:
                    for val in per_structure.values():
                        shapes.append(val.numel())
            else:
                for val in structure.values():
                    shapes.append(val.numel())
            values_per_structure = params_raveled.split(shapes)
            return values_per_structure
        
        values_per_structure = extract_shapes(structure)
        result = []
        index = [0]

        def result_per_dict(values_per_structure, per_structure):
            per_result = {}
            for key, val in per_structure.items():
                # print(key, val.shape, values_per_structure[index[0]].shape)
                per_result[key] = values_per_structure[index[0]].reshape(val.shape)
                index[0] += 1
            return per_result
        
        if is_list:
            for per_structure in structure:
                per_result = result_per_dict(values_per_structure, per_structure)
                result.append(per_result)
            return result
        else:
            return result_per_dict(values_per_structure, structure)
        
    return unravel_all_shapes(structured_tuple, type(structured_tuple) == list)
    
def bnn_log_joint(params, X, y, model:MLP1D):
    logits = model.forward(params, X).ravel()
    flatten_params = ravel_params(params)
    log_prior = torch.distributions.Normal(0.0, 1.0).log_prob(flatten_params).sum()
    log_likelihood = torch.distributions.Bernoulli(logits=logits).log_prob(y).sum()
    log_joint = log_prior + log_likelihood
    return log_joint

noise = 0.2
num_samples = 50
num_warmup = 1000
num_steps = 500
in_shapes = [2,10,10,10]
out_shapes = [10,10,10,1]

X, y = make_moons(n_samples=num_samples, noise=noise, random_state=314)
model = MLP1D(in_shapes=in_shapes, out_shapes=out_shapes)
params = model.fetch_params()
potential = partial(bnn_log_joint, X=torch.Tensor(X), y=torch.Tensor(y), model=model)


# Test

# potential(params)
# print(ravel_params(params[0]).shape)
# print(unravel_params(ravel_params(params[1]),params[1]))
# print(unravel_params(ravel_params(params),params))

# %%
class EnergyParameters:

    def __init__(self, potential_energy_fn:Callable, precision):
        self.potential_energy_fn = potential_energy_fn 
        self.precision = precision
    
    def set_position(self, position):
        self.position = position
        self.potential_energy = self.potential_energy_fn(position)
        self.potential_energy_grad = torch.func.grad(self.potential_energy_fn)(position)
    
    def set_velocity(self, velocity):
        self.velocity = velocity
        self.kinetic_energy = self.kinetic_energy_fn(self.velocity)
        self.kinetic_energy_grad = torch.func.grad(self.kinetic_energy_fn)(self.velocity)

    def init_per_step(self, position, velocity):
        self.set_position(position)
        self.set_velocity(velocity)
        self.total_init_energy = self.total_current_energy()
    
    def kinetic_energy_fn(self, velocity:torch.Tensor):
        return 0.5*torch.matmul(velocity, torch.matmul(self.precision, velocity.T))
    
    def update_position(self, step_size_with_direction):
        position_raveled = ravel_params(self.position)
        result = position_raveled + step_size_with_direction*self.kinetic_energy_grad
        n_position = unravel_params(result, self.position)
        self.set_position(n_position)
        return n_position

    def updated_velocity(self, step_size_with_direction, is_half_step_momentum = False):
        n_velocity = torch.subtract(self.velocity, step_size_with_direction*(0.5 if is_half_step_momentum else 1)*ravel_params(self.potential_energy_grad))
        self.set_velocity(n_velocity)
        return n_velocity
    
    def delta_energy(self):
        return - self.total_current_energy() + self.total_init_energy 
    
    def total_current_energy(self):
        return - self.potential_energy - self.kinetic_energy

# Test

# e_params = EnergyParameters(potential_energy_fn=potential)
# e_params.set_energy_parameters(params)

# %% [markdown]
# # Efficient No-U-Turn Sampler

# %%
class HMCAlgorithm:
    
    def __init__(self, log_density_fn: Callable, precision, l=1, step_size=0.1):
        self.log_density_fn = log_density_fn
        self.l = l
        self.step_size = step_size
        self.ep = EnergyParameters(potential_energy_fn=log_density_fn, precision=precision)
    

    def generate_default_velocity(self, position_shape):

        def generate_random_gaussian(covariance: torch.Tensor):
            return torch.distributions.MultivariateNormal(loc=torch.zeros(covariance.shape[-1]),covariance_matrix=covariance).sample()

        def generate_inverse_mass_matrix_and_sigma(covariance_shape: int):
            covariance = torch.eye(covariance_shape)
            inverse_mass_matrix = covariance.inverse()
            return inverse_mass_matrix, covariance
        
        _, covariance = generate_inverse_mass_matrix_and_sigma(position_shape)
        return generate_random_gaussian(covariance)

    def current_direction(self):
        direction = torch.distributions.Bernoulli(logits=torch.tensor([0.5])).sample()
        return -1 if direction.bool() else 1

    def stop_condition(self, p_minus, v_minus, p_plus, v_plus):
        diff = ravel_params(p_plus)-ravel_params(p_minus)
        condition = torch.all(diff*v_minus >= torch.zeros(diff.shape)) and torch.all(diff*v_plus >= torch.zeros(diff.shape))
        return condition.int()

    def build_tree(self, position, velocity, energy, direction, iter_no, step_size, m):
        delta_max = torch.tensor(1000)
        if iter_no == 0:
            delta_energy, new_position, new_velocity, new_energy = self.step_integrator(position, velocity, direction*step_size)
            print(new_energy, energy, delta_energy, m)
            n_leaves = 1 if energy <= new_energy else 0
            s = 1 if new_energy > torch.log(energy) - delta_max else 0
            return new_position, new_velocity, new_position, new_velocity, new_position, n_leaves, s
        else:
            p_minus, v_minus, p_plus, v_plus, p, n_leaves, s = self.build_tree(position, velocity, energy, direction, iter_no-1, step_size, m)
            if s == 1:
                if direction == -1:
                    p_minus, v_minus, _, _, new_p, n_n_leaves, new_s = self.build_tree(p_minus, v_minus, energy, direction, iter_no-1, step_size, m)
                else:
                    _, _, p_plus, v_plus, new_p, n_n_leaves, new_s = self.build_tree(p_plus, v_plus, energy, direction, iter_no-1, step_size, m)
                p = new_p if torch.distributions.Bernoulli(logits=new_s/(s+new_s)).sample().bool() else p
                s = new_s * self.stop_condition(p_minus, v_minus, p_plus, v_plus)
                n_leaves += n_n_leaves
            return p_minus, v_minus, p_plus, v_plus, p, n_leaves, new_s

    def update(self, position, m):
        # self.step_size = self.find_reasonable_epsilon(position)
        velocity = self.generate_default_velocity(ravel_params(position).shape[-1])
        self.ep.init_per_step(position, velocity)
        energy = torch.distributions.Uniform(torch.tensor([0.0]),self.ep.total_current_energy()).sample()
        p_minus, p_plus, v_minus, v_plus, proposal_position = position, position, velocity, velocity, position
        counter, s, n_leaves = 0, 1, 1
        while s == 1:
            direction = self.current_direction()
            if direction == -1:
                p_minus, v_minus, _,_, new_p, n_n_leaves, new_s = self.build_tree(p_minus, v_minus, energy, direction, counter, self.step_size, m) 
            else:
                _, _, p_plus, v_plus, new_p, n_n_leaves, new_s = self.build_tree(p_plus, v_plus, energy, direction, counter, self.step_size, m) 
            if new_s == 1:
                proposal_position = new_p if torch.distributions.Bernoulli(logits=torch.tensor(min(1, n_n_leaves/n_leaves))).sample().bool() else position
            n_leaves += n_n_leaves
            s = new_s * self.stop_condition(p_minus, v_minus, p_plus, v_plus)
            counter += 1
        return proposal_position

    def step_integrator(self, position, velocity, step_size_with_direction):
        self.ep.init_per_step(position, velocity)
        # init step
        self.ep.updated_velocity(step_size_with_direction, is_half_step_momentum=True)
        # l_frog_steps
        for i in range(self.l):
            self.ep.update_position(step_size_with_direction)
            self.ep.updated_velocity(step_size_with_direction, is_half_step_momentum=False)
        # final step
        f_step_position = self.ep.update_position(step_size_with_direction)
        half_step_velocity = self.ep.updated_velocity(step_size_with_direction, is_half_step_momentum=True)
        return self.ep.delta_energy(), f_step_position, half_step_velocity, self.ep.total_current_energy()

precision_shape = ravel_params(params).shape[-1]
# I^-1 = I so inverse doesn't matter but writing it for visibility
default_precision = torch.eye(precision_shape).inverse()
hmc_kernel = HMCAlgorithm(log_density_fn=potential, precision=default_precision)

# Test
# hmc_kernel.update(params)

# %%
def scan(func, init_values, length):
    carry = init_values
    result = []
    for i in range(length):
        carry = func(carry,i)
        result.append(carry)
    return carry, result 

final_state, result = scan(hmc_kernel.update, init_values=params, length=num_warmup)
# Out:
# tensor(143.6068, grad_fn=<SubBackward0>) tensor([1.0507]) tensor(-0.1590, grad_fn=<AddBackward0>) 0
# tensor(143.4349, grad_fn=<SubBackward0>) tensor([58.5233]) tensor(0.0470, grad_fn=<AddBackward0>) 1
# tensor(200.7657, grad_fn=<SubBackward0>) tensor([114.9899]) tensor(-4.7101, grad_fn=<AddBackward0>) 2
# tensor(191.8407, grad_fn=<SubBackward0>) tensor([14.0119]) tensor(-11.6809, grad_fn=<AddBackward0>) 3
# tensor(175.9684, grad_fn=<SubBackward0>) tensor([8.6598]) tensor(5.1246, grad_fn=<AddBackward0>) 4
# tensor(166.1482, grad_fn=<SubBackward0>) tensor([70.8182]) tensor(-1.1202, grad_fn=<AddBackward0>) 5
# tensor(178.8044, grad_fn=<SubBackward0>) tensor([30.0670]) tensor(-1.0601, grad_fn=<AddBackward0>) 6
# tensor(208.0465, grad_fn=<SubBackward0>) tensor([1.9323]) tensor(-3.9600, grad_fn=<AddBackward0>) 7
# tensor(180.4149, grad_fn=<SubBackward0>) tensor([19.3365]) tensor(6.3463, grad_fn=<AddBackward0>) 8
# tensor(215.5519, grad_fn=<SubBackward0>) tensor([40.1775]) tensor(-6.3619, grad_fn=<AddBackward0>) 9
# tensor(231.2852, grad_fn=<SubBackward0>) tensor([84.1947]) tensor(-33.7315, grad_fn=<AddBackward0>) 10
# tensor(207.0119, grad_fn=<SubBackward0>) tensor([39.7887]) tensor(0.2100, grad_fn=<AddBackward0>) 11
# tensor(243.0869, grad_fn=<SubBackward0>) tensor([148.6354]) tensor(-33.3067, grad_fn=<AddBackward0>) 12
# tensor(209.9933, grad_fn=<SubBackward0>) tensor([105.1137]) tensor(44.5441, grad_fn=<AddBackward0>) 13
# tensor(224.7529, grad_fn=<SubBackward0>) tensor([164.0303]) tensor(-11.0844, grad_fn=<AddBackward0>) 14
# tensor(307.7244, grad_fn=<SubBackward0>) tensor([47.6057]) tensor(-85.1926, grad_fn=<AddBackward0>) 15
# tensor(312.5241, grad_fn=<SubBackward0>) tensor([20.0288]) tensor(11.8558, grad_fn=<AddBackward0>) 16
# tensor(325.7287, grad_fn=<SubBackward0>) tensor([303.1244]) tensor(-9.7195, grad_fn=<AddBackward0>) 17
# tensor(346.0512, grad_fn=<SubBackward0>) tensor([209.6204]) tensor(10.3614, grad_fn=<AddBackward0>) 18
# tensor(326.2776, grad_fn=<SubBackward0>) tensor([211.5386]) tensor(13.5153, grad_fn=<AddBackward0>) 19
# tensor(491.5482, grad_fn=<SubBackward0>) tensor([22.2113]) tensor(-149.5557, grad_fn=<AddBackward0>) 20
# tensor(432.8976, grad_fn=<SubBackward0>) tensor([276.2034]) tensor(59.9038, grad_fn=<AddBackward0>) 21
# tensor(429.3055, grad_fn=<SubBackward0>) tensor([243.5858]) tensor(42.9357, grad_fn=<AddBackward0>) 22
# tensor(318.5266, grad_fn=<SubBackward0>) tensor([362.2633]) tensor(86.4717, grad_fn=<AddBackward0>) 23
# tensor(360.2694, grad_fn=<SubBackward0>) tensor([34.0544]) tensor(61.5849, grad_fn=<AddBackward0>) 24
# tensor(444.3022, grad_fn=<SubBackward0>) tensor([353.5283]) tensor(-55.7149, grad_fn=<AddBackward0>) 25
# tensor(541.7388, grad_fn=<SubBackward0>) tensor([171.4225]) tensor(-95.0668, grad_fn=<AddBackward0>) 26
# tensor(770.9418, grad_fn=<SubBackward0>) tensor([348.1590]) tensor(-201.1219, grad_fn=<AddBackward0>) 27
# tensor(753.2243, grad_fn=<SubBackward0>) tensor([495.5986]) tensor(-213.7703, grad_fn=<AddBackward0>) 28
# tensor(745.8079, grad_fn=<SubBackward0>) tensor([648.3051]) tensor(32.9373, grad_fn=<AddBackward0>) 29
# tensor(1680.0085, grad_fn=<SubBackward0>) tensor([176.0843]) tensor(-900.3845, grad_fn=<AddBackward0>) 30
# tensor(1094.0708, grad_fn=<SubBackward0>) tensor([573.9991]) tensor(-303.7618, grad_fn=<AddBackward0>) 31
# tensor(1569.4501, grad_fn=<SubBackward0>) tensor([398.1750]) tensor(-475.5005, grad_fn=<AddBackward0>) 32
# tensor(1374.4038, grad_fn=<SubBackward0>) tensor([545.7258]) tensor(-270.6235, grad_fn=<AddBackward0>) 33
# tensor(1363.1240, grad_fn=<SubBackward0>) tensor([1081.7288]) tensor(16.9163, grad_fn=<AddBackward0>) 34
# tensor(1155.5634, grad_fn=<SubBackward0>) tensor([1256.0426]) tensor(213.5015, grad_fn=<AddBackward0>) 35
# tensor(965.3245, grad_fn=<SubBackward0>) tensor([1039.8558]) tensor(209.4202, grad_fn=<AddBackward0>) 36
# tensor(1167.1931, grad_fn=<SubBackward0>) tensor([197.4607]) tensor(-174.2198, grad_fn=<AddBackward0>) 37
# tensor(1088.7239, grad_fn=<SubBackward0>) tensor([460.4467]) tensor(-98.9745, grad_fn=<AddBackward0>) 38
# tensor(1064.4293, grad_fn=<SubBackward0>) tensor([811.4120]) tensor(-80.0227, grad_fn=<AddBackward0>) 39
# tensor(1721.3601, grad_fn=<SubBackward0>) tensor([617.2571]) tensor(-722.3661, grad_fn=<AddBackward0>) 40
# tensor(2558.3066, grad_fn=<SubBackward0>) tensor([1286.2617]) tensor(-809.7628, grad_fn=<AddBackward0>) 41
# tensor(1961.2921, grad_fn=<SubBackward0>) tensor([573.2749]) tensor(-213.1903, grad_fn=<AddBackward0>) 42
# tensor(1275.5254, grad_fn=<SubBackward0>) tensor([1022.9983]) tensor(684.8167, grad_fn=<AddBackward0>) 43
# tensor(2036.8645, grad_fn=<SubBackward0>) tensor([1028.3512]) tensor(-718.1527, grad_fn=<AddBackward0>) 44
# tensor(2844.2925, grad_fn=<SubBackward0>) tensor([963.7187]) tensor(-808.0203, grad_fn=<AddBackward0>) 45
# tensor(3187.9766, grad_fn=<SubBackward0>) tensor([2318.6648]) tensor(-337.0161, grad_fn=<AddBackward0>) 46
# tensor(2888.8491, grad_fn=<SubBackward0>) tensor([420.5860]) tensor(306.0811, grad_fn=<AddBackward0>) 47
# tensor(3245.1318, grad_fn=<SubBackward0>) tensor([2363.0383]) tensor(-302.9482, grad_fn=<AddBackward0>) 48
# tensor(3026.3792, grad_fn=<SubBackward0>) tensor([1539.8324]) tensor(-89.1174, grad_fn=<AddBackward0>) 49
# tensor(3516.8962, grad_fn=<SubBackward0>) tensor([1742.3239]) tensor(-587.0129, grad_fn=<AddBackward0>) 50
# tensor(2456.5503, grad_fn=<SubBackward0>) tensor([1007.8251]) tensor(486.1465, grad_fn=<AddBackward0>) 51
# tensor(3579.6167, grad_fn=<SubBackward0>) tensor([653.8842]) tensor(-1095.1367, grad_fn=<AddBackward0>) 52
# tensor(4591.0103, grad_fn=<SubBackward0>) tensor([1371.1174]) tensor(-973.6697, grad_fn=<AddBackward0>) 53
# tensor(4909.2598, grad_fn=<SubBackward0>) tensor([926.7195]) tensor(-270.3628, grad_fn=<AddBackward0>) 54
# tensor(4868.3003, grad_fn=<SubBackward0>) tensor([4227.7383]) tensor(-248.0015, grad_fn=<AddBackward0>) 55
# tensor(4578.0503, grad_fn=<SubBackward0>) tensor([1746.2057]) tensor(314.1938, grad_fn=<AddBackward0>) 56
# tensor(5295.1968, grad_fn=<SubBackward0>) tensor([1374.1522]) tensor(-707.4248, grad_fn=<AddBackward0>) 57
# tensor(6326.0488, grad_fn=<SubBackward0>) tensor([3065.6299]) tensor(-982.9824, grad_fn=<AddBackward0>) 58
# tensor(6169.1738, grad_fn=<SubBackward0>) tensor([2041.2942]) tensor(187.7485, grad_fn=<AddBackward0>) 59
# tensor(6140.0454, grad_fn=<SubBackward0>) tensor([2279.7539]) tensor(83.4126, grad_fn=<AddBackward0>) 60
# tensor(5839.7139, grad_fn=<SubBackward0>) tensor([229.6216]) tensor(321.8857, grad_fn=<AddBackward0>) 61
# tensor(8665.1182, grad_fn=<SubBackward0>) tensor([5929.7505]) tensor(-2513.6733, grad_fn=<AddBackward0>) 62
# tensor(9724.2324, grad_fn=<SubBackward0>) tensor([6808.2485]) tensor(-1009.8379, grad_fn=<AddBackward0>) 63
# tensor(16066.9824, grad_fn=<SubBackward0>) tensor([5998.3369]) tensor(-6337.1455, grad_fn=<AddBackward0>) 64
# tensor(10244.8535, grad_fn=<SubBackward0>) tensor([251.2391]) tensor(-504.6260, grad_fn=<AddBackward0>) 65
# tensor(8625.7432, grad_fn=<SubBackward0>) tensor([1135.8170]) tensor(1099.4219, grad_fn=<AddBackward0>) 66
# tensor(11202.1523, grad_fn=<SubBackward0>) tensor([8554.8750]) tensor(-2508.9189, grad_fn=<AddBackward0>) 67
# tensor(10090.4297, grad_fn=<SubBackward0>) tensor([4414.9551]) tensor(1139.5010, grad_fn=<AddBackward0>) 68
# tensor(11571.3125, grad_fn=<SubBackward0>) tensor([2999.5337]) tensor(-1446.0596, grad_fn=<AddBackward0>) 69
# tensor(13107.1670, grad_fn=<SubBackward0>) tensor([2712.6802]) tensor(-1470.5967, grad_fn=<AddBackward0>) 70
# tensor(14286.4316, grad_fn=<SubBackward0>) tensor([9092.9023]) tensor(-2644.9248, grad_fn=<AddBackward0>) 71
# tensor(13714.8682, grad_fn=<SubBackward0>) tensor([5237.9771]) tensor(604.4121, grad_fn=<AddBackward0>) 72
# tensor(15336.3340, grad_fn=<SubBackward0>) tensor([11436.1982]) tensor(-1565.7539, grad_fn=<AddBackward0>) 73
# tensor(16550.5527, grad_fn=<SubBackward0>) tensor([9335.0430]) tensor(-1174.5293, grad_fn=<AddBackward0>) 74
# tensor(17694.4766, grad_fn=<SubBackward0>) tensor([8671.5371]) tensor(-2305.2461, grad_fn=<AddBackward0>) 75
# tensor(15812.7578, grad_fn=<SubBackward0>) tensor([4208.7627]) tensor(-432.6035, grad_fn=<AddBackward0>) 76
# tensor(18462.4141, grad_fn=<SubBackward0>) tensor([6236.2227]) tensor(-2617.4805, grad_fn=<AddBackward0>) 77
# tensor(17013.8398, grad_fn=<SubBackward0>) tensor([8707.2891]) tensor(1561.1816, grad_fn=<AddBackward0>) 78
# tensor(19142.0996, grad_fn=<SubBackward0>) tensor([1467.9226]) tensor(-2093.0410, grad_fn=<AddBackward0>) 79
# tensor(24771.3184, grad_fn=<SubBackward0>) tensor([11035.1904]) tensor(-7739.1035, grad_fn=<AddBackward0>) 80
# tensor(25795.6680, grad_fn=<SubBackward0>) tensor([23903.8906]) tensor(-953.0586, grad_fn=<AddBackward0>) 81
# tensor(25548.5938, grad_fn=<SubBackward0>) tensor([4288.9731]) tensor(-702.1543, grad_fn=<AddBackward0>) 82
# tensor(24807.8359, grad_fn=<SubBackward0>) tensor([6081.0024]) tensor(773.6816, grad_fn=<AddBackward0>) 83
# tensor(21049.0859, grad_fn=<SubBackward0>) tensor([19483.2441]) tensor(3829.5449, grad_fn=<AddBackward0>) 84
# tensor(30155.1582, grad_fn=<SubBackward0>) tensor([12984.2969]) tensor(-5302.4434, grad_fn=<AddBackward0>) 85
# tensor(31116.0586, grad_fn=<SubBackward0>) tensor([4228.4609]) tensor(-879.6934, grad_fn=<AddBackward0>) 86
# tensor(32439.7441, grad_fn=<SubBackward0>) tensor([7804.2788]) tensor(-1301.1230, grad_fn=<AddBackward0>) 87
# tensor(32040.9121, grad_fn=<SubBackward0>) tensor([26478.1719]) tensor(446.6094, grad_fn=<AddBackward0>) 88
# tensor(34741.2773, grad_fn=<SubBackward0>) tensor([23116.2715]) tensor(-2584.5234, grad_fn=<AddBackward0>) 89
# tensor(35841.6680, grad_fn=<SubBackward0>) tensor([4091.3596]) tensor(-1040.1602, grad_fn=<AddBackward0>) 90
# tensor(38775.6250, grad_fn=<SubBackward0>) tensor([20908.8125]) tensor(-2882.1445, grad_fn=<AddBackward0>) 91
# tensor(35765.4844, grad_fn=<SubBackward0>) tensor([14976.7490]) tensor(133.1250, grad_fn=<AddBackward0>) 92
# tensor(45935.7734, grad_fn=<SubBackward0>) tensor([29525.6328]) tensor(-10085.1484, grad_fn=<AddBackward0>) 93
# tensor(39823.1562, grad_fn=<SubBackward0>) tensor([11152.3828]) tensor(-3983.4805, grad_fn=<AddBackward0>) 94
# tensor(42866.8047, grad_fn=<SubBackward0>) tensor([37298.1602]) tensor(-2962.0977, grad_fn=<AddBackward0>) 95
# tensor(47669.3672, grad_fn=<SubBackward0>) tensor([5662.3735]) tensor(-4727.7578, grad_fn=<AddBackward0>) 96
# tensor(59813.9023, grad_fn=<SubBackward0>) tensor([41736.4844]) tensor(-12091.0352, grad_fn=<AddBackward0>) 97
# tensor(56090.7109, grad_fn=<SubBackward0>) tensor([27061.2695]) tensor(3842.5000, grad_fn=<AddBackward0>) 98
# tensor(59346.2031, grad_fn=<SubBackward0>) tensor([44797.1602]) tensor(-3188.4219, grad_fn=<AddBackward0>) 99
# tensor(59580.3984, grad_fn=<SubBackward0>) tensor([15761.2285]) tensor(-145.3164, grad_fn=<AddBackward0>) 100
# tensor(62452.9492, grad_fn=<SubBackward0>) tensor([33097.2617]) tensor(-3029.0742, grad_fn=<AddBackward0>) 101
# tensor(72969.5156, grad_fn=<SubBackward0>) tensor([23582.6016]) tensor(-13545.9336, grad_fn=<AddBackward0>) 102
# tensor(71892.3438, grad_fn=<SubBackward0>) tensor([39173.7266]) tensor(1183.3047, grad_fn=<AddBackward0>) 103
# tensor(72559.7422, grad_fn=<SubBackward0>) tensor([28451.8223]) tensor(523.3828, grad_fn=<AddBackward0>) 104
# tensor(87292.2812, grad_fn=<SubBackward0>) tensor([30743.3691]) tensor(-14635.5625, grad_fn=<AddBackward0>) 105
# tensor(99102.7031, grad_fn=<SubBackward0>) tensor([27009.7656]) tensor(-11706.9609, grad_fn=<AddBackward0>) 106
# tensor(102508.3594, grad_fn=<SubBackward0>) tensor([61998.3359]) tensor(-15118.9531, grad_fn=<AddBackward0>) 107
# tensor(113735.8828, grad_fn=<SubBackward0>) tensor([20192.1641]) tensor(-11145.5391, grad_fn=<AddBackward0>) 108
# tensor(148912.7812, grad_fn=<SubBackward0>) tensor([30601.6816]) tensor(-35090.1641, grad_fn=<AddBackward0>) 109
# tensor(122824.7266, grad_fn=<SubBackward0>) tensor([51508.1562]) tensor(-8994.7656, grad_fn=<AddBackward0>) 110
# tensor(125335.6094, grad_fn=<SubBackward0>) tensor([56667.2734]) tensor(-2357.8594, grad_fn=<AddBackward0>) 111
# tensor(163991.6406, grad_fn=<SubBackward0>) tensor([114248.7969]) tensor(-38575.9766, grad_fn=<AddBackward0>) 112
# tensor(158984.7344, grad_fn=<SubBackward0>) tensor([46620.6406]) tensor(-33581.6406, grad_fn=<AddBackward0>) 113
# tensor(163986.6562, grad_fn=<SubBackward0>) tensor([44016.7930]) tensor(-38559.3047, grad_fn=<AddBackward0>) 114
# tensor(158299.3281, grad_fn=<SubBackward0>) tensor([108982.6719]) tensor(5824.5156, grad_fn=<AddBackward0>) 115
# tensor(199779.7188, grad_fn=<SubBackward0>) tensor([5915.5801]) tensor(-41384.7500, grad_fn=<AddBackward0>) 116
# tensor(180345.5156, grad_fn=<SubBackward0>) tensor([93259.5625]) tensor(-21944.3906, grad_fn=<AddBackward0>) 117
# tensor(191235.2031, grad_fn=<SubBackward0>) tensor([22432.9844]) tensor(-10714.1094, grad_fn=<AddBackward0>) 118
# tensor(203228.2500, grad_fn=<SubBackward0>) tensor([69510.8828]) tensor(-11862.7812, grad_fn=<AddBackward0>) 119
# tensor(190179.3125, grad_fn=<SubBackward0>) tensor([176638.3281]) tensor(1170.2812, grad_fn=<AddBackward0>) 120
# tensor(206162.7188, grad_fn=<SubBackward0>) tensor([34017.3086]) tensor(-15845.1562, grad_fn=<AddBackward0>) 121
# tensor(208790.4219, grad_fn=<SubBackward0>) tensor([194113.9219]) tensor(-2483.4375, grad_fn=<AddBackward0>) 122
# tensor(215355.2500, grad_fn=<SubBackward0>) tensor([151239.2344]) tensor(-9074.0156, grad_fn=<AddBackward0>) 123
# tensor(237544.8906, grad_fn=<SubBackward0>) tensor([189527.5781]) tensor(-21988.7500, grad_fn=<AddBackward0>) 124
# tensor(262979.8125, grad_fn=<SubBackward0>) tensor([165166.7031]) tensor(-25295.5000, grad_fn=<AddBackward0>) 125
# tensor(269676.5625, grad_fn=<SubBackward0>) tensor([101101.4062]) tensor(-31995.6406, grad_fn=<AddBackward0>) 126
# tensor(299692.1875, grad_fn=<SubBackward0>) tensor([191433.2656]) tensor(-29843.8125, grad_fn=<AddBackward0>) 127
# tensor(306456.1250, grad_fn=<SubBackward0>) tensor([56715.0938]) tensor(-36591.5000, grad_fn=<AddBackward0>) 128
# tensor(329413.7500, grad_fn=<SubBackward0>) tensor([39428.2266]) tensor(-22772., grad_fn=<AddBackward0>) 129
# tensor(370331.9688, grad_fn=<SubBackward0>) tensor([158828.8125]) tensor(-40707.3125, grad_fn=<AddBackward0>) 130
# tensor(332352.5312, grad_fn=<SubBackward0>) tensor([319158.3438]) tensor(-2738.5312, grad_fn=<AddBackward0>) 131
# tensor(360472.1875, grad_fn=<SubBackward0>) tensor([88392.0781]) tensor(-27900.5938, grad_fn=<AddBackward0>) 132
# tensor(362675.6250, grad_fn=<SubBackward0>) tensor([253367.8750]) tensor(-2074.5625, grad_fn=<AddBackward0>) 133
# tensor(408493.0625, grad_fn=<SubBackward0>) tensor([128314.5391]) tensor(-45572.5312, grad_fn=<AddBackward0>) 134
# tensor(442155.2812, grad_fn=<SubBackward0>) tensor([400004.6562]) tensor(-33475., grad_fn=<AddBackward0>) 135
# tensor(461284.6562, grad_fn=<SubBackward0>) tensor([151829.5156]) tensor(-52597., grad_fn=<AddBackward0>) 136
# tensor(481671.3750, grad_fn=<SubBackward0>) tensor([138684.5781]) tensor(-20159.6875, grad_fn=<AddBackward0>) 137
# tensor(548840.7500, grad_fn=<SubBackward0>) tensor([153808.6250]) tensor(-66912.4688, grad_fn=<AddBackward0>) 138
# tensor(605696.3750, grad_fn=<SubBackward0>) tensor([149443.3438]) tensor(-56640.0625, grad_fn=<AddBackward0>) 139
# tensor(708115.2500, grad_fn=<SubBackward0>) tensor([382267.3750]) tensor(-102109., grad_fn=<AddBackward0>) 140
# tensor(834966.3125, grad_fn=<SubBackward0>) tensor([613461.3750]) tensor(-126568.7500, grad_fn=<AddBackward0>) 141
# tensor(869178.9375, grad_fn=<SubBackward0>) tensor([549930.0625]) tensor(-33942.2500, grad_fn=<AddBackward0>) 142
# tensor(891477.4375, grad_fn=<SubBackward0>) tensor([445517.0312]) tensor(-56225.2500, grad_fn=<AddBackward0>) 143
# tensor(1026663.4375, grad_fn=<SubBackward0>) tensor([214767.5469]) tensor(-134935.5000, grad_fn=<AddBackward0>) 144
# tensor(1053911.5000, grad_fn=<SubBackward0>) tensor([642413.3125]) tensor(-26915.5000, grad_fn=<AddBackward0>) 145
# tensor(1086962.2500, grad_fn=<SubBackward0>) tensor([115114.]) tensor(-32761., grad_fn=<AddBackward0>) 146
# tensor(1141044.8750, grad_fn=<SubBackward0>) tensor([526465.1875]) tensor(-86829.2500, grad_fn=<AddBackward0>) 147
# tensor(1244468.5000, grad_fn=<SubBackward0>) tensor([247249.6875]) tensor(-103121.6250, grad_fn=<AddBackward0>) 148
# tensor(1339291.8750, grad_fn=<SubBackward0>) tensor([406959.2812]) tensor(-94465., grad_fn=<AddBackward0>) 149
# tensor(1527273.3750, grad_fn=<SubBackward0>) tensor([886679.8125]) tensor(-187627.6250, grad_fn=<AddBackward0>) 150
# tensor(1373822.8750, grad_fn=<SubBackward0>) tensor([611082.1875]) tensor(-34186.6250, grad_fn=<AddBackward0>) 151
# tensor(1423290., grad_fn=<SubBackward0>) tensor([748084.7500]) tensor(-49068.6250, grad_fn=<AddBackward0>) 152
# tensor(1597057.3750, grad_fn=<SubBackward0>) tensor([282623.8125]) tensor(-173400.3750, grad_fn=<AddBackward0>) 153
# tensor(1735408.6250, grad_fn=<SubBackward0>) tensor([1527463.1250]) tensor(-137968.3750, grad_fn=<AddBackward0>) 154
# tensor(1891946.6250, grad_fn=<SubBackward0>) tensor([1144688.8750]) tensor(-156073.5000, grad_fn=<AddBackward0>) 155
# tensor(1822544.1250, grad_fn=<SubBackward0>) tensor([800227.1250]) tensor(-86675.5000, grad_fn=<AddBackward0>) 156
# tensor(1816563.3750, grad_fn=<SubBackward0>) tensor([858008.4375]) tensor(-80689.2500, grad_fn=<AddBackward0>) 157
# tensor(1856875.7500, grad_fn=<SubBackward0>) tensor([1543767.]) tensor(-120993.2500, grad_fn=<AddBackward0>) 158
# tensor(1890077.6250, grad_fn=<SubBackward0>) tensor([313709.6250]) tensor(-32769., grad_fn=<AddBackward0>) 159
# tensor(2072387.5000, grad_fn=<SubBackward0>) tensor([24568.8047]) tensor(-181874.3750, grad_fn=<AddBackward0>) 160
# tensor(2260617.2500, grad_fn=<SubBackward0>) tensor([377629.0938]) tensor(-187701.2500, grad_fn=<AddBackward0>) 161
# tensor(2312940.5000, grad_fn=<SubBackward0>) tensor([1019222.8125]) tensor(-240032.8750, grad_fn=<AddBackward0>) 162
# tensor(2515678.7500, grad_fn=<SubBackward0>) tensor([2213967.]) tensor(-202212.7500, grad_fn=<AddBackward0>) 163
# tensor(2440382., grad_fn=<SubBackward0>) tensor([959010.1875]) tensor(-126896.2500, grad_fn=<AddBackward0>) 164
# tensor(2681480., grad_fn=<SubBackward0>) tensor([551354.9375]) tensor(-240591.5000, grad_fn=<AddBackward0>) 165
# tensor(2721694.2500, grad_fn=<SubBackward0>) tensor([2534196.7500]) tensor(-39691.5000, grad_fn=<AddBackward0>) 166
# tensor(2953835.2500, grad_fn=<SubBackward0>) tensor([1730887.6250]) tensor(-231584.2500, grad_fn=<AddBackward0>) 167
# tensor(2913107.5000, grad_fn=<SubBackward0>) tensor([2528250.]) tensor(-190881.7500, grad_fn=<AddBackward0>) 168
# tensor(3076943.7500, grad_fn=<SubBackward0>) tensor([1043030.2500]) tensor(-163215.5000, grad_fn=<AddBackward0>) 169
# tensor(3426185., grad_fn=<SubBackward0>) tensor([2309276.7500]) tensor(-348679., grad_fn=<AddBackward0>) 170
# tensor(3509697.2500, grad_fn=<SubBackward0>) tensor([844335.1250]) tensor(-82896.5000, grad_fn=<AddBackward0>) 171
# tensor(3784637.7500, grad_fn=<SubBackward0>) tensor([2768591.2500]) tensor(-274305.2500, grad_fn=<AddBackward0>) 172
# tensor(4093424.5000, grad_fn=<SubBackward0>) tensor([2799544.7500]) tensor(-308081.2500, grad_fn=<AddBackward0>) 173
# tensor(4298263.5000, grad_fn=<SubBackward0>) tensor([3616645.5000]) tensor(-204124.2500, grad_fn=<AddBackward0>) 174
# tensor(4596233.5000, grad_fn=<SubBackward0>) tensor([3979194.]) tensor(-297240., grad_fn=<AddBackward0>) 175
# tensor(5213767., grad_fn=<SubBackward0>) tensor([3982627.7500]) tensor(-616719., grad_fn=<AddBackward0>) 176
# tensor(5553130., grad_fn=<SubBackward0>) tensor([2285837.7500]) tensor(-338572.5000, grad_fn=<AddBackward0>) 177
# tensor(6020172., grad_fn=<SubBackward0>) tensor([4581111.]) tensor(-466212.5000, grad_fn=<AddBackward0>) 178
# tensor(5885073.5000, grad_fn=<SubBackward0>) tensor([512033.4688]) tensor(-331129.5000, grad_fn=<AddBackward0>) 179
# tensor(6098029.5000, grad_fn=<SubBackward0>) tensor([2283214.2500]) tensor(-544074.5000, grad_fn=<AddBackward0>) 180
# tensor(6317677., grad_fn=<SubBackward0>) tensor([11054.3398]) tensor(-218790.5000, grad_fn=<AddBackward0>) 181
# tensor(6553737.5000, grad_fn=<SubBackward0>) tensor([687136.4375]) tensor(-454861., grad_fn=<AddBackward0>) 182
# tensor(6991403.5000, grad_fn=<SubBackward0>) tensor([696352.5000]) tensor(-436868., grad_fn=<AddBackward0>) 183
# tensor(7255868., grad_fn=<SubBackward0>) tensor([147089.5938]) tensor(-701339., grad_fn=<AddBackward0>) 184
# tensor(7970251., grad_fn=<SubBackward0>) tensor([3597399.2500]) tensor(-713521.5000, grad_fn=<AddBackward0>) 185
# tensor(8779973., grad_fn=<SubBackward0>) tensor([243696.]) tensor(-808663.5000, grad_fn=<AddBackward0>) 186
# tensor(9297910., grad_fn=<SubBackward0>) tensor([808624.3125]) tensor(-516913., grad_fn=<AddBackward0>) 187
# tensor(9615150., grad_fn=<SubBackward0>) tensor([7631857.5000]) tensor(-834178., grad_fn=<AddBackward0>) 188
# tensor(9675318., grad_fn=<SubBackward0>) tensor([9265187.]) tensor(-59113., grad_fn=<AddBackward0>) 189
# tensor(10325936., grad_fn=<SubBackward0>) tensor([6864808.]) tensor(-649493., grad_fn=<AddBackward0>) 190
# tensor(11044575., grad_fn=<SubBackward0>) tensor([4435231.]) tensor(-717580., grad_fn=<AddBackward0>) 191
# tensor(11147092., grad_fn=<SubBackward0>) tensor([8951924.]) tensor(-820097., grad_fn=<AddBackward0>) 192
# tensor(12245392., grad_fn=<SubBackward0>) tensor([2449488.]) tensor(-1097155., grad_fn=<AddBackward0>) 193
# tensor(13305419., grad_fn=<SubBackward0>) tensor([5162059.5000]) tensor(-1058851., grad_fn=<AddBackward0>) 194
# tensor(14717159., grad_fn=<SubBackward0>) tensor([9527310.]) tensor(-1410436., grad_fn=<AddBackward0>) 195
# tensor(14643855., grad_fn=<SubBackward0>) tensor([294982.7812]) tensor(-1337114., grad_fn=<AddBackward0>) 196
# tensor(14208055., grad_fn=<SubBackward0>) tensor([3356010.2500]) tensor(-901329., grad_fn=<AddBackward0>) 197
# tensor(14722907., grad_fn=<SubBackward0>) tensor([28868.2227]) tensor(-513477., grad_fn=<AddBackward0>) 198
# tensor(16020483., grad_fn=<SubBackward0>) tensor([9524347.]) tensor(-1296322., grad_fn=<AddBackward0>) 199
# tensor(17277568., grad_fn=<SubBackward0>) tensor([11766359.]) tensor(-1255567., grad_fn=<AddBackward0>) 200
# tensor(19018454., grad_fn=<SubBackward0>) tensor([5730155.]) tensor(-1739384., grad_fn=<AddBackward0>) 201
# tensor(19864276., grad_fn=<SubBackward0>) tensor([8044876.]) tensor(-844254., grad_fn=<AddBackward0>) 202
# tensor(21817454., grad_fn=<SubBackward0>) tensor([16046935.]) tensor(-1951544., grad_fn=<AddBackward0>) 203
# tensor(24964146., grad_fn=<SubBackward0>) tensor([6769739.]) tensor(-3145040., grad_fn=<AddBackward0>) 204
# tensor(27678392., grad_fn=<SubBackward0>) tensor([2830445.7500]) tensor(-2712302., grad_fn=<AddBackward0>) 205
# tensor(31339510., grad_fn=<SubBackward0>) tensor([6688275.5000]) tensor(-3659294., grad_fn=<AddBackward0>) 206
# tensor(33738152., grad_fn=<SubBackward0>) tensor([21854394.]) tensor(-2396736., grad_fn=<AddBackward0>) 207
# tensor(36236904., grad_fn=<SubBackward0>) tensor([8635450.]) tensor(-2496748., grad_fn=<AddBackward0>) 208
# tensor(39017736., grad_fn=<SubBackward0>) tensor([17995294.]) tensor(-2778868., grad_fn=<AddBackward0>) 209
# tensor(42251284., grad_fn=<SubBackward0>) tensor([11532693.]) tensor(-3231536., grad_fn=<AddBackward0>) 210
# tensor(47197352., grad_fn=<SubBackward0>) tensor([41112448.]) tensor(-4943920., grad_fn=<AddBackward0>) 211
# tensor(44213428., grad_fn=<SubBackward0>) tensor([31247448.]) tensor(-1959972., grad_fn=<AddBackward0>) 212
# tensor(48004472., grad_fn=<SubBackward0>) tensor([14712975.]) tensor(-3788804., grad_fn=<AddBackward0>) 213
# tensor(47030108., grad_fn=<SubBackward0>) tensor([4837629.5000]) tensor(-2814448., grad_fn=<AddBackward0>) 214
# tensor(51542664., grad_fn=<SubBackward0>) tensor([28523706.]) tensor(-4510144., grad_fn=<AddBackward0>) 215
# tensor(51463760., grad_fn=<SubBackward0>) tensor([5852917.]) tensor(-4431228., grad_fn=<AddBackward0>) 216
# tensor(55125124., grad_fn=<SubBackward0>) tensor([38097828.]) tensor(-3658840., grad_fn=<AddBackward0>) 217
# tensor(61605276., grad_fn=<SubBackward0>) tensor([4391353.]) tensor(-6477552., grad_fn=<AddBackward0>) 218
# tensor(66000616., grad_fn=<SubBackward0>) tensor([15020008.]) tensor(-4392660., grad_fn=<AddBackward0>) 219
# tensor(70356416., grad_fn=<SubBackward0>) tensor([18009188.]) tensor(-4352872., grad_fn=<AddBackward0>) 220
# tensor(76191752., grad_fn=<SubBackward0>) tensor([69052616.]) tensor(-5832424., grad_fn=<AddBackward0>) 221
# tensor(82842336., grad_fn=<SubBackward0>) tensor([483713.5000]) tensor(-6647440., grad_fn=<AddBackward0>) 222
# tensor(90997144., grad_fn=<SubBackward0>) tensor([66792460.]) tensor(-8151600., grad_fn=<AddBackward0>) 223
# tensor(88572296., grad_fn=<SubBackward0>) tensor([7645230.5000]) tensor(-5726760., grad_fn=<AddBackward0>) 224
# tensor(89914576., grad_fn=<SubBackward0>) tensor([10286061.]) tensor(-7069008., grad_fn=<AddBackward0>) 225
# tensor(92819416., grad_fn=<SubBackward0>) tensor([29284072.]) tensor(-2901616., grad_fn=<AddBackward0>) 226
# tensor(97377736., grad_fn=<SubBackward0>) tensor([33136276.]) tensor(-7459928., grad_fn=<AddBackward0>) 227
# tensor(1.0901e+08, grad_fn=<SubBackward0>) tensor([82204168.]) tensor(-11625312., grad_fn=<AddBackward0>) 228
# tensor(1.0735e+08, grad_fn=<SubBackward0>) tensor([74700608.]) tensor(-9973376., grad_fn=<AddBackward0>) 229
# tensor(1.0412e+08, grad_fn=<SubBackward0>) tensor([27256178.]) tensor(-6736104., grad_fn=<AddBackward0>) 230
# tensor(1.1179e+08, grad_fn=<SubBackward0>) tensor([22474586.]) tensor(-7671272., grad_fn=<AddBackward0>) 231
# tensor(1.1891e+08, grad_fn=<SubBackward0>) tensor([75401152.]) tensor(-7109800., grad_fn=<AddBackward0>) 232
# tensor(1.2660e+08, grad_fn=<SubBackward0>) tensor([9763437.]) tensor(-7695552., grad_fn=<AddBackward0>) 233
# tensor(1.3668e+08, grad_fn=<SubBackward0>) tensor([1.1361e+08]) tensor(-10070224., grad_fn=<AddBackward0>) 234
# tensor(1.4747e+08, grad_fn=<SubBackward0>) tensor([26004186.]) tensor(-10790944., grad_fn=<AddBackward0>) 235
# tensor(1.6005e+08, grad_fn=<SubBackward0>) tensor([7346519.]) tensor(-12567392., grad_fn=<AddBackward0>) 236
# tensor(1.7219e+08, grad_fn=<SubBackward0>) tensor([1.4645e+08]) tensor(-12141744., grad_fn=<AddBackward0>) 237
# tensor(1.8752e+08, grad_fn=<SubBackward0>) tensor([1.0209e+08]) tensor(-15321584., grad_fn=<AddBackward0>) 238
# tensor(1.8849e+08, grad_fn=<SubBackward0>) tensor([1.4889e+08]) tensor(-16288928., grad_fn=<AddBackward0>) 239
# tensor(1.9187e+08, grad_fn=<SubBackward0>) tensor([1.0781e+08]) tensor(-19674272., grad_fn=<AddBackward0>) 240
# tensor(2.0748e+08, grad_fn=<SubBackward0>) tensor([1.2172e+08]) tensor(-15607952., grad_fn=<AddBackward0>) 241
# tensor(2.2761e+08, grad_fn=<SubBackward0>) tensor([1.7215e+08]) tensor(-20120704., grad_fn=<AddBackward0>) 242
# tensor(2.4467e+08, grad_fn=<SubBackward0>) tensor([97868296.]) tensor(-17058608., grad_fn=<AddBackward0>) 243
# tensor(2.4753e+08, grad_fn=<SubBackward0>) tensor([45206924.]) tensor(-19917392., grad_fn=<AddBackward0>) 244
# tensor(2.6479e+08, grad_fn=<SubBackward0>) tensor([2.4396e+08]) tensor(-17249136., grad_fn=<AddBackward0>) 245
# tensor(2.9159e+08, grad_fn=<SubBackward0>) tensor([1.6558e+08]) tensor(-26800032., grad_fn=<AddBackward0>) 246
# tensor(3.1940e+08, grad_fn=<SubBackward0>) tensor([25167726.]) tensor(-27805920., grad_fn=<AddBackward0>) 247
# tensor(3.4856e+08, grad_fn=<SubBackward0>) tensor([90753648.]) tensor(-29151872., grad_fn=<AddBackward0>) 248
# tensor(3.8100e+08, grad_fn=<SubBackward0>) tensor([3.0016e+08]) tensor(-32430624., grad_fn=<AddBackward0>) 249
# tensor(4.1156e+08, grad_fn=<SubBackward0>) tensor([1.7891e+08]) tensor(-30556768., grad_fn=<AddBackward0>) 250
# tensor(4.0603e+08, grad_fn=<SubBackward0>) tensor([2.6508e+08]) tensor(-25019360., grad_fn=<AddBackward0>) 251
# tensor(4.5265e+08, grad_fn=<SubBackward0>) tensor([1.2397e+08]) tensor(-46621056., grad_fn=<AddBackward0>) 252
# tensor(4.7931e+08, grad_fn=<SubBackward0>) tensor([3.1081e+08]) tensor(-26650208., grad_fn=<AddBackward0>) 253
# tensor(5.0618e+08, grad_fn=<SubBackward0>) tensor([1.3608e+08]) tensor(-26864096., grad_fn=<AddBackward0>) 254
# tensor(5.4820e+08, grad_fn=<SubBackward0>) tensor([3.4755e+08]) tensor(-42006464., grad_fn=<AddBackward0>) 255
# tensor(5.9460e+08, grad_fn=<SubBackward0>) tensor([4.6138e+08]) tensor(-46396608., grad_fn=<AddBackward0>) 256
# tensor(5.9906e+08, grad_fn=<SubBackward0>) tensor([3.8973e+08]) tensor(-50857152., grad_fn=<AddBackward0>) 257
# tensor(6.4932e+08, grad_fn=<SubBackward0>) tensor([4.0758e+08]) tensor(-50244864., grad_fn=<AddBackward0>) 258
# tensor(6.2923e+08, grad_fn=<SubBackward0>) tensor([87765536.]) tensor(-30156032., grad_fn=<AddBackward0>) 259
# tensor(6.9232e+08, grad_fn=<SubBackward0>) tensor([38024512.]) tensor(-63082944., grad_fn=<AddBackward0>) 260
# tensor(7.5841e+08, grad_fn=<SubBackward0>) tensor([3.7116e+08]) tensor(-66081408., grad_fn=<AddBackward0>) 261
# tensor(8.2260e+08, grad_fn=<SubBackward0>) tensor([3.1826e+08]) tensor(-64184960., grad_fn=<AddBackward0>) 262
# tensor(7.9950e+08, grad_fn=<SubBackward0>) tensor([4.8988e+08]) tensor(-41083136., grad_fn=<AddBackward0>) 263
# tensor(8.1490e+08, grad_fn=<SubBackward0>) tensor([1.9559e+08]) tensor(-56481472., grad_fn=<AddBackward0>) 264
# tensor(8.8479e+08, grad_fn=<SubBackward0>) tensor([2.2786e+08]) tensor(-69878528., grad_fn=<AddBackward0>) 265
# tensor(9.6848e+08, grad_fn=<SubBackward0>) tensor([4.9165e+08]) tensor(-83683968., grad_fn=<AddBackward0>) 266
# tensor(1.0572e+09, grad_fn=<SubBackward0>) tensor([4.9488e+08]) tensor(-88688384., grad_fn=<AddBackward0>) 267
# tensor(1.1403e+09, grad_fn=<SubBackward0>) tensor([9.1304e+08]) tensor(-83060096., grad_fn=<AddBackward0>) 268
# tensor(1.2545e+09, grad_fn=<SubBackward0>) tensor([4.2238e+08]) tensor(-1.1427e+08, grad_fn=<AddBackward0>) 269
# tensor(1.3293e+09, grad_fn=<SubBackward0>) tensor([5.7377e+08]) tensor(-74730368., grad_fn=<AddBackward0>) 270
# tensor(1.4388e+09, grad_fn=<SubBackward0>) tensor([73695696.]) tensor(-1.0953e+08, grad_fn=<AddBackward0>) 271
# tensor(1.4362e+09, grad_fn=<SubBackward0>) tensor([157513.4531]) tensor(-1.0694e+08, grad_fn=<AddBackward0>) 272
# tensor(1.5709e+09, grad_fn=<SubBackward0>) tensor([7.1894e+08]) tensor(-1.3467e+08, grad_fn=<AddBackward0>) 273
# tensor(1.7037e+09, grad_fn=<SubBackward0>) tensor([6.4839e+08]) tensor(-1.3272e+08, grad_fn=<AddBackward0>) 274
# tensor(1.8728e+09, grad_fn=<SubBackward0>) tensor([1.4542e+09]) tensor(-1.6913e+08, grad_fn=<AddBackward0>) 275
# tensor(2.0286e+09, grad_fn=<SubBackward0>) tensor([1.6524e+08]) tensor(-1.5580e+08, grad_fn=<AddBackward0>) 276
# tensor(2.0720e+09, grad_fn=<SubBackward0>) tensor([6.0835e+08]) tensor(-1.9923e+08, grad_fn=<AddBackward0>) 277
# tensor(2.0312e+09, grad_fn=<SubBackward0>) tensor([1.4311e+09]) tensor(-1.5837e+08, grad_fn=<AddBackward0>) 278
# tensor(2.2121e+09, grad_fn=<SubBackward0>) tensor([1.0609e+08]) tensor(-1.8091e+08, grad_fn=<AddBackward0>) 279
# tensor(2.3928e+09, grad_fn=<SubBackward0>) tensor([2.0817e+09]) tensor(-1.8072e+08, grad_fn=<AddBackward0>) 280
# tensor(2.5574e+09, grad_fn=<SubBackward0>) tensor([7.1562e+08]) tensor(-1.6451e+08, grad_fn=<AddBackward0>) 281
# tensor(2.7855e+09, grad_fn=<SubBackward0>) tensor([2.0481e+09]) tensor(-2.2808e+08, grad_fn=<AddBackward0>) 282
# tensor(3.0630e+09, grad_fn=<SubBackward0>) tensor([2.5427e+09]) tensor(-2.7753e+08, grad_fn=<AddBackward0>) 283
# tensor(3.3028e+09, grad_fn=<SubBackward0>) tensor([6.2010e+08]) tensor(-2.3973e+08, grad_fn=<AddBackward0>) 284
# tensor(3.3786e+09, grad_fn=<SubBackward0>) tensor([4.8594e+08]) tensor(-3.1553e+08, grad_fn=<AddBackward0>) 285
# tensor(3.6703e+09, grad_fn=<SubBackward0>) tensor([3.2165e+09]) tensor(-2.9170e+08, grad_fn=<AddBackward0>) 286
# tensor(3.9738e+09, grad_fn=<SubBackward0>) tensor([2.6721e+09]) tensor(-3.0344e+08, grad_fn=<AddBackward0>) 287
# tensor(4.3116e+09, grad_fn=<SubBackward0>) tensor([1.4421e+09]) tensor(-3.3782e+08, grad_fn=<AddBackward0>) 288
# tensor(4.6636e+09, grad_fn=<SubBackward0>) tensor([3.5724e+09]) tensor(-3.5201e+08, grad_fn=<AddBackward0>) 289
# tensor(5.0077e+09, grad_fn=<SubBackward0>) tensor([3.6299e+08]) tensor(-3.4404e+08, grad_fn=<AddBackward0>) 290
# tensor(5.0987e+09, grad_fn=<SubBackward0>) tensor([2.1212e+09]) tensor(-4.3501e+08, grad_fn=<AddBackward0>) 291
# tensor(5.5402e+09, grad_fn=<SubBackward0>) tensor([3.4199e+09]) tensor(-4.4150e+08, grad_fn=<AddBackward0>) 292
# tensor(5.5427e+09, grad_fn=<SubBackward0>) tensor([5.7812e+08]) tensor(-4.4400e+08, grad_fn=<AddBackward0>) 293
# tensor(5.9662e+09, grad_fn=<SubBackward0>) tensor([1.8234e+09]) tensor(-4.2350e+08, grad_fn=<AddBackward0>) 294
# tensor(6.4430e+09, grad_fn=<SubBackward0>) tensor([5.2127e+09]) tensor(-4.7676e+08, grad_fn=<AddBackward0>) 295
# tensor(6.9420e+09, grad_fn=<SubBackward0>) tensor([1.2377e+09]) tensor(-4.9899e+08, grad_fn=<AddBackward0>) 296
# tensor(7.4930e+09, grad_fn=<SubBackward0>) tensor([6.7469e+09]) tensor(-5.5094e+08, grad_fn=<AddBackward0>) 297
# tensor(8.0651e+09, grad_fn=<SubBackward0>) tensor([6.1571e+09]) tensor(-5.7204e+08, grad_fn=<AddBackward0>) 298
# tensor(8.0828e+09, grad_fn=<SubBackward0>) tensor([6.2073e+09]) tensor(-5.8980e+08, grad_fn=<AddBackward0>) 299
# tensor(8.7828e+09, grad_fn=<SubBackward0>) tensor([7.6753e+09]) tensor(-6.9994e+08, grad_fn=<AddBackward0>) 300
# tensor(9.5296e+09, grad_fn=<SubBackward0>) tensor([5.6771e+09]) tensor(-7.4683e+08, grad_fn=<AddBackward0>) 301
# tensor(1.0333e+10, grad_fn=<SubBackward0>) tensor([5.6364e+09]) tensor(-8.0348e+08, grad_fn=<AddBackward0>) 302
# tensor(1.1215e+10, grad_fn=<SubBackward0>) tensor([1.5055e+09]) tensor(-8.8191e+08, grad_fn=<AddBackward0>) 303
# tensor(1.1161e+10, grad_fn=<SubBackward0>) tensor([9.4617e+09]) tensor(-8.2771e+08, grad_fn=<AddBackward0>) 304
# tensor(1.2126e+10, grad_fn=<SubBackward0>) tensor([1.9393e+09]) tensor(-9.6520e+08, grad_fn=<AddBackward0>) 305
# tensor(1.1988e+10, grad_fn=<SubBackward0>) tensor([1.0563e+10]) tensor(-8.2724e+08, grad_fn=<AddBackward0>) 306
# tensor(1.3085e+10, grad_fn=<SubBackward0>) tensor([1.1418e+10]) tensor(-1.0965e+09, grad_fn=<AddBackward0>) 307
# tensor(1.4215e+10, grad_fn=<SubBackward0>) tensor([7.2804e+09]) tensor(-1.1302e+09, grad_fn=<AddBackward0>) 308
# tensor(1.5443e+10, grad_fn=<SubBackward0>) tensor([7.3400e+08]) tensor(-1.2282e+09, grad_fn=<AddBackward0>) 309
# tensor(1.6767e+10, grad_fn=<SubBackward0>) tensor([7.0100e+09]) tensor(-1.3232e+09, grad_fn=<AddBackward0>) 310
# tensor(1.8112e+10, grad_fn=<SubBackward0>) tensor([1.3828e+09]) tensor(-1.3450e+09, grad_fn=<AddBackward0>) 311
# tensor(1.9563e+10, grad_fn=<SubBackward0>) tensor([1.1092e+10]) tensor(-1.4516e+09, grad_fn=<AddBackward0>) 312
# tensor(2.1099e+10, grad_fn=<SubBackward0>) tensor([1.2988e+10]) tensor(-1.5361e+09, grad_fn=<AddBackward0>) 313
# tensor(2.2949e+10, grad_fn=<SubBackward0>) tensor([2.0348e+10]) tensor(-1.8493e+09, grad_fn=<AddBackward0>) 314
# tensor(2.2848e+10, grad_fn=<SubBackward0>) tensor([3.1734e+09]) tensor(-1.7481e+09, grad_fn=<AddBackward0>) 315
# tensor(2.2920e+10, grad_fn=<SubBackward0>) tensor([1.2477e+10]) tensor(-1.8205e+09, grad_fn=<AddBackward0>) 316
# tensor(2.5010e+10, grad_fn=<SubBackward0>) tensor([1.9323e+10]) tensor(-2.0902e+09, grad_fn=<AddBackward0>) 317
# tensor(2.7242e+10, grad_fn=<SubBackward0>) tensor([1.9234e+10]) tensor(-2.2321e+09, grad_fn=<AddBackward0>) 318
# tensor(2.9597e+10, grad_fn=<SubBackward0>) tensor([1.3791e+10]) tensor(-2.3542e+09, grad_fn=<AddBackward0>) 319
# tensor(2.9376e+10, grad_fn=<SubBackward0>) tensor([6.2263e+09]) tensor(-2.1332e+09, grad_fn=<AddBackward0>) 320
# tensor(2.9392e+10, grad_fn=<SubBackward0>) tensor([5.1059e+09]) tensor(-2.1497e+09, grad_fn=<AddBackward0>) 321
# tensor(2.9514e+10, grad_fn=<SubBackward0>) tensor([1.8564e+10]) tensor(-2.2718e+09, grad_fn=<AddBackward0>) 322
# tensor(3.2294e+10, grad_fn=<SubBackward0>) tensor([7.5096e+09]) tensor(-2.7801e+09, grad_fn=<AddBackward0>) 323
# tensor(3.5133e+10, grad_fn=<SubBackward0>) tensor([8.4619e+08]) tensor(-2.8389e+09, grad_fn=<AddBackward0>) 324
# tensor(3.8034e+10, grad_fn=<SubBackward0>) tensor([1.9462e+10]) tensor(-2.9011e+09, grad_fn=<AddBackward0>) 325
# tensor(4.1163e+10, grad_fn=<SubBackward0>) tensor([8.3940e+09]) tensor(-3.1290e+09, grad_fn=<AddBackward0>) 326
# tensor(4.4329e+10, grad_fn=<SubBackward0>) tensor([2.1231e+10]) tensor(-3.1650e+09, grad_fn=<AddBackward0>) 327
# tensor(4.4887e+10, grad_fn=<SubBackward0>) tensor([1.6858e+10]) tensor(-3.7235e+09, grad_fn=<AddBackward0>) 328
# tensor(4.8827e+10, grad_fn=<SubBackward0>) tensor([2.0058e+09]) tensor(-3.9397e+09, grad_fn=<AddBackward0>) 329
# tensor(5.2780e+10, grad_fn=<SubBackward0>) tensor([4.7802e+10]) tensor(-3.9531e+09, grad_fn=<AddBackward0>) 330
# tensor(5.7295e+10, grad_fn=<SubBackward0>) tensor([1.1383e+10]) tensor(-4.5152e+09, grad_fn=<AddBackward0>) 331
# tensor(6.2074e+10, grad_fn=<SubBackward0>) tensor([1.0907e+10]) tensor(-4.7783e+09, grad_fn=<AddBackward0>) 332
# tensor(6.6786e+10, grad_fn=<SubBackward0>) tensor([2.9822e+10]) tensor(-4.7123e+09, grad_fn=<AddBackward0>) 333
# tensor(6.7065e+10, grad_fn=<SubBackward0>) tensor([1.8864e+10]) tensor(-4.9909e+09, grad_fn=<AddBackward0>) 334
# tensor(7.2559e+10, grad_fn=<SubBackward0>) tensor([2.5600e+10]) tensor(-5.4942e+09, grad_fn=<AddBackward0>) 335
# tensor(7.2330e+10, grad_fn=<SubBackward0>) tensor([1.6472e+10]) tensor(-5.2657e+09, grad_fn=<AddBackward0>) 336
# tensor(7.3083e+10, grad_fn=<SubBackward0>) tensor([5.4555e+10]) tensor(-6.0183e+09, grad_fn=<AddBackward0>) 337
# tensor(7.9369e+10, grad_fn=<SubBackward0>) tensor([6.7607e+10]) tensor(-6.2856e+09, grad_fn=<AddBackward0>) 338
# tensor(7.9233e+10, grad_fn=<SubBackward0>) tensor([2.1525e+10]) tensor(-6.1496e+09, grad_fn=<AddBackward0>) 339
# tensor(8.5931e+10, grad_fn=<SubBackward0>) tensor([2.2900e+10]) tensor(-6.6982e+09, grad_fn=<AddBackward0>) 340
# tensor(9.3261e+10, grad_fn=<SubBackward0>) tensor([3.3030e+10]) tensor(-7.3294e+09, grad_fn=<AddBackward0>) 341
# tensor(1.0006e+11, grad_fn=<SubBackward0>) tensor([7.5035e+10]) tensor(-6.8032e+09, grad_fn=<AddBackward0>) 342
# tensor(1.0767e+11, grad_fn=<SubBackward0>) tensor([8.4929e+10]) tensor(-7.6073e+09, grad_fn=<AddBackward0>) 343
# tensor(1.1662e+11, grad_fn=<SubBackward0>) tensor([9.4783e+10]) tensor(-8.9468e+09, grad_fn=<AddBackward0>) 344
# tensor(1.2623e+11, grad_fn=<SubBackward0>) tensor([2.1272e+10]) tensor(-9.6075e+09, grad_fn=<AddBackward0>) 345
# tensor(1.3653e+11, grad_fn=<SubBackward0>) tensor([1.1750e+11]) tensor(-1.0307e+10, grad_fn=<AddBackward0>) 346
# tensor(1.4852e+11, grad_fn=<SubBackward0>) tensor([4.3196e+10]) tensor(-1.1991e+10, grad_fn=<AddBackward0>) 347
# tensor(1.6033e+11, grad_fn=<SubBackward0>) tensor([6.5451e+10]) tensor(-1.1803e+10, grad_fn=<AddBackward0>) 348
# tensor(1.7318e+11, grad_fn=<SubBackward0>) tensor([4.5412e+08]) tensor(-1.2847e+10, grad_fn=<AddBackward0>) 349
# tensor(1.8753e+11, grad_fn=<SubBackward0>) tensor([1.2988e+11]) tensor(-1.4354e+10, grad_fn=<AddBackward0>) 350
# tensor(1.8693e+11, grad_fn=<SubBackward0>) tensor([1.0545e+11]) tensor(-1.3757e+10, grad_fn=<AddBackward0>) 351
# tensor(2.0142e+11, grad_fn=<SubBackward0>) tensor([1.5250e+11]) tensor(-1.4488e+10, grad_fn=<AddBackward0>) 352
# tensor(2.1817e+11, grad_fn=<SubBackward0>) tensor([9.6703e+10]) tensor(-1.6754e+10, grad_fn=<AddBackward0>) 353
# tensor(2.3594e+11, grad_fn=<SubBackward0>) tensor([1.3623e+11]) tensor(-1.7765e+10, grad_fn=<AddBackward0>) 354
# tensor(2.3571e+11, grad_fn=<SubBackward0>) tensor([3.3305e+10]) tensor(-1.7538e+10, grad_fn=<AddBackward0>) 355
# tensor(2.5465e+11, grad_fn=<SubBackward0>) tensor([1.9755e+11]) tensor(-1.8939e+10, grad_fn=<AddBackward0>) 356
# tensor(2.7523e+11, grad_fn=<SubBackward0>) tensor([2.4166e+11]) tensor(-2.0576e+10, grad_fn=<AddBackward0>) 357
# tensor(2.9732e+11, grad_fn=<SubBackward0>) tensor([2.6410e+11]) tensor(-2.2096e+10, grad_fn=<AddBackward0>) 358
# tensor(3.2100e+11, grad_fn=<SubBackward0>) tensor([5.0909e+10]) tensor(-2.3676e+10, grad_fn=<AddBackward0>) 359
# tensor(3.4723e+11, grad_fn=<SubBackward0>) tensor([1.3005e+11]) tensor(-2.6226e+10, grad_fn=<AddBackward0>) 360
# tensor(3.7547e+11, grad_fn=<SubBackward0>) tensor([8.5669e+10]) tensor(-2.8243e+10, grad_fn=<AddBackward0>) 361
# tensor(3.7701e+11, grad_fn=<SubBackward0>) tensor([1.8309e+11]) tensor(-2.9780e+10, grad_fn=<AddBackward0>) 362
# tensor(4.0999e+11, grad_fn=<SubBackward0>) tensor([1.3570e+11]) tensor(-3.2984e+10, grad_fn=<AddBackward0>) 363
# tensor(4.0859e+11, grad_fn=<SubBackward0>) tensor([2.6676e+11]) tensor(-3.1583e+10, grad_fn=<AddBackward0>) 364
# tensor(4.0979e+11, grad_fn=<SubBackward0>) tensor([2.5797e+10]) tensor(-3.2780e+10, grad_fn=<AddBackward0>) 365
# tensor(4.4280e+11, grad_fn=<SubBackward0>) tensor([3.6348e+11]) tensor(-3.3009e+10, grad_fn=<AddBackward0>) 366
# tensor(4.8134e+11, grad_fn=<SubBackward0>) tensor([6.7062e+10]) tensor(-3.8538e+10, grad_fn=<AddBackward0>) 367
# tensor(5.2077e+11, grad_fn=<SubBackward0>) tensor([4.0096e+10]) tensor(-3.9432e+10, grad_fn=<AddBackward0>) 368
# tensor(5.6305e+11, grad_fn=<SubBackward0>) tensor([4.7300e+11]) tensor(-4.2284e+10, grad_fn=<AddBackward0>) 369
# tensor(6.0870e+11, grad_fn=<SubBackward0>) tensor([5.0242e+11]) tensor(-4.5652e+10, grad_fn=<AddBackward0>) 370
# tensor(6.5746e+11, grad_fn=<SubBackward0>) tensor([2.1295e+11]) tensor(-4.8755e+10, grad_fn=<AddBackward0>) 371
# tensor(7.1575e+11, grad_fn=<SubBackward0>) tensor([6.4007e+11]) tensor(-5.8287e+10, grad_fn=<AddBackward0>) 372
# tensor(7.1153e+11, grad_fn=<SubBackward0>) tensor([4.0869e+11]) tensor(-5.4068e+10, grad_fn=<AddBackward0>) 373
# tensor(7.6945e+11, grad_fn=<SubBackward0>) tensor([2.1215e+11]) tensor(-5.7919e+10, grad_fn=<AddBackward0>) 374
# tensor(8.3360e+11, grad_fn=<SubBackward0>) tensor([2.9503e+11]) tensor(-6.4156e+10, grad_fn=<AddBackward0>) 375
# tensor(9.0220e+11, grad_fn=<SubBackward0>) tensor([1.8607e+11]) tensor(-6.8600e+10, grad_fn=<AddBackward0>) 376
# tensor(8.9958e+11, grad_fn=<SubBackward0>) tensor([5.5928e+11]) tensor(-6.5979e+10, grad_fn=<AddBackward0>) 377
# tensor(9.7537e+11, grad_fn=<SubBackward0>) tensor([4.2575e+11]) tensor(-7.5787e+10, grad_fn=<AddBackward0>) 378
# tensor(1.0555e+12, grad_fn=<SubBackward0>) tensor([4.4315e+10]) tensor(-8.0175e+10, grad_fn=<AddBackward0>) 379
# tensor(1.1423e+12, grad_fn=<SubBackward0>) tensor([3.5355e+11]) tensor(-8.6723e+10, grad_fn=<AddBackward0>) 380
# tensor(1.1428e+12, grad_fn=<SubBackward0>) tensor([9.2106e+10]) tensor(-8.7212e+10, grad_fn=<AddBackward0>) 381
# tensor(1.2377e+12, grad_fn=<SubBackward0>) tensor([9.5534e+11]) tensor(-9.4898e+10, grad_fn=<AddBackward0>) 382
# tensor(1.2376e+12, grad_fn=<SubBackward0>) tensor([1.0149e+12]) tensor(-9.4793e+10, grad_fn=<AddBackward0>) 383
# tensor(1.2319e+12, grad_fn=<SubBackward0>) tensor([7.1173e+11]) tensor(-8.9117e+10, grad_fn=<AddBackward0>) 384
# tensor(1.2372e+12, grad_fn=<SubBackward0>) tensor([1.0456e+12]) tensor(-9.4485e+10, grad_fn=<AddBackward0>) 385
# tensor(1.2362e+12, grad_fn=<SubBackward0>) tensor([9.5691e+11]) tensor(-9.3411e+10, grad_fn=<AddBackward0>) 386
# tensor(1.3366e+12, grad_fn=<SubBackward0>) tensor([2.4678e+11]) tensor(-1.0039e+11, grad_fn=<AddBackward0>) 387
# tensor(1.4453e+12, grad_fn=<SubBackward0>) tensor([1.3316e+12]) tensor(-1.0870e+11, grad_fn=<AddBackward0>) 388
# tensor(1.5593e+12, grad_fn=<SubBackward0>) tensor([2.7445e+11]) tensor(-1.1404e+11, grad_fn=<AddBackward0>) 389
# tensor(1.6869e+12, grad_fn=<SubBackward0>) tensor([1.1590e+12]) tensor(-1.2757e+11, grad_fn=<AddBackward0>) 390
# tensor(1.8188e+12, grad_fn=<SubBackward0>) tensor([1.5006e+12]) tensor(-1.3191e+11, grad_fn=<AddBackward0>) 391
# tensor(1.9646e+12, grad_fn=<SubBackward0>) tensor([2.5216e+11]) tensor(-1.4583e+11, grad_fn=<AddBackward0>) 392
# tensor(2.1284e+12, grad_fn=<SubBackward0>) tensor([1.5831e+12]) tensor(-1.6376e+11, grad_fn=<AddBackward0>) 393
# tensor(2.1146e+12, grad_fn=<SubBackward0>) tensor([1.7996e+12]) tensor(-1.5000e+11, grad_fn=<AddBackward0>) 394
# tensor(2.1252e+12, grad_fn=<SubBackward0>) tensor([1.8365e+12]) tensor(-1.6056e+11, grad_fn=<AddBackward0>) 395
# tensor(2.3004e+12, grad_fn=<SubBackward0>) tensor([1.3294e+12]) tensor(-1.7524e+11, grad_fn=<AddBackward0>) 396
# tensor(2.4895e+12, grad_fn=<SubBackward0>) tensor([2.1183e+12]) tensor(-1.8909e+11, grad_fn=<AddBackward0>) 397
# tensor(2.6949e+12, grad_fn=<SubBackward0>) tensor([2.1805e+12]) tensor(-2.0541e+11, grad_fn=<AddBackward0>) 398
# tensor(2.9208e+12, grad_fn=<SubBackward0>) tensor([2.0409e+11]) tensor(-2.2594e+11, grad_fn=<AddBackward0>) 399
# tensor(2.9202e+12, grad_fn=<SubBackward0>) tensor([6.0832e+11]) tensor(-2.2530e+11, grad_fn=<AddBackward0>) 400
# tensor(3.1618e+12, grad_fn=<SubBackward0>) tensor([7.5862e+11]) tensor(-2.4159e+11, grad_fn=<AddBackward0>) 401
# tensor(3.4214e+12, grad_fn=<SubBackward0>) tensor([2.1412e+12]) tensor(-2.5960e+11, grad_fn=<AddBackward0>) 402
# tensor(3.6918e+12, grad_fn=<SubBackward0>) tensor([2.0211e+12]) tensor(-2.7043e+11, grad_fn=<AddBackward0>) 403
# tensor(3.7079e+12, grad_fn=<SubBackward0>) tensor([1.2382e+12]) tensor(-2.8647e+11, grad_fn=<AddBackward0>) 404
# tensor(4.0024e+12, grad_fn=<SubBackward0>) tensor([1.1863e+12]) tensor(-2.9450e+11, grad_fn=<AddBackward0>) 405
# tensor(4.3286e+12, grad_fn=<SubBackward0>) tensor([3.8717e+12]) tensor(-3.2623e+11, grad_fn=<AddBackward0>) 406
# tensor(4.6835e+12, grad_fn=<SubBackward0>) tensor([3.8373e+12]) tensor(-3.5490e+11, grad_fn=<AddBackward0>) 407
# tensor(5.0697e+12, grad_fn=<SubBackward0>) tensor([2.5156e+12]) tensor(-3.8615e+11, grad_fn=<AddBackward0>) 408
# tensor(5.4913e+12, grad_fn=<SubBackward0>) tensor([3.1915e+12]) tensor(-4.2167e+11, grad_fn=<AddBackward0>) 409
# tensor(5.9398e+12, grad_fn=<SubBackward0>) tensor([1.7260e+12]) tensor(-4.4852e+11, grad_fn=<AddBackward0>) 410
# tensor(5.9360e+12, grad_fn=<SubBackward0>) tensor([4.2132e+12]) tensor(-4.4466e+11, grad_fn=<AddBackward0>) 411
# tensor(6.4332e+12, grad_fn=<SubBackward0>) tensor([3.1196e+12]) tensor(-4.9723e+11, grad_fn=<AddBackward0>) 412
# tensor(6.4349e+12, grad_fn=<SubBackward0>) tensor([1.5865e+12]) tensor(-4.9893e+11, grad_fn=<AddBackward0>) 413
# tensor(6.4156e+12, grad_fn=<SubBackward0>) tensor([1.2939e+12]) tensor(-4.7964e+11, grad_fn=<AddBackward0>) 414
# tensor(6.9532e+12, grad_fn=<SubBackward0>) tensor([7.5534e+11]) tensor(-5.3756e+11, grad_fn=<AddBackward0>) 415
# tensor(7.5261e+12, grad_fn=<SubBackward0>) tensor([5.7695e+12]) tensor(-5.7289e+11, grad_fn=<AddBackward0>) 416
# tensor(7.5248e+12, grad_fn=<SubBackward0>) tensor([5.0164e+12]) tensor(-5.7164e+11, grad_fn=<AddBackward0>) 417
# tensor(7.5296e+12, grad_fn=<SubBackward0>) tensor([3.8630e+12]) tensor(-5.7645e+11, grad_fn=<AddBackward0>) 418
# tensor(8.1579e+12, grad_fn=<SubBackward0>) tensor([2.0222e+12]) tensor(-6.2821e+11, grad_fn=<AddBackward0>) 419
# tensor(8.8255e+12, grad_fn=<SubBackward0>) tensor([4.4608e+12]) tensor(-6.6769e+11, grad_fn=<AddBackward0>) 420
# tensor(9.5601e+12, grad_fn=<SubBackward0>) tensor([1.8253e+12]) tensor(-7.3455e+11, grad_fn=<AddBackward0>) 421
# tensor(1.0342e+13, grad_fn=<SubBackward0>) tensor([5.8576e+12]) tensor(-7.8176e+11, grad_fn=<AddBackward0>) 422
# tensor(1.1216e+13, grad_fn=<SubBackward0>) tensor([8.0489e+12]) tensor(-8.7460e+11, grad_fn=<AddBackward0>) 423
# tensor(1.2119e+13, grad_fn=<SubBackward0>) tensor([4.2346e+12]) tensor(-9.0255e+11, grad_fn=<AddBackward0>) 424
# tensor(1.3125e+13, grad_fn=<SubBackward0>) tensor([5.6040e+12]) tensor(-1.0064e+12, grad_fn=<AddBackward0>) 425
# tensor(1.3125e+13, grad_fn=<SubBackward0>) tensor([8.3482e+11]) tensor(-1.0064e+12, grad_fn=<AddBackward0>) 426
# tensor(1.3122e+13, grad_fn=<SubBackward0>) tensor([3.3626e+12]) tensor(-1.0032e+12, grad_fn=<AddBackward0>) 427
# tensor(1.4207e+13, grad_fn=<SubBackward0>) tensor([3.9871e+12]) tensor(-1.0845e+12, grad_fn=<AddBackward0>) 428
# tensor(1.4190e+13, grad_fn=<SubBackward0>) tensor([6.3824e+11]) tensor(-1.0677e+12, grad_fn=<AddBackward0>) 429
# tensor(1.5343e+13, grad_fn=<SubBackward0>) tensor([2.0352e+12]) tensor(-1.1533e+12, grad_fn=<AddBackward0>) 430
# tensor(1.6638e+13, grad_fn=<SubBackward0>) tensor([4.5264e+12]) tensor(-1.2943e+12, grad_fn=<AddBackward0>) 431
# tensor(1.8040e+13, grad_fn=<SubBackward0>) tensor([1.3125e+13]) tensor(-1.4019e+12, grad_fn=<AddBackward0>) 432
# tensor(1.9515e+13, grad_fn=<SubBackward0>) tensor([1.1384e+12]) tensor(-1.4758e+12, grad_fn=<AddBackward0>) 433
# tensor(2.1160e+13, grad_fn=<SubBackward0>) tensor([5.8699e+12]) tensor(-1.6444e+12, grad_fn=<AddBackward0>) 434
# ...
# tensor(1.6641e+24, grad_fn=<SubBackward0>) tensor([2.2245e+22]) tensor(-1.2702e+23, grad_fn=<AddBackward0>) 858
# tensor(1.8016e+24, grad_fn=<SubBackward0>) tensor([7.0806e+23]) tensor(-1.3752e+23, grad_fn=<AddBackward0>) 859
# tensor(1.8016e+24, grad_fn=<SubBackward0>) tensor([6.0500e+23]) tensor(-1.3752e+23, grad_fn=<AddBackward0>) 860
# tensor(1.9505e+24, grad_fn=<SubBackward0>) tensor([1.7219e+24]) tensor(-1.4889e+23, grad_fn=<AddBackward0>) 861
# tensor(2.1117e+24, grad_fn=<SubBackward0>) tensor([9.5197e+23]) tensor(-1.6119e+23, grad_fn=<AddBackward0>) 862
# tensor(2.2862e+24, grad_fn=<SubBackward0>) tensor([1.3764e+24]) tensor(-1.7452e+23, grad_fn=<AddBackward0>) 863
# tensor(2.4751e+24, grad_fn=<SubBackward0>) tensor([1.3224e+24]) tensor(-1.8894e+23, grad_fn=<AddBackward0>) 864
# tensor(2.6797e+24, grad_fn=<SubBackward0>) tensor([1.3017e+24]) tensor(-2.0456e+23, grad_fn=<AddBackward0>) 865
# tensor(2.6797e+24, grad_fn=<SubBackward0>) tensor([7.6046e+23]) tensor(-2.0456e+23, grad_fn=<AddBackward0>) 866
# tensor(2.6797e+24, grad_fn=<SubBackward0>) tensor([6.5828e+23]) tensor(-2.0456e+23, grad_fn=<AddBackward0>) 867
# tensor(2.9012e+24, grad_fn=<SubBackward0>) tensor([8.9625e+23]) tensor(-2.2146e+23, grad_fn=<AddBackward0>) 868
# tensor(2.9012e+24, grad_fn=<SubBackward0>) tensor([2.0606e+24]) tensor(-2.2147e+23, grad_fn=<AddBackward0>) 869
# tensor(3.1409e+24, grad_fn=<SubBackward0>) tensor([2.3284e+22]) tensor(-2.3977e+23, grad_fn=<AddBackward0>) 870
# tensor(3.4005e+24, grad_fn=<SubBackward0>) tensor([2.7866e+24]) tensor(-2.5959e+23, grad_fn=<AddBackward0>) 871
# tensor(3.6816e+24, grad_fn=<SubBackward0>) tensor([2.7000e+24]) tensor(-2.8104e+23, grad_fn=<AddBackward0>) 872
# tensor(3.9858e+24, grad_fn=<SubBackward0>) tensor([3.2704e+24]) tensor(-3.0426e+23, grad_fn=<AddBackward0>) 873
# tensor(3.9858e+24, grad_fn=<SubBackward0>) tensor([9.9329e+23]) tensor(-3.0426e+23, grad_fn=<AddBackward0>) 874
# tensor(4.3152e+24, grad_fn=<SubBackward0>) tensor([2.7612e+24]) tensor(-3.2940e+23, grad_fn=<AddBackward0>) 875
# tensor(4.6719e+24, grad_fn=<SubBackward0>) tensor([3.6825e+24]) tensor(-3.5663e+23, grad_fn=<AddBackward0>) 876
# tensor(4.6718e+24, grad_fn=<SubBackward0>) tensor([1.9706e+24]) tensor(-3.5663e+23, grad_fn=<AddBackward0>) 877
# tensor(5.0580e+24, grad_fn=<SubBackward0>) tensor([2.9981e+24]) tensor(-3.8611e+23, grad_fn=<AddBackward0>) 878
# tensor(5.0579e+24, grad_fn=<SubBackward0>) tensor([7.3914e+23]) tensor(-3.8609e+23, grad_fn=<AddBackward0>) 879
# tensor(5.4760e+24, grad_fn=<SubBackward0>) tensor([2.5249e+24]) tensor(-4.1801e+23, grad_fn=<AddBackward0>) 880
# tensor(5.9285e+24, grad_fn=<SubBackward0>) tensor([1.2758e+24]) tensor(-4.5255e+23, grad_fn=<AddBackward0>) 881
# tensor(6.4185e+24, grad_fn=<SubBackward0>) tensor([5.7439e+24]) tensor(-4.8996e+23, grad_fn=<AddBackward0>) 882
# tensor(6.9489e+24, grad_fn=<SubBackward0>) tensor([3.2698e+24]) tensor(-5.3046e+23, grad_fn=<AddBackward0>) 883
# tensor(7.5232e+24, grad_fn=<SubBackward0>) tensor([6.1390e+24]) tensor(-5.7429e+23, grad_fn=<AddBackward0>) 884
# tensor(7.5232e+24, grad_fn=<SubBackward0>) tensor([3.7945e+24]) tensor(-5.7431e+23, grad_fn=<AddBackward0>) 885
# tensor(8.1450e+24, grad_fn=<SubBackward0>) tensor([1.3909e+24]) tensor(-6.2176e+23, grad_fn=<AddBackward0>) 886
# tensor(8.1450e+24, grad_fn=<SubBackward0>) tensor([6.2066e+24]) tensor(-6.2175e+23, grad_fn=<AddBackward0>) 887
# tensor(8.1450e+24, grad_fn=<SubBackward0>) tensor([4.8190e+24]) tensor(-6.2175e+23, grad_fn=<AddBackward0>) 888
# tensor(8.8181e+24, grad_fn=<SubBackward0>) tensor([7.9650e+24]) tensor(-6.7313e+23, grad_fn=<AddBackward0>) 889
# tensor(9.5469e+24, grad_fn=<SubBackward0>) tensor([5.0353e+24]) tensor(-7.2877e+23, grad_fn=<AddBackward0>) 890
# tensor(9.5469e+24, grad_fn=<SubBackward0>) tensor([3.2356e+24]) tensor(-7.2875e+23, grad_fn=<AddBackward0>) 891
# tensor(9.5469e+24, grad_fn=<SubBackward0>) tensor([3.0012e+24]) tensor(-7.2878e+23, grad_fn=<AddBackward0>) 892
# tensor(9.5469e+24, grad_fn=<SubBackward0>) tensor([6.7107e+24]) tensor(-7.2879e+23, grad_fn=<AddBackward0>) 893
# tensor(1.0336e+25, grad_fn=<SubBackward0>) tensor([4.9676e+24]) tensor(-7.8900e+23, grad_fn=<AddBackward0>) 894
# tensor(1.1190e+25, grad_fn=<SubBackward0>) tensor([4.3575e+24]) tensor(-8.5421e+23, grad_fn=<AddBackward0>) 895
# tensor(1.2115e+25, grad_fn=<SubBackward0>) tensor([1.1163e+25]) tensor(-9.2481e+23, grad_fn=<AddBackward0>) 896
# tensor(1.3116e+25, grad_fn=<SubBackward0>) tensor([1.1501e+25]) tensor(-1.0012e+24, grad_fn=<AddBackward0>) 897
# tensor(1.4200e+25, grad_fn=<SubBackward0>) tensor([1.1899e+25]) tensor(-1.0840e+24, grad_fn=<AddBackward0>) 898
# tensor(1.5374e+25, grad_fn=<SubBackward0>) tensor([8.6292e+24]) tensor(-1.1736e+24, grad_fn=<AddBackward0>) 899
# tensor(1.5374e+25, grad_fn=<SubBackward0>) tensor([4.8007e+24]) tensor(-1.1736e+24, grad_fn=<AddBackward0>) 900
# tensor(1.6644e+25, grad_fn=<SubBackward0>) tensor([1.0948e+25]) tensor(-1.2705e+24, grad_fn=<AddBackward0>) 901
# tensor(1.8020e+25, grad_fn=<SubBackward0>) tensor([1.3851e+25]) tensor(-1.3755e+24, grad_fn=<AddBackward0>) 902
# tensor(1.9509e+25, grad_fn=<SubBackward0>) tensor([1.7239e+25]) tensor(-1.4893e+24, grad_fn=<AddBackward0>) 903
# tensor(1.9509e+25, grad_fn=<SubBackward0>) tensor([1.1883e+25]) tensor(-1.4893e+24, grad_fn=<AddBackward0>) 904
# tensor(2.1121e+25, grad_fn=<SubBackward0>) tensor([1.5875e+25]) tensor(-1.6123e+24, grad_fn=<AddBackward0>) 905
# tensor(2.2867e+25, grad_fn=<SubBackward0>) tensor([6.1246e+24]) tensor(-1.7456e+24, grad_fn=<AddBackward0>) 906
# tensor(2.4757e+25, grad_fn=<SubBackward0>) tensor([5.4612e+24]) tensor(-1.8898e+24, grad_fn=<AddBackward0>) 907
# tensor(2.6803e+25, grad_fn=<SubBackward0>) tensor([1.7012e+25]) tensor(-2.0460e+24, grad_fn=<AddBackward0>) 908
# tensor(2.9018e+25, grad_fn=<SubBackward0>) tensor([7.0460e+24]) tensor(-2.2151e+24, grad_fn=<AddBackward0>) 909
# tensor(2.9018e+25, grad_fn=<SubBackward0>) tensor([1.4598e+24]) tensor(-2.2151e+24, grad_fn=<AddBackward0>) 910
# tensor(3.1416e+25, grad_fn=<SubBackward0>) tensor([6.1107e+24]) tensor(-2.3982e+24, grad_fn=<AddBackward0>) 911
# tensor(3.4012e+25, grad_fn=<SubBackward0>) tensor([1.7013e+25]) tensor(-2.5963e+24, grad_fn=<AddBackward0>) 912
# tensor(3.6823e+25, grad_fn=<SubBackward0>) tensor([1.8741e+25]) tensor(-2.8109e+24, grad_fn=<AddBackward0>) 913
# tensor(3.6823e+25, grad_fn=<SubBackward0>) tensor([1.9810e+25]) tensor(-2.8109e+24, grad_fn=<AddBackward0>) 914
# tensor(3.6823e+25, grad_fn=<SubBackward0>) tensor([2.2915e+24]) tensor(-2.8109e+24, grad_fn=<AddBackward0>) 915
# tensor(3.6823e+25, grad_fn=<SubBackward0>) tensor([1.6548e+25]) tensor(-2.8109e+24, grad_fn=<AddBackward0>) 916
# tensor(3.6823e+25, grad_fn=<SubBackward0>) tensor([2.4233e+25]) tensor(-2.8110e+24, grad_fn=<AddBackward0>) 917
# tensor(3.6823e+25, grad_fn=<SubBackward0>) tensor([3.9589e+24]) tensor(-2.8110e+24, grad_fn=<AddBackward0>) 918
# tensor(3.9867e+25, grad_fn=<SubBackward0>) tensor([6.7277e+24]) tensor(-3.0432e+24, grad_fn=<AddBackward0>) 919
# tensor(4.3161e+25, grad_fn=<SubBackward0>) tensor([1.4113e+25]) tensor(-3.2948e+24, grad_fn=<AddBackward0>) 920
# tensor(4.6728e+25, grad_fn=<SubBackward0>) tensor([2.3685e+25]) tensor(-3.5670e+24, grad_fn=<AddBackward0>) 921
# tensor(5.0590e+25, grad_fn=<SubBackward0>) tensor([1.6657e+25]) tensor(-3.8619e+24, grad_fn=<AddBackward0>) 922
# tensor(5.0590e+25, grad_fn=<SubBackward0>) tensor([1.0661e+25]) tensor(-3.8619e+24, grad_fn=<AddBackward0>) 923
# tensor(5.0590e+25, grad_fn=<SubBackward0>) tensor([3.7456e+25]) tensor(-3.8619e+24, grad_fn=<AddBackward0>) 924
# tensor(5.0590e+25, grad_fn=<SubBackward0>) tensor([2.4757e+25]) tensor(-3.8618e+24, grad_fn=<AddBackward0>) 925
# tensor(5.4771e+25, grad_fn=<SubBackward0>) tensor([4.8419e+25]) tensor(-4.1810e+24, grad_fn=<AddBackward0>) 926
# tensor(5.4771e+25, grad_fn=<SubBackward0>) tensor([1.9892e+25]) tensor(-4.1810e+24, grad_fn=<AddBackward0>) 927
# tensor(5.9298e+25, grad_fn=<SubBackward0>) tensor([3.6567e+24]) tensor(-4.5265e+24, grad_fn=<AddBackward0>) 928
# tensor(6.4198e+25, grad_fn=<SubBackward0>) tensor([4.5554e+25]) tensor(-4.9006e+24, grad_fn=<AddBackward0>) 929
# tensor(6.9504e+25, grad_fn=<SubBackward0>) tensor([4.8717e+25]) tensor(-5.3057e+24, grad_fn=<AddBackward0>) 930
# tensor(7.5248e+25, grad_fn=<SubBackward0>) tensor([5.8600e+25]) tensor(-5.7441e+24, grad_fn=<AddBackward0>) 931
# tensor(8.1467e+25, grad_fn=<SubBackward0>) tensor([6.3842e+25]) tensor(-6.2188e+24, grad_fn=<AddBackward0>) 932
# tensor(8.8200e+25, grad_fn=<SubBackward0>) tensor([2.0122e+25]) tensor(-6.7328e+24, grad_fn=<AddBackward0>) 933
# tensor(8.8200e+25, grad_fn=<SubBackward0>) tensor([7.2994e+25]) tensor(-6.7327e+24, grad_fn=<AddBackward0>) 934
# tensor(9.5489e+25, grad_fn=<SubBackward0>) tensor([2.7154e+25]) tensor(-7.2892e+24, grad_fn=<AddBackward0>) 935
# tensor(1.0338e+26, grad_fn=<SubBackward0>) tensor([7.5619e+25]) tensor(-7.8916e+24, grad_fn=<AddBackward0>) 936
# tensor(1.1192e+26, grad_fn=<SubBackward0>) tensor([7.7525e+25]) tensor(-8.5439e+24, grad_fn=<AddBackward0>) 937
# tensor(1.2117e+26, grad_fn=<SubBackward0>) tensor([7.0880e+25]) tensor(-9.2499e+24, grad_fn=<AddBackward0>) 938
# tensor(1.3119e+26, grad_fn=<SubBackward0>) tensor([9.3112e+25]) tensor(-1.0014e+25, grad_fn=<AddBackward0>) 939
# tensor(1.4203e+26, grad_fn=<SubBackward0>) tensor([7.3491e+25]) tensor(-1.0842e+25, grad_fn=<AddBackward0>) 940
# tensor(1.5377e+26, grad_fn=<SubBackward0>) tensor([1.2439e+26]) tensor(-1.1738e+25, grad_fn=<AddBackward0>) 941
# tensor(1.6648e+26, grad_fn=<SubBackward0>) tensor([2.1940e+25]) tensor(-1.2708e+25, grad_fn=<AddBackward0>) 942
# tensor(1.6648e+26, grad_fn=<SubBackward0>) tensor([3.3535e+25]) tensor(-1.2708e+25, grad_fn=<AddBackward0>) 943
# tensor(1.8024e+26, grad_fn=<SubBackward0>) tensor([9.4278e+25]) tensor(-1.3758e+25, grad_fn=<AddBackward0>) 944
# tensor(1.8024e+26, grad_fn=<SubBackward0>) tensor([2.4326e+25]) tensor(-1.3758e+25, grad_fn=<AddBackward0>) 945
# tensor(1.9513e+26, grad_fn=<SubBackward0>) tensor([6.8590e+25]) tensor(-1.4895e+25, grad_fn=<AddBackward0>) 946
# tensor(2.1126e+26, grad_fn=<SubBackward0>) tensor([1.1973e+26]) tensor(-1.6126e+25, grad_fn=<AddBackward0>) 947
# tensor(2.2872e+26, grad_fn=<SubBackward0>) tensor([4.3551e+25]) tensor(-1.7459e+25, grad_fn=<AddBackward0>) 948
# tensor(2.4762e+26, grad_fn=<SubBackward0>) tensor([8.6912e+25]) tensor(-1.8902e+25, grad_fn=<AddBackward0>) 949
# tensor(2.6808e+26, grad_fn=<SubBackward0>) tensor([6.6480e+25]) tensor(-2.0464e+25, grad_fn=<AddBackward0>) 950
# tensor(2.9024e+26, grad_fn=<SubBackward0>) tensor([8.2726e+25]) tensor(-2.2156e+25, grad_fn=<AddBackward0>) 951
# tensor(3.1422e+26, grad_fn=<SubBackward0>) tensor([2.5459e+26]) tensor(-2.3987e+25, grad_fn=<AddBackward0>) 952
# tensor(3.1422e+26, grad_fn=<SubBackward0>) tensor([1.3012e+26]) tensor(-2.3987e+25, grad_fn=<AddBackward0>) 953
# tensor(3.4019e+26, grad_fn=<SubBackward0>) tensor([1.1310e+26]) tensor(-2.5969e+25, grad_fn=<AddBackward0>) 954
# tensor(3.6831e+26, grad_fn=<SubBackward0>) tensor([2.5870e+25]) tensor(-2.8115e+25, grad_fn=<AddBackward0>) 955
# tensor(3.9875e+26, grad_fn=<SubBackward0>) tensor([2.9808e+26]) tensor(-3.0439e+25, grad_fn=<AddBackward0>) 956
# tensor(4.3170e+26, grad_fn=<SubBackward0>) tensor([3.3633e+25]) tensor(-3.2954e+25, grad_fn=<AddBackward0>) 957
# tensor(4.3170e+26, grad_fn=<SubBackward0>) tensor([3.5650e+26]) tensor(-3.2955e+25, grad_fn=<AddBackward0>) 958
# tensor(4.6738e+26, grad_fn=<SubBackward0>) tensor([6.4026e+25]) tensor(-3.5678e+25, grad_fn=<AddBackward0>) 959
# tensor(5.0601e+26, grad_fn=<SubBackward0>) tensor([2.3572e+26]) tensor(-3.8626e+25, grad_fn=<AddBackward0>) 960
# tensor(5.4782e+26, grad_fn=<SubBackward0>) tensor([1.8122e+26]) tensor(-4.1818e+25, grad_fn=<AddBackward0>) 961
# tensor(5.9310e+26, grad_fn=<SubBackward0>) tensor([4.0304e+26]) tensor(-4.5275e+25, grad_fn=<AddBackward0>) 962
# tensor(6.4211e+26, grad_fn=<SubBackward0>) tensor([4.3217e+26]) tensor(-4.9016e+25, grad_fn=<AddBackward0>) 963
# tensor(6.4212e+26, grad_fn=<SubBackward0>) tensor([2.5603e+26]) tensor(-4.9016e+25, grad_fn=<AddBackward0>) 964
# tensor(6.9518e+26, grad_fn=<SubBackward0>) tensor([4.5201e+26]) tensor(-5.3068e+25, grad_fn=<AddBackward0>) 965
# tensor(7.5264e+26, grad_fn=<SubBackward0>) tensor([6.4004e+26]) tensor(-5.7453e+25, grad_fn=<AddBackward0>) 966
# tensor(8.1484e+26, grad_fn=<SubBackward0>) tensor([5.7337e+26]) tensor(-6.2201e+25, grad_fn=<AddBackward0>) 967
# tensor(8.8218e+26, grad_fn=<SubBackward0>) tensor([8.9911e+25]) tensor(-6.7341e+25, grad_fn=<AddBackward0>) 968
# tensor(9.5509e+26, grad_fn=<SubBackward0>) tensor([8.2002e+26]) tensor(-7.2907e+25, grad_fn=<AddBackward0>) 969
# tensor(1.0340e+27, grad_fn=<SubBackward0>) tensor([7.6699e+26]) tensor(-7.8933e+25, grad_fn=<AddBackward0>) 970
# tensor(1.1195e+27, grad_fn=<SubBackward0>) tensor([2.8356e+26]) tensor(-8.5455e+25, grad_fn=<AddBackward0>) 971
# tensor(1.1195e+27, grad_fn=<SubBackward0>) tensor([6.9097e+26]) tensor(-8.5456e+25, grad_fn=<AddBackward0>) 972
# tensor(1.2120e+27, grad_fn=<SubBackward0>) tensor([2.1914e+26]) tensor(-9.2519e+25, grad_fn=<AddBackward0>) 973
# tensor(1.3122e+27, grad_fn=<SubBackward0>) tensor([7.9817e+26]) tensor(-1.0016e+26, grad_fn=<AddBackward0>) 974
# tensor(1.3122e+27, grad_fn=<SubBackward0>) tensor([8.2520e+26]) tensor(-1.0016e+26, grad_fn=<AddBackward0>) 975
# tensor(1.4206e+27, grad_fn=<SubBackward0>) tensor([1.1092e+27]) tensor(-1.0844e+26, grad_fn=<AddBackward0>) 976
# tensor(1.5380e+27, grad_fn=<SubBackward0>) tensor([4.3239e+26]) tensor(-1.1740e+26, grad_fn=<AddBackward0>) 977
# tensor(1.6651e+27, grad_fn=<SubBackward0>) tensor([4.4788e+26]) tensor(-1.2711e+26, grad_fn=<AddBackward0>) 978
# tensor(1.6651e+27, grad_fn=<SubBackward0>) tensor([5.7124e+26]) tensor(-1.2711e+26, grad_fn=<AddBackward0>) 979
# tensor(1.8027e+27, grad_fn=<SubBackward0>) tensor([6.9993e+26]) tensor(-1.3761e+26, grad_fn=<AddBackward0>) 980
# tensor(1.9517e+27, grad_fn=<SubBackward0>) tensor([3.9767e+26]) tensor(-1.4899e+26, grad_fn=<AddBackward0>) 981
# tensor(2.1130e+27, grad_fn=<SubBackward0>) tensor([8.0747e+26]) tensor(-1.6130e+26, grad_fn=<AddBackward0>) 982
# tensor(2.1130e+27, grad_fn=<SubBackward0>) tensor([1.6601e+27]) tensor(-1.6130e+26, grad_fn=<AddBackward0>) 983
# tensor(2.2876e+27, grad_fn=<SubBackward0>) tensor([1.8348e+27]) tensor(-1.7463e+26, grad_fn=<AddBackward0>) 984
# tensor(2.2876e+27, grad_fn=<SubBackward0>) tensor([9.8135e+26]) tensor(-1.7463e+26, grad_fn=<AddBackward0>) 985
# tensor(2.4767e+27, grad_fn=<SubBackward0>) tensor([1.5290e+27]) tensor(-1.8906e+26, grad_fn=<AddBackward0>) 986
# tensor(2.6814e+27, grad_fn=<SubBackward0>) tensor([1.3247e+26]) tensor(-2.0468e+26, grad_fn=<AddBackward0>) 987
# tensor(2.9030e+27, grad_fn=<SubBackward0>) tensor([1.1724e+27]) tensor(-2.2160e+26, grad_fn=<AddBackward0>) 988
# tensor(3.1429e+27, grad_fn=<SubBackward0>) tensor([1.1338e+27]) tensor(-2.3992e+26, grad_fn=<AddBackward0>) 989
# tensor(3.4026e+27, grad_fn=<SubBackward0>) tensor([2.1636e+27]) tensor(-2.5974e+26, grad_fn=<AddBackward0>) 990
# tensor(3.4026e+27, grad_fn=<SubBackward0>) tensor([8.5204e+26]) tensor(-2.5974e+26, grad_fn=<AddBackward0>) 991
# tensor(3.4026e+27, grad_fn=<SubBackward0>) tensor([1.3800e+27]) tensor(-2.5974e+26, grad_fn=<AddBackward0>) 992
# tensor(3.4026e+27, grad_fn=<SubBackward0>) tensor([2.8066e+27]) tensor(-2.5974e+26, grad_fn=<AddBackward0>) 993
# tensor(3.4026e+27, grad_fn=<SubBackward0>) tensor([5.0918e+26]) tensor(-2.5974e+26, grad_fn=<AddBackward0>) 994
# tensor(3.4026e+27, grad_fn=<SubBackward0>) tensor([1.3460e+27]) tensor(-2.5974e+26, grad_fn=<AddBackward0>) 995
# tensor(3.6838e+27, grad_fn=<SubBackward0>) tensor([2.9900e+27]) tensor(-2.8121e+26, grad_fn=<AddBackward0>) 996
# tensor(3.6839e+27, grad_fn=<SubBackward0>) tensor([1.5022e+27]) tensor(-2.8121e+26, grad_fn=<AddBackward0>) 997
# tensor(3.6839e+27, grad_fn=<SubBackward0>) tensor([1.2420e+27]) tensor(-2.8121e+26, grad_fn=<AddBackward0>) 998
# tensor(3.9883e+27, grad_fn=<SubBackward0>) tensor([2.7951e+27]) tensor(-3.0445e+26, grad_fn=<AddBackward0>) 999

# %%
result

# %%
step = 0.2
vmin, vmax = X.min() - step, X.max() + step
X_grid = torch.mgrid[vmin:vmax:100j, vmin:vmax:100j]
