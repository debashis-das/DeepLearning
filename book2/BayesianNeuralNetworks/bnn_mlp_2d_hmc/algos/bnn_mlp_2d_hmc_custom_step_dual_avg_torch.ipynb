# %%
from typing import NamedTuple, Callable
from functools import partial

import torch
import torch.nn as nn
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# %%
class MLP1D(nn.Module):

    def __init__(self, in_shapes=[2,10,10,10], out_shapes = [10,10,10,1]):
        super().__init__()
        self.linears = [nn.Linear(in_shapes[i], out_shapes[i]) for i in range(len(in_shapes))]
        self.relu = nn.ReLU()
        
    def model(self):
        return nn.Sequential(self.linears[0], self.relu, 
                             self.linears[1], self.relu, 
                             self.linears[2], self.relu, self.linears[3])

    def forward(self, params, X):
        self.weights_and_biases(params)
        return self.model()(X)
    
    def weights_and_biases(self, params):
        for i,param in enumerate(params):
            self.linears[i].weight = nn.Parameter(param['weight'])
            self.linears[i].bias = nn.Parameter(param['bias'])
    
    def fetch_params(self):
        params = []
        for linear in self.linears:
            params.append({
                'weight': linear.weight.detach(),
                'bias': linear.bias.detach()
            })
        return params

def ravel_params(params):
    def ravel_per_item():
        all_params = []
        def ravel_per_item_per_key(param):
            for value in param.values(): 
                all_params.append(value.ravel())

        if type(params) == list:
            for param in params:
                ravel_per_item_per_key(param)
        else:
            ravel_per_item_per_key(params)
        return all_params
    return torch.cat(ravel_per_item())

def unravel_params(params_raveled: torch.Tensor, structured_tuple):
    
    def unravel_all_shapes(structure, is_list):
        shapes = []
        def extract_shapes(structure):
            if is_list:
                for per_structure in structure:
                    for val in per_structure.values():
                        shapes.append(val.numel())
            else:
                for val in structure.values():
                    shapes.append(val.numel())
            values_per_structure = params_raveled.split(shapes)
            return values_per_structure
        
        values_per_structure = extract_shapes(structure)
        result = []
        index = [0]

        def result_per_dict(values_per_structure, per_structure):
            per_result = {}
            for key, val in per_structure.items():
                # print(key, val.shape, values_per_structure[index[0]].shape)
                per_result[key] = values_per_structure[index[0]].reshape(val.shape)
                index[0] += 1
            return per_result
        
        if is_list:
            for per_structure in structure:
                per_result = result_per_dict(values_per_structure, per_structure)
                result.append(per_result)
            return result
        else:
            return result_per_dict(values_per_structure, structure)
        
    return unravel_all_shapes(structured_tuple, type(structured_tuple) == list)
    
def bnn_log_joint(params, X, y, model:MLP1D):
    logits = model.forward(params, X).ravel()
    flatten_params = ravel_params(params)
    log_prior = torch.distributions.Normal(0.0, 1.0).log_prob(flatten_params).sum()
    log_likelihood = torch.distributions.Bernoulli(logits=logits).log_prob(y).sum()
    log_joint = log_prior + log_likelihood
    return log_joint

noise = 0.2
num_samples = 50
num_warmup = 1000
num_steps = 500
in_shapes = [2,10,10,10]
out_shapes = [10,10,10,1]

X, y = make_moons(n_samples=num_samples, noise=noise, random_state=314)
model = MLP1D(in_shapes=in_shapes, out_shapes=out_shapes)
params = model.fetch_params()
potential = partial(bnn_log_joint, X=torch.Tensor(X), y=torch.Tensor(y), model=model)


# Test

potential(params)
# print(ravel_params(params[0]).shape)
# print(unravel_params(ravel_params(params[1]),params[1]))
# print(unravel_params(ravel_params(params),params))
# Out:
# tensor(-281.3270, grad_fn=<AddBackward0>)

# %%
class EnergyParameters:

    def __init__(self, potential_energy_fn:Callable, precision):
        self.potential_energy_fn = potential_energy_fn 
        self.precision = precision
    
    def set_position(self, position):
        self.position = position
        self.potential_energy = self.potential_energy_fn(position)
        self.potential_energy_grad = torch.func.grad(self.potential_energy_fn)(position)
    
    def set_velocity(self, velocity):
        self.velocity = velocity
        self.kinetic_energy = self.kinetic_energy_fn(self.velocity)
        self.kinetic_energy_grad = torch.func.grad(self.kinetic_energy_fn)(self.velocity)

    def init_per_step(self, position, velocity):
        self.set_position(position)
        self.set_velocity(velocity)
        self.total_init_energy = self.total_current_energy()
    
    def kinetic_energy_fn(self, velocity:torch.Tensor):
        return 0.5*torch.matmul(velocity, torch.matmul(self.precision, velocity.T))
    
    def update_position(self, step_size_with_direction):
        position_raveled = ravel_params(self.position)
        result = position_raveled + step_size_with_direction*self.kinetic_energy_grad
        n_position = unravel_params(result, self.position)
        self.set_position(n_position)
        return n_position

    def updated_velocity(self, step_size_with_direction, is_half_step_momentum = False):
        n_velocity = torch.subtract(self.velocity, step_size_with_direction*(0.5 if is_half_step_momentum else 1)*ravel_params(self.potential_energy_grad))
        self.set_velocity(n_velocity)
        return n_velocity
    
    def delta_energy(self):
        return - self.total_current_energy() + self.total_init_energy 
    
    def total_current_energy(self):
        return - self.potential_energy - self.kinetic_energy

# Test

# e_params = EnergyParameters(potential_energy_fn=potential)
# e_params.set_energy_parameters(params)

# %% [markdown]
# # HMC with Dual Averaging

# %%
class HMCAlgorithm:
    
    def __init__(self, log_density_fn: Callable, precision, expected_prob_density=0.65, Lambda = 0.12, m_warmup=1000, num_steps=500):
        self.log_density_fn = log_density_fn
        # Lambda
        self.Lambda = Lambda
        # delta
        self.expected_prob_density = expected_prob_density
        # M_adapt
        self.m_warmup = m_warmup
        # M
        self.M = m_warmup + num_steps
        self.ep = EnergyParameters(potential_energy_fn=log_density_fn, precision=precision)

    
    def generate_default_velocity(self, position_shape):

        def generate_random_gaussian(covariance: torch.Tensor):
            return torch.distributions.MultivariateNormal(loc=torch.zeros(covariance.shape[-1]),covariance_matrix=covariance).sample()

        def generate_inverse_mass_matrix_and_sigma(covariance_shape: int):
            covariance = torch.eye(covariance_shape)
            inverse_mass_matrix = covariance.inverse()
            return inverse_mass_matrix, covariance
        
        _, covariance = generate_inverse_mass_matrix_and_sigma(position_shape)
        return generate_random_gaussian(covariance)

    def find_reasonable_epsilon(self, position):
        step_size, velocity = 0.01, self.generate_default_velocity(ravel_params(position).shape[-1])
        delta_energy, proposal_position, proposal_velocity, _ = self.step_integrator(position, velocity, step_size)
        alpha = 2*(1 if torch.exp(delta_energy) > 0.5 else 0) - 1
        while torch.pow(torch.exp(delta_energy), alpha) > torch.pow(torch.tensor(0.5), alpha):
            step_size = torch.pow(torch.tensor(2), alpha) * step_size
            delta_energy, proposal_position, proposal_velocity, _ = self.step_integrator(proposal_position, proposal_velocity, step_size)
        print(f'Step size (find_reasonable_epsilon) : {step_size}')
        return step_size

    def update(self, position):
        self.init_step(position)
        log_step_size_average = torch.log(self.step_size_average)
        # starting from 1
        for m in range(1,self.M+1):
            velocity = self.generate_default_velocity(ravel_params(position).shape[-1])
            proposal_position, n_position, n_velocity = position, position, velocity
            current_l_frog_steps = torch.max(torch.tensor(1),torch.round(self.Lambda/self.step_size)).int()
            delta_energy, proposal_position, proposal_velocity, _ = self.step_integrator(position, velocity, self.step_size, current_l_frog_steps)
            # nan fix
            delta_energy = torch.where(torch.isnan(delta_energy), -torch.inf, delta_energy)
            # MH Algo
            alpha = torch.min(torch.exp(delta_energy), torch.ones(1))
            accept_condition = torch.distributions.Bernoulli(alpha).sample()
            proposal_position, proposal_velocity = (proposal_position, proposal_velocity) if accept_condition.bool() else (position, velocity)
            # tuning step size
            if m <= self.m_warmup:
                self.H_m = (1-1/(m+self.t_0))*self.H_m + (1/(m+self.t_0))*(self.expected_prob_density - alpha)
                log_step_size = self.mu - (torch.sqrt(torch.tensor(m))/self.gamma)*self.H_m
                step = self.step_fn(m)
                log_step_size_average = step * log_step_size + (1-step)*log_step_size_average
            self.step_size = torch.exp(log_step_size_average)
            self.step_size_average = torch.exp(log_step_size_average)
            print('Step size : ', self.step_size, delta_energy, current_l_frog_steps)

    def step_fn(self, current_step):
        return torch.pow(torch.tensor(1/current_step), self.k)

    def init_step(self, position):
        self.step_size = self.find_reasonable_epsilon(position)
        self.mu = torch.log(10*self.step_size)  
        self.step_size_average = torch.tensor(1)
        self.H_m = 0
        self.gamma = 0.05
        self.t_0 = 10
        self.k = 0.75
    
    def step_integrator(self, position, velocity, step_size_with_direction, l_frog_step=1):
        self.ep.init_per_step(position, velocity)
        # init step
        self.ep.updated_velocity(step_size_with_direction, is_half_step_momentum=True)
        # l_frog_steps
        for i in range(l_frog_step):
            self.ep.update_position(step_size_with_direction)
            self.ep.updated_velocity(step_size_with_direction, is_half_step_momentum=False)
        # final step
        f_step_position = self.ep.update_position(step_size_with_direction)
        half_step_velocity = self.ep.updated_velocity(step_size_with_direction, is_half_step_momentum=True)
        return self.ep.delta_energy(), f_step_position, half_step_velocity, self.ep.total_current_energy()

precision_shape = ravel_params(params).shape[-1]
# I^-1 = I so inverse doesn't matter but writing it for visibility
default_precision = torch.eye(precision_shape).inverse()
hmc_kernel = HMCAlgorithm(log_density_fn=potential, precision=default_precision)

# Test
hmc_kernel.update(params)
# Out:
# Step size (find_reasonable_epsilon) : 0.07999999821186066
# Step size :  tensor([0.4697], grad_fn=<ExpBackward0>) tensor(-1.0297, grad_fn=<WhereBackward0>) tensor(2, dtype=torch.int32)
# Step size :  tensor([0.1725], grad_fn=<ExpBackward0>) tensor(-6.1974, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0526], grad_fn=<ExpBackward0>) tensor(-28.1749, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0199], grad_fn=<ExpBackward0>) tensor(-1.1208, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0141], grad_fn=<ExpBackward0>) tensor(-0.0612, grad_fn=<WhereBackward0>) tensor([6], dtype=torch.int32)
# Step size :  tensor([0.0146], grad_fn=<ExpBackward0>) tensor(0.7122, grad_fn=<WhereBackward0>) tensor([8], dtype=torch.int32)
# Step size :  tensor([0.0119], grad_fn=<ExpBackward0>) tensor(-1.0486, grad_fn=<WhereBackward0>) tensor([8], dtype=torch.int32)
# Step size :  tensor([0.0075], grad_fn=<ExpBackward0>) tensor(-1.6344, grad_fn=<WhereBackward0>) tensor([10], dtype=torch.int32)
# Step size :  tensor([0.0067], grad_fn=<ExpBackward0>) tensor(1.9197, grad_fn=<WhereBackward0>) tensor([16], dtype=torch.int32)
# Step size :  tensor([0.0068], grad_fn=<ExpBackward0>) tensor(-0.1499, grad_fn=<WhereBackward0>) tensor([18], dtype=torch.int32)
# Step size :  tensor([0.0076], grad_fn=<ExpBackward0>) tensor(-0.1940, grad_fn=<WhereBackward0>) tensor([18], dtype=torch.int32)
# Step size :  tensor([0.0099], grad_fn=<ExpBackward0>) tensor(0.0714, grad_fn=<WhereBackward0>) tensor([16], dtype=torch.int32)
# Step size :  tensor([0.0108], grad_fn=<ExpBackward0>) tensor(-0.9494, grad_fn=<WhereBackward0>) tensor([12], dtype=torch.int32)
# Step size :  tensor([0.0098], grad_fn=<ExpBackward0>) tensor(-1.3712, grad_fn=<WhereBackward0>) tensor([11], dtype=torch.int32)
# Step size :  tensor([0.0079], grad_fn=<ExpBackward0>) tensor(-1.2401, grad_fn=<WhereBackward0>) tensor([12], dtype=torch.int32)
# Step size :  tensor([0.0074], grad_fn=<ExpBackward0>) tensor(-0.0511, grad_fn=<WhereBackward0>) tensor([15], dtype=torch.int32)
# Step size :  tensor([0.0080], grad_fn=<ExpBackward0>) tensor(0.2228, grad_fn=<WhereBackward0>) tensor([16], dtype=torch.int32)
# Step size :  tensor([0.0092], grad_fn=<ExpBackward0>) tensor(-0.1902, grad_fn=<WhereBackward0>) tensor([15], dtype=torch.int32)
# Step size :  tensor([0.0093], grad_fn=<ExpBackward0>) tensor(-1.0190, grad_fn=<WhereBackward0>) tensor([13], dtype=torch.int32)
# Step size :  tensor([0.0095], grad_fn=<ExpBackward0>) tensor(-0.4654, grad_fn=<WhereBackward0>) tensor([13], dtype=torch.int32)
# Step size :  tensor([0.0095], grad_fn=<ExpBackward0>) tensor(-0.4730, grad_fn=<WhereBackward0>) tensor([13], dtype=torch.int32)
# Step size :  tensor([0.0105], grad_fn=<ExpBackward0>) tensor(-0.0589, grad_fn=<WhereBackward0>) tensor([13], dtype=torch.int32)
# Step size :  tensor([0.0121], grad_fn=<ExpBackward0>) tensor(-0.1449, grad_fn=<WhereBackward0>) tensor([11], dtype=torch.int32)
# Step size :  tensor([0.0152], grad_fn=<ExpBackward0>) tensor(0.3689, grad_fn=<WhereBackward0>) tensor([10], dtype=torch.int32)
# Step size :  tensor([0.0192], grad_fn=<ExpBackward0>) tensor(-0.2195, grad_fn=<WhereBackward0>) tensor([8], dtype=torch.int32)
# Step size :  tensor([0.0225], grad_fn=<ExpBackward0>) tensor(-0.7990, grad_fn=<WhereBackward0>) tensor([6], dtype=torch.int32)
# Step size :  tensor([0.0283], grad_fn=<ExpBackward0>) tensor(0.0406, grad_fn=<WhereBackward0>) tensor([5], dtype=torch.int32)
# Step size :  tensor([0.0375], grad_fn=<ExpBackward0>) tensor(0.5350, grad_fn=<WhereBackward0>) tensor([4], dtype=torch.int32)
# Step size :  tensor([0.0511], grad_fn=<ExpBackward0>) tensor(-0.0928, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0707], grad_fn=<ExpBackward0>) tensor(-0.1494, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.1015], grad_fn=<ExpBackward0>) tensor(0.6634, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.1356], grad_fn=<ExpBackward0>) tensor(-0.7514, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1551], grad_fn=<ExpBackward0>) tensor(-6.7010, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1596], grad_fn=<ExpBackward0>) tensor(-1.8854, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1470], grad_fn=<ExpBackward0>) tensor(-2.9563, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1453], grad_fn=<ExpBackward0>) tensor(2.9445, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1528], grad_fn=<ExpBackward0>) tensor(0.5310, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1497], grad_fn=<ExpBackward0>) tensor(-1.3995, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1452], grad_fn=<ExpBackward0>) tensor(-0.5532, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1300], grad_fn=<ExpBackward0>) tensor(-2.0805, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1242], grad_fn=<ExpBackward0>) tensor(0.1742, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1220], grad_fn=<ExpBackward0>) tensor(-0.2180, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1265], grad_fn=<ExpBackward0>) tensor(1.2645, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1221], grad_fn=<ExpBackward0>) tensor(-1.7972, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1242], grad_fn=<ExpBackward0>) tensor(0.7630, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1254], grad_fn=<ExpBackward0>) tensor(-0.5104, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1327], grad_fn=<ExpBackward0>) tensor(0.2488, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1465], grad_fn=<ExpBackward0>) tensor(2.2359, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1679], grad_fn=<ExpBackward0>) tensor(1.9820, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1757], grad_fn=<ExpBackward0>) tensor(-36.9342, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1694], grad_fn=<ExpBackward0>) tensor(-6.5881, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1515], grad_fn=<ExpBackward0>) tensor(-47.1915, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1424], grad_fn=<ExpBackward0>) tensor(0.5487, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1300], grad_fn=<ExpBackward0>) tensor(-1.0235, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1162], grad_fn=<ExpBackward0>) tensor(-0.9217, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1045], grad_fn=<ExpBackward0>) tensor(-0.4706, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0948], grad_fn=<ExpBackward0>) tensor(-0.3979, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0900], grad_fn=<ExpBackward0>) tensor(0.1745, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0863], grad_fn=<ExpBackward0>) tensor(-0.3434, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0803], grad_fn=<ExpBackward0>) tensor(-1.1227, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0778], grad_fn=<ExpBackward0>) tensor(1.0481, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0724], grad_fn=<ExpBackward0>) tensor(-1.5200, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0649], grad_fn=<ExpBackward0>) tensor(-1.5787, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0605], grad_fn=<ExpBackward0>) tensor(1.1237, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0587], grad_fn=<ExpBackward0>) tensor(0.9985, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0569], grad_fn=<ExpBackward0>) tensor(-0.4545, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0540], grad_fn=<ExpBackward0>) tensor(-0.9639, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0489], grad_fn=<ExpBackward0>) tensor(-2.5145, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0440], grad_fn=<ExpBackward0>) tensor(-0.6784, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0411], grad_fn=<ExpBackward0>) tensor(1.2582, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0397], grad_fn=<ExpBackward0>) tensor(0.5584, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0396], grad_fn=<ExpBackward0>) tensor(0.1444, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0398], grad_fn=<ExpBackward0>) tensor(-0.3173, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0397], grad_fn=<ExpBackward0>) tensor(-0.6246, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0406], grad_fn=<ExpBackward0>) tensor(0.4815, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0406], grad_fn=<ExpBackward0>) tensor(-1.0760, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0418], grad_fn=<ExpBackward0>) tensor(0.6763, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0440], grad_fn=<ExpBackward0>) tensor(0.4622, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0476], grad_fn=<ExpBackward0>) tensor(1.0300, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0526], grad_fn=<ExpBackward0>) tensor(0.3448, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0593], grad_fn=<ExpBackward0>) tensor(1.6810, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0683], grad_fn=<ExpBackward0>) tensor(2.2050, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0801], grad_fn=<ExpBackward0>) tensor(1.0106, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0948], grad_fn=<ExpBackward0>) tensor(-0.1027, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1100], grad_fn=<ExpBackward0>) tensor(-0.7568, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1297], grad_fn=<ExpBackward0>) tensor(-0.0254, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1517], grad_fn=<ExpBackward0>) tensor(-0.4230, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1689], grad_fn=<ExpBackward0>) tensor(-4.0801, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1793], grad_fn=<ExpBackward0>) tensor(-14.9877, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1820], grad_fn=<ExpBackward0>) tensor(-8.5525, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1785], grad_fn=<ExpBackward0>) tensor(-2.1630, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1682], grad_fn=<ExpBackward0>) tensor(-4.4768, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1528], grad_fn=<ExpBackward0>) tensor(-5.0310, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1344], grad_fn=<ExpBackward0>) tensor(-2.8915, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1204], grad_fn=<ExpBackward0>) tensor(-0.1588, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1107], grad_fn=<ExpBackward0>) tensor(0.8988, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1036], grad_fn=<ExpBackward0>) tensor(-0.1220, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0974], grad_fn=<ExpBackward0>) tensor(-0.4062, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0938], grad_fn=<ExpBackward0>) tensor(0.3101, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0889], grad_fn=<ExpBackward0>) tensor(-1.0479, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0852], grad_fn=<ExpBackward0>) tensor(-0.2115, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0835], grad_fn=<ExpBackward0>) tensor(0.6509, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0818], grad_fn=<ExpBackward0>) tensor(-0.4636, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0784], grad_fn=<ExpBackward0>) tensor(-1.4790, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0752], grad_fn=<ExpBackward0>) tensor(-0.4582, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0737], grad_fn=<ExpBackward0>) tensor(0.4783, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0724], grad_fn=<ExpBackward0>) tensor(-0.4047, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0704], grad_fn=<ExpBackward0>) tensor(-0.7984, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0680], grad_fn=<ExpBackward0>) tensor(-0.7052, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0669], grad_fn=<ExpBackward0>) tensor(0.0973, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0672], grad_fn=<ExpBackward0>) tensor(0.4728, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0653], grad_fn=<ExpBackward0>) tensor(-8.3100, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0643], grad_fn=<ExpBackward0>) tensor(-0.1039, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0614], grad_fn=<ExpBackward0>) tensor(-5.0718, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0598], grad_fn=<ExpBackward0>) tensor(0.1350, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0572], grad_fn=<ExpBackward0>) tensor(-1.3083, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0532], grad_fn=<ExpBackward0>) tensor(-3.8252, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0493], grad_fn=<ExpBackward0>) tensor(-0.7150, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0466], grad_fn=<ExpBackward0>) tensor(0.4790, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0448], grad_fn=<ExpBackward0>) tensor(0.6034, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0439], grad_fn=<ExpBackward0>) tensor(1.7322, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0421], grad_fn=<ExpBackward0>) tensor(-1.9942, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0399], grad_fn=<ExpBackward0>) tensor(-0.9499, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0383], grad_fn=<ExpBackward0>) tensor(-0.1491, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0374], grad_fn=<ExpBackward0>) tensor(0.4289, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0364], grad_fn=<ExpBackward0>) tensor(-0.5805, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0353], grad_fn=<ExpBackward0>) tensor(-0.5833, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0348], grad_fn=<ExpBackward0>) tensor(0.3028, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0344], grad_fn=<ExpBackward0>) tensor(-0.4153, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0345], grad_fn=<ExpBackward0>) tensor(0.3925, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0352], grad_fn=<ExpBackward0>) tensor(0.1738, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0362], grad_fn=<ExpBackward0>) tensor(-0.0717, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0374], grad_fn=<ExpBackward0>) tensor(-0.3535, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0391], grad_fn=<ExpBackward0>) tensor(0.0939, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0414], grad_fn=<ExpBackward0>) tensor(0.2622, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0432], grad_fn=<ExpBackward0>) tensor(-1.0854, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0453], grad_fn=<ExpBackward0>) tensor(-0.1908, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0482], grad_fn=<ExpBackward0>) tensor(1.3490, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0514], grad_fn=<ExpBackward0>) tensor(-0.2656, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0554], grad_fn=<ExpBackward0>) tensor(0.4295, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0600], grad_fn=<ExpBackward0>) tensor(-0.1980, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0641], grad_fn=<ExpBackward0>) tensor(-1.1007, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0692], grad_fn=<ExpBackward0>) tensor(1.5759, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0749], grad_fn=<ExpBackward0>) tensor(-0.2841, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0797], grad_fn=<ExpBackward0>) tensor(-1.2446, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0858], grad_fn=<ExpBackward0>) tensor(2.0901, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0933], grad_fn=<ExpBackward0>) tensor(0.1621, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1008], grad_fn=<ExpBackward0>) tensor(-0.6595, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1064], grad_fn=<ExpBackward0>) tensor(-2.2932, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1116], grad_fn=<ExpBackward0>) tensor(-0.7079, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1184], grad_fn=<ExpBackward0>) tensor(0.4971, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1226], grad_fn=<ExpBackward0>) tensor(-3.8596, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1248], grad_fn=<ExpBackward0>) tensor(-1.7011, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1250], grad_fn=<ExpBackward0>) tensor(-1.6444, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1228], grad_fn=<ExpBackward0>) tensor(-2.3782, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1181], grad_fn=<ExpBackward0>) tensor(-8.2449, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1150], grad_fn=<ExpBackward0>) tensor(0.8249, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1135], grad_fn=<ExpBackward0>) tensor(0.1801, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1134], grad_fn=<ExpBackward0>) tensor(0.1008, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1146], grad_fn=<ExpBackward0>) tensor(2.3686, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1171], grad_fn=<ExpBackward0>) tensor(1.0057, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1210], grad_fn=<ExpBackward0>) tensor(1.3291, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1230], grad_fn=<ExpBackward0>) tensor(-1.7624, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1224], grad_fn=<ExpBackward0>) tensor(-9.0214, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1195], grad_fn=<ExpBackward0>) tensor(-3.9419, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1151], grad_fn=<ExpBackward0>) tensor(-1.5202, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1122], grad_fn=<ExpBackward0>) tensor(1.0218, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1085], grad_fn=<ExpBackward0>) tensor(-0.9988, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1033], grad_fn=<ExpBackward0>) tensor(-2.4408, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0995], grad_fn=<ExpBackward0>) tensor(0.0653, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0950], grad_fn=<ExpBackward0>) tensor(-1.0589, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0915], grad_fn=<ExpBackward0>) tensor(-0.1624, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0891], grad_fn=<ExpBackward0>) tensor(0.3825, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0878], grad_fn=<ExpBackward0>) tensor(0.6334, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0874], grad_fn=<ExpBackward0>) tensor(0.1476, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0880], grad_fn=<ExpBackward0>) tensor(0.4387, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0872], grad_fn=<ExpBackward0>) tensor(-2.0126, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0873], grad_fn=<ExpBackward0>) tensor(-0.0286, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0883], grad_fn=<ExpBackward0>) tensor(0.4412, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0894], grad_fn=<ExpBackward0>) tensor(-0.3584, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0902], grad_fn=<ExpBackward0>) tensor(-0.6211, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0920], grad_fn=<ExpBackward0>) tensor(0.8243, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0941], grad_fn=<ExpBackward0>) tensor(-0.1930, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0972], grad_fn=<ExpBackward0>) tensor(-0.0025, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1014], grad_fn=<ExpBackward0>) tensor(0.9479, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1066], grad_fn=<ExpBackward0>) tensor(1.1358, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1121], grad_fn=<ExpBackward0>) tensor(-0.3420, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1158], grad_fn=<ExpBackward0>) tensor(-4.7153, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1174], grad_fn=<ExpBackward0>) tensor(-4.2477, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1201], grad_fn=<ExpBackward0>) tensor(0.4164, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1218], grad_fn=<ExpBackward0>) tensor(-1.0889, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1240], grad_fn=<ExpBackward0>) tensor(-0.2539, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1250], grad_fn=<ExpBackward0>) tensor(-1.0915, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1245], grad_fn=<ExpBackward0>) tensor(-1.9246, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1250], grad_fn=<ExpBackward0>) tensor(2.0386, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1240], grad_fn=<ExpBackward0>) tensor(-1.7617, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1242], grad_fn=<ExpBackward0>) tensor(0.5026, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1241], grad_fn=<ExpBackward0>) tensor(-0.5685, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1241], grad_fn=<ExpBackward0>) tensor(-0.4075, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1252], grad_fn=<ExpBackward0>) tensor(0.3992, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1274], grad_fn=<ExpBackward0>) tensor(0.6936, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1292], grad_fn=<ExpBackward0>) tensor(-0.6374, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1292], grad_fn=<ExpBackward0>) tensor(-2.5057, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1273], grad_fn=<ExpBackward0>) tensor(-2.7389, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1236], grad_fn=<ExpBackward0>) tensor(-3.2878, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1206], grad_fn=<ExpBackward0>) tensor(-0.2177, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1187], grad_fn=<ExpBackward0>) tensor(0.1338, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1171], grad_fn=<ExpBackward0>) tensor(-0.3227, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1140], grad_fn=<ExpBackward0>) tensor(-2.9480, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1098], grad_fn=<ExpBackward0>) tensor(-1.5776, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1055], grad_fn=<ExpBackward0>) tensor(-0.6823, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1000], grad_fn=<ExpBackward0>) tensor(-11.0884, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0936], grad_fn=<ExpBackward0>) tensor(-2.3429, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0882], grad_fn=<ExpBackward0>) tensor(-0.1891, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0839], grad_fn=<ExpBackward0>) tensor(1.0585, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0793], grad_fn=<ExpBackward0>) tensor(-1.1513, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0756], grad_fn=<ExpBackward0>) tensor(0.4116, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0714], grad_fn=<ExpBackward0>) tensor(-1.9023, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0680], grad_fn=<ExpBackward0>) tensor(0.1565, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0648], grad_fn=<ExpBackward0>) tensor(-0.4987, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0611], grad_fn=<ExpBackward0>) tensor(-2.5329, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0581], grad_fn=<ExpBackward0>) tensor(0.6932, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0550], grad_fn=<ExpBackward0>) tensor(-0.9594, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0516], grad_fn=<ExpBackward0>) tensor(-1.4010, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0490], grad_fn=<ExpBackward0>) tensor(0.1947, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0462], grad_fn=<ExpBackward0>) tensor(-0.9753, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0437], grad_fn=<ExpBackward0>) tensor(-0.3741, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0417], grad_fn=<ExpBackward0>) tensor(1.0352, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0398], grad_fn=<ExpBackward0>) tensor(-0.4495, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0383], grad_fn=<ExpBackward0>) tensor(0.7009, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0372], grad_fn=<ExpBackward0>) tensor(0.8159, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0362], grad_fn=<ExpBackward0>) tensor(-0.4836, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0354], grad_fn=<ExpBackward0>) tensor(0.9063, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0346], grad_fn=<ExpBackward0>) tensor(-0.7672, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0340], grad_fn=<ExpBackward0>) tensor(0.1415, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0335], grad_fn=<ExpBackward0>) tensor(-0.3237, grad_fn=<WhereBackward0>) tensor([4], dtype=torch.int32)
# Step size :  tensor([0.0332], grad_fn=<ExpBackward0>) tensor(-0.1608, grad_fn=<WhereBackward0>) tensor([4], dtype=torch.int32)
# Step size :  tensor([0.0330], grad_fn=<ExpBackward0>) tensor(-0.1954, grad_fn=<WhereBackward0>) tensor([4], dtype=torch.int32)
# Step size :  tensor([0.0331], grad_fn=<ExpBackward0>) tensor(0.5701, grad_fn=<WhereBackward0>) tensor([4], dtype=torch.int32)
# Step size :  tensor([0.0330], grad_fn=<ExpBackward0>) tensor(-0.9037, grad_fn=<WhereBackward0>) tensor([4], dtype=torch.int32)
# Step size :  tensor([0.0331], grad_fn=<ExpBackward0>) tensor(0.5500, grad_fn=<WhereBackward0>) tensor([4], dtype=torch.int32)
# Step size :  tensor([0.0334], grad_fn=<ExpBackward0>) tensor(0.3529, grad_fn=<WhereBackward0>) tensor([4], dtype=torch.int32)
# Step size :  tensor([0.0340], grad_fn=<ExpBackward0>) tensor(1.4458, grad_fn=<WhereBackward0>) tensor([4], dtype=torch.int32)
# Step size :  tensor([0.0344], grad_fn=<ExpBackward0>) tensor(-1.2606, grad_fn=<WhereBackward0>) tensor([4], dtype=torch.int32)
# Step size :  tensor([0.0350], grad_fn=<ExpBackward0>) tensor(0.4728, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0356], grad_fn=<ExpBackward0>) tensor(-0.2879, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0366], grad_fn=<ExpBackward0>) tensor(0.3855, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0377], grad_fn=<ExpBackward0>) tensor(0.4302, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0388], grad_fn=<ExpBackward0>) tensor(-0.7047, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0401], grad_fn=<ExpBackward0>) tensor(-0.1069, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0414], grad_fn=<ExpBackward0>) tensor(-0.3880, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0430], grad_fn=<ExpBackward0>) tensor(1.0532, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0447], grad_fn=<ExpBackward0>) tensor(-0.3446, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0460], grad_fn=<ExpBackward0>) tensor(-2.2428, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0469], grad_fn=<ExpBackward0>) tensor(-1.3177, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0477], grad_fn=<ExpBackward0>) tensor(-0.7449, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0483], grad_fn=<ExpBackward0>) tensor(-0.7444, grad_fn=<WhereBackward0>) tensor([3], dtype=torch.int32)
# Step size :  tensor([0.0487], grad_fn=<ExpBackward0>) tensor(-1.0408, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0492], grad_fn=<ExpBackward0>) tensor(-0.2391, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0492], grad_fn=<ExpBackward0>) tensor(-1.6833, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0495], grad_fn=<ExpBackward0>) tensor(-0.1666, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0494], grad_fn=<ExpBackward0>) tensor(-0.9975, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0490], grad_fn=<ExpBackward0>) tensor(-1.8810, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0488], grad_fn=<ExpBackward0>) tensor(0.0075, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0490], grad_fn=<ExpBackward0>) tensor(0.3184, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0495], grad_fn=<ExpBackward0>) tensor(0.4852, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0503], grad_fn=<ExpBackward0>) tensor(0.6332, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0508], grad_fn=<ExpBackward0>) tensor(-1.1999, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0509], grad_fn=<ExpBackward0>) tensor(-1.2964, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0509], grad_fn=<ExpBackward0>) tensor(-0.8047, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0512], grad_fn=<ExpBackward0>) tensor(0.3559, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0518], grad_fn=<ExpBackward0>) tensor(0.9184, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0527], grad_fn=<ExpBackward0>) tensor(0.6188, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0539], grad_fn=<ExpBackward0>) tensor(0.1198, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0555], grad_fn=<ExpBackward0>) tensor(0.9778, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0575], grad_fn=<ExpBackward0>) tensor(0.6155, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0598], grad_fn=<ExpBackward0>) tensor(0.1207, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0626], grad_fn=<ExpBackward0>) tensor(0.6872, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0649], grad_fn=<ExpBackward0>) tensor(-1.5382, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0677], grad_fn=<ExpBackward0>) tensor(-0.0659, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0709], grad_fn=<ExpBackward0>) tensor(0.8232, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0746], grad_fn=<ExpBackward0>) tensor(0.3434, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0786], grad_fn=<ExpBackward0>) tensor(-0.3127, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0819], grad_fn=<ExpBackward0>) tensor(-2.7721, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0854], grad_fn=<ExpBackward0>) tensor(-0.2952, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0895], grad_fn=<ExpBackward0>) tensor(0.5616, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0933], grad_fn=<ExpBackward0>) tensor(-1.0379, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0977], grad_fn=<ExpBackward0>) tensor(0.0189, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1028], grad_fn=<ExpBackward0>) tensor(0.1434, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1072], grad_fn=<ExpBackward0>) tensor(-2.0345, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1115], grad_fn=<ExpBackward0>) tensor(-0.6803, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1146], grad_fn=<ExpBackward0>) tensor(-4.1480, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1167], grad_fn=<ExpBackward0>) tensor(-3.1183, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1186], grad_fn=<ExpBackward0>) tensor(-0.6379, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1194], grad_fn=<ExpBackward0>) tensor(-1.9638, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1210], grad_fn=<ExpBackward0>) tensor(1.1579, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1214], grad_fn=<ExpBackward0>) tensor(-2.4635, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1207], grad_fn=<ExpBackward0>) tensor(-3.2745, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1207], grad_fn=<ExpBackward0>) tensor(0.7371, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1205], grad_fn=<ExpBackward0>) tensor(-0.6086, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1191], grad_fn=<ExpBackward0>) tensor(-4.2546, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1184], grad_fn=<ExpBackward0>) tensor(0.7126, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1168], grad_fn=<ExpBackward0>) tensor(-2.1253, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1158], grad_fn=<ExpBackward0>) tensor(0.6205, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1155], grad_fn=<ExpBackward0>) tensor(0.1633, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1140], grad_fn=<ExpBackward0>) tensor(-7.0389, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1132], grad_fn=<ExpBackward0>) tensor(0.8438, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1128], grad_fn=<ExpBackward0>) tensor(-0.1425, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1125], grad_fn=<ExpBackward0>) tensor(-0.4084, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1116], grad_fn=<ExpBackward0>) tensor(-1.0519, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1106], grad_fn=<ExpBackward0>) tensor(-0.6534, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1101], grad_fn=<ExpBackward0>) tensor(0.9824, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1093], grad_fn=<ExpBackward0>) tensor(-0.9093, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1091], grad_fn=<ExpBackward0>) tensor(0.0086, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1081], grad_fn=<ExpBackward0>) tensor(-1.7143, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1062], grad_fn=<ExpBackward0>) tensor(-3.3336, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1044], grad_fn=<ExpBackward0>) tensor(-0.3869, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1032], grad_fn=<ExpBackward0>) tensor(0.0701, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1014], grad_fn=<ExpBackward0>) tensor(-1.4926, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0998], grad_fn=<ExpBackward0>) tensor(-0.2687, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0988], grad_fn=<ExpBackward0>) tensor(1.1008, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0975], grad_fn=<ExpBackward0>) tensor(-0.8513, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0968], grad_fn=<ExpBackward0>) tensor(1.1696, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0965], grad_fn=<ExpBackward0>) tensor(0.3821, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0967], grad_fn=<ExpBackward0>) tensor(0.0452, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0964], grad_fn=<ExpBackward0>) tensor(-1.3173, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0958], grad_fn=<ExpBackward0>) tensor(-0.8972, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0950], grad_fn=<ExpBackward0>) tensor(-0.6836, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0947], grad_fn=<ExpBackward0>) tensor(0.9700, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0948], grad_fn=<ExpBackward0>) tensor(0.1358, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0954], grad_fn=<ExpBackward0>) tensor(0.4034, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0961], grad_fn=<ExpBackward0>) tensor(-0.3136, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0973], grad_fn=<ExpBackward0>) tensor(0.0723, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.0990], grad_fn=<ExpBackward0>) tensor(0.8603, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1011], grad_fn=<ExpBackward0>) tensor(0.3630, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1029], grad_fn=<ExpBackward0>) tensor(-0.9870, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1051], grad_fn=<ExpBackward0>) tensor(1.2591, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1070], grad_fn=<ExpBackward0>) tensor(-0.8743, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1095], grad_fn=<ExpBackward0>) tensor(0.4297, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1111], grad_fn=<ExpBackward0>) tensor(-3.3043, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1125], grad_fn=<ExpBackward0>) tensor(-0.6010, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1144], grad_fn=<ExpBackward0>) tensor(2.6125, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1154], grad_fn=<ExpBackward0>) tensor(-2.9666, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1164], grad_fn=<ExpBackward0>) tensor(-0.4860, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1164], grad_fn=<ExpBackward0>) tensor(-4.0144, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1155], grad_fn=<ExpBackward0>) tensor(-4.6140, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1139], grad_fn=<ExpBackward0>) tensor(-1.5332, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1129], grad_fn=<ExpBackward0>) tensor(0.7467, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1124], grad_fn=<ExpBackward0>) tensor(0.4373, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1110], grad_fn=<ExpBackward0>) tensor(-5.2180, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1101], grad_fn=<ExpBackward0>) tensor(0.8230, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1093], grad_fn=<ExpBackward0>) tensor(-0.4593, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1076], grad_fn=<ExpBackward0>) tensor(-3.2273, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1065], grad_fn=<ExpBackward0>) tensor(0.1063, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1058], grad_fn=<ExpBackward0>) tensor(1.1574, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1056], grad_fn=<ExpBackward0>) tensor(0.5357, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1059], grad_fn=<ExpBackward0>) tensor(0.0370, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1067], grad_fn=<ExpBackward0>) tensor(0.5248, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1074], grad_fn=<ExpBackward0>) tensor(-0.5099, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1086], grad_fn=<ExpBackward0>) tensor(0.1956, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1092], grad_fn=<ExpBackward0>) tensor(-1.4646, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1097], grad_fn=<ExpBackward0>) tensor(-0.5618, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1098], grad_fn=<ExpBackward0>) tensor(-1.0078, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1093], grad_fn=<ExpBackward0>) tensor(-1.4460, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1083], grad_fn=<ExpBackward0>) tensor(-1.3992, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1078], grad_fn=<ExpBackward0>) tensor(0.5833, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1078], grad_fn=<ExpBackward0>) tensor(1.8171, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1083], grad_fn=<ExpBackward0>) tensor(0.2511, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1091], grad_fn=<ExpBackward0>) tensor(-0.0415, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1104], grad_fn=<ExpBackward0>) tensor(2.1695, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1112], grad_fn=<ExpBackward0>) tensor(-1.4691, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1115], grad_fn=<ExpBackward0>) tensor(-1.0990, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1110], grad_fn=<ExpBackward0>) tensor(-2.6435, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1110], grad_fn=<ExpBackward0>) tensor(1.0402, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1115], grad_fn=<ExpBackward0>) tensor(3.3295, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1125], grad_fn=<ExpBackward0>) tensor(1.4289, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1133], grad_fn=<ExpBackward0>) tensor(-0.5940, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# Step size :  tensor([0.1135], grad_fn=<ExpBackward0>) tensor(-1.4197, grad_fn=<WhereBackward0>) tensor([1], dtype=torch.int32)
# ...
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.5810, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.1555, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.7442, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.1160, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.6785, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.3170, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.3551, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.4987, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.1959, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.5056, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.4887, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.5171, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.6013, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.5182, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.1646, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2945, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.3652, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.0961, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.5319, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.2006, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.4536, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.5890, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.5549, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.3355, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.3055, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.5850, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.1437, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.1509, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2744, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.9676, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.0403, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.4870, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.3335, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.5784, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.4513, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.4337, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.3500, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.0465, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2896, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.7019, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.9289, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.1925, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.2349, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(1.0844, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.2490, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.3427, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.0379, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.0247, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.0042, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.1050, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.3390, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.1171, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.4959, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.1242, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.0917, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.3766, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2123, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.6691, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.2613, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.6040, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.4528, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.0154, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.3569, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.6993, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(1.2903, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.1212, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.0204, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.4655, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.6636, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.2290, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-2.2009, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.7882, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.1093, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2587, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2636, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.1599, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.0370, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.3439, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.6490, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.2029, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.0100, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2211, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2384, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.2687, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.2715, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.3546, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.7975, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.2702, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.9270, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.2334, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2262, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.7316, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.0905, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.8595, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.5197, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.1308, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.7462, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.3444, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2602, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.9347, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2112, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.4022, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.9970, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(1.1039, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.9309, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.2430, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.1794, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.1834, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.2883, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.6154, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.6878, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.6279, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.5762, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.5798, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.2642, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.0178, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-1.1026, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.4490, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.2446, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.1080, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.9553, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.1924, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-2.0298, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.3238, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(0.5756, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
# Step size :  tensor([0.0507], grad_fn=<ExpBackward0>) tensor(-0.6593, grad_fn=<WhereBackward0>) tensor([2], dtype=torch.int32)
